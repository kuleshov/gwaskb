# %% [markdown]
# # Evaluation notebook

# %% [markdown]
# Here, we will evaluate the relations extracted in all the other notebooks

# %%
# %load_ext autoreload
# %autoreload 2

import sys
import cPickle
import numpy as np

# import snorkel and gwasdb
sys.path.append('../snorkel')
sys.path.append('../src')
sys.path.append('../src/crawler')

# set up paths
abstract_dir = '../data/db/papers'

# %%
from snorkel.parser import XMLDocParser, HTMLParser, CorpusParser
from extractor.parser import UnicodeXMLTableDocParser, UnicodeTableParser

xml_parser = UnicodeXMLTableDocParser(
    path=abstract_dir,
    doc='./*',
    text='.//table',
    id='.//article-id[@pub-id-type="pmid"]/text()',
    keep_xml_tree=True)

table_parser = UnicodeTableParser()
html_parser = HTMLParser(path='../data/db/papers/')
cp = CorpusParser(xml_parser, table_parser)
# %time corpus = cp.parse_corpus(name='GWAS Corpus')
# Out:
# CPU times: user 14min 49s, sys: 47.4 s, total: 15min 37s
# Wall time: 23min 30s

# %% [markdown]
# ## Loading results from other notebooks

# %% [markdown]
# #### Phenotype/rsid relations from tables

# %%
table_associations = []
with open('phen-rsid.table.rel.all.tsv') as f:
    for line in f:
        fields = line.strip().split('\t')
        pmid, rsid, phen, pval = fields[:4]
        table_associations.append((pmid, rsid, phen))
        
print len(table_associations), 'loaded, e.g.:'
print table_associations[:5]
# Out:
# 1939 loaded, e.g.:
# [('17903292', 'rs1158167', 'cst3'), ('17903292', 'rs1712790', 'urinary albumin excretion'), ('17903292', 'rs6977660', 'thyroid stimulating hormone'), ('17903292', 'rs9322817', 'thyroid stimulating hormone'), ('17903292', 'rs10499559', 'thyroid stimulating hormone')]

# %% [markdown]
# #### PMID/Phenotype relations extracted from titles/abstracts

# %%
text_associations = dict()
with open('phenotypes.extracted.tsv') as f:
    for line in f:
        name, phen = line.strip().split('\t')
        text_associations[name] = phen
        
print len(text_associations), 'loaded, e.g.:'
print text_associations.items()[:5]
# Out:
# 589 loaded, e.g.:
# [('23738518', 'reading'), ('19056611', 'Type 2 Diabetes'), ('21298047', 'Dependence'), ('23104006', 'endometriosis'), ('20072603', 'Osteoporosis.')]

# %% [markdown]
# #### RSID/Pvalue relations extracted from tables

# %%
rsid_dict = dict()
pval_dict = dict()
with open('pval-rsid.raw.tsv') as f:
    for line in f:
        pmid, rsid, table_id, row_id, col_id, pval = line.strip().split('\t')
        pval, table_id, row_id, col_id = float(pval), int(table_id), int(row_id), int(col_id)
        
        if pmid not in pval_dict: pval_dict[pmid] = dict()
        if rsid not in pval_dict[pmid]: pval_dict[pmid][rsid] = set()
        pval_dict[pmid][rsid].add(pval)
        
        if pval > 1e-5: continue
            
        if pmid not in rsid_dict: rsid_dict[pmid] = set()
        rsid_dict[pmid].add(rsid)

# %% [markdown]
# #### Singleton RSids

# %%
singleton_rsids = dict()
with open('rsids.singletons.all.tsv') as f:
    for line in f:
        pmid, table_id, rsid = line.strip().split()
        if pmid not in singleton_rsids: singleton_rsids[pmid] = set()
        singleton_rsids[pmid].add(rsid)
# Out:
# 17903305

# %% [markdown]
# ## Construct a list valid relations

# %%
# TODO: load pvalues properly, use them to filter stuff downstream, do acroynm resolution here

# %%
import re

def clean(phen):
    phen = re.sub('[)():.]+', '', phen)
    phen = re.sub('^or ', '', phen)
    phen = phen.strip()
    return phen

associations = []

for (pmid, rsid, loc_phen) in table_associations:
    if rsid in rsid_dict[pmid]:
        glob_phen = clean(text_associations.get(pmid, ''))
        associations.append((pmid, rsid, (glob_phen, loc_phen)))

table_rsids = {(pmid, rsid) for pmid, rsid, _ in table_associations}
for pmid in rsid_dict:
    phen = clean(text_associations[pmid])
    for rsid in rsid_dict[pmid]:
        if (pmid, rsid) in table_rsids: continue
        associations.append((pmid, rsid, (phen, '')))

for pmid, rsids in singleton_rsids.items():
    for rsid in rsids:
        if rsid in rsid_dict.get(pmid, []): continue
        phen = clean(text_associations[pmid])
        associations.append((pmid, rsid, (phen, '')))

# %% [markdown]
# ## Comparing to GWAS central

# %%
from db.kb import KnowledgeBase

kb = KnowledgeBase()
assocs = [assoc for doc in corpus.documents for assoc in kb.assoc_by_pmid(doc.name) if assoc.source == 'gwas_central' and assoc.pvalue < 1e-5]

print '%d documents, %d associations' % (len(corpus.documents), len(assocs))
# Out:
# 589 documents, 7629 associations

# %%
rel_dict = { (pmid, rsid) : set() for (pmid, rsid, phen) in associations }
for (pmid, rsid, phen) in associations:
    rel_dict[(pmid, rsid)].add(phen)

gold_rel_dict = { (a.paper.pubmed_id, a.snp.rs_id) : set() for a in assocs }
for a in assocs:
    gold_rel_dict[(a.paper.pubmed_id, a.snp.rs_id)].add(a.phenotype.name)

# %%
# display directly the results we found
for doc in corpus.documents:
#     continue
    rsids_seen = set()
    for a in assocs:
        if str(a.paper.pubmed_id) != doc.name: continue
        rsids_seen.add(a.snp.rs_id)
        
        print a.paper.pubmed_id, a.snp.rs_id, a.source
        print 'GWC:', gold_rel_dict[(a.paper.pubmed_id, a.snp.rs_id)]
        print 'US: ', rel_dict.get((str(a.paper.pubmed_id), a.snp.rs_id), None)
        print
    
    for (pmid, rsid), phens in rel_dict.items():
        if pmid != doc.name: continue
        if rsid in rsids_seen: continue
        print pmid, rsid, phens
    print '---'
# Out:
# 17447842 rs11209026 gwas_central
# GWC: set([u"Crohn's disease"])
# US:  None
#
# 17447842 rs11465804 gwas_central
# GWC: set([u"Crohn's disease"])
# US:  None
#
# 17447842 rs1373692 gwas_central
# GWC: set([u"Crohn's disease"])
# US:  None
#
# 17447842 rs10512734 gwas_central
# GWC: set([u"Crohn's disease"])
# US:  None
#
# 17447842 rs4613763 gwas_central
# GWC: set([u"Crohn's disease"])
# US:  None
#
# 17447842 rs1002922 gwas_central
# GWC: set([u"Crohn's disease"])
# US:  None
#
# 17447842 rs1343151 gwas_central
# GWC: set([u"Crohn's disease"])
# US:  None
#
# 17447842 rs4495224 gwas_central
# GWC: set([u"Crohn's disease"])
# US:  None
#
# 17447842 rs348601 gwas_central
# GWC: set([u"Crohn's disease"])
# US:  None
#
# 17447842 rs5743289 gwas_central
# GWC: set([u"Crohn's disease"])
# US:  None
#
# 17447842 rs10889677 gwas_central
# GWC: set([u"Crohn's disease"])
# US:  None
#
# 17447842 rs11209026 gwas_central
# GWC: set([u"Crohn's disease"])
# US:  None
#
# 17447842 rs11465804 gwas_central
# GWC: set([u"Crohn's disease"])
# US:  None
#
# 17447842 rs1373692 gwas_central
# GWC: set([u"Crohn's disease"])
# US:  None
#
# 17447842 rs10512734 gwas_central
# GWC: set([u"Crohn's disease"])
# US:  None
#
# 17447842 rs4613763 gwas_central
# GWC: set([u"Crohn's disease"])
# US:  None
#
# 17447842 rs1002922 gwas_central
# GWC: set([u"Crohn's disease"])
# US:  None
#
# 17447842 rs1343151 gwas_central
# GWC: set([u"Crohn's disease"])
# US:  None
#
# 17447842 rs4495224 gwas_central
# GWC: set([u"Crohn's disease"])
# US:  None
#
# 17447842 rs348601 gwas_central
# GWC: set([u"Crohn's disease"])
# US:  None
#
# 17447842 rs5743289 gwas_central
# GWC: set([u"Crohn's disease"])
# US:  None
#
# 17447842 rs10889677 gwas_central
# GWC: set([u"Crohn's disease"])
# US:  None
#
# ---
# 17658951 rs9930506 gwas_central
# GWC: set([u'Hip circumference'])
# US:  None
#
# 17658951 rs8050136 gwas_central
# GWC: set([u'Hip circumference'])
# US:  None
#
# 17658951 rs9940128 gwas_central
# GWC: set([u'Hip circumference'])
# US:  None
#
# 17658951 rs9939973 gwas_central
# GWC: set([u'Hip circumference'])
# US:  None
#
# 17658951 rs1121980 gwas_central
# GWC: set([u'Hip circumference'])
# US:  None
#
# 17658951 rs7193144 gwas_central
# GWC: set([u'Hip circumference'])
# US:  None
#
# 17658951 rs9939609 gwas_central
# GWC: set([u'Hip circumference'])
# US:  None
#
# 17658951 rs9926289 gwas_central
# GWC: set([u'Hip circumference'])
# US:  None
#
# 17658951 rs965670 gwas_central
# GWC: set([u'Hip circumference'])
# US:  None
#
# 17658951 rs2180579 gwas_central
# GWC: set([u'Hip circumference'])
# US:  None
#
# 17658951 rs6602024 gwas_central
# GWC: set([u'Body mass index'])
# US:  None
#
# 17658951 rs658838 gwas_central
# GWC: set([u'Body mass index'])
# US:  None
#
# 17658951 rs41512445 gwas_central
# GWC: set([u'Weight'])
# US:  None
#
# 17658951 rs9930506 gwas_central
# GWC: set([u'Hip circumference'])
# US:  None
#
# 17658951 rs8050136 gwas_central
# GWC: set([u'Hip circumference'])
# US:  None
#
# 17658951 rs9940128 gwas_central
# GWC: set([u'Hip circumference'])
# US:  None
#
# 17658951 rs9939973 gwas_central
# GWC: set([u'Hip circumference'])
# US:  None
#
# 17658951 rs1121980 gwas_central
# GWC: set([u'Hip circumference'])
# US:  None
#
# 17658951 rs7193144 gwas_central
# GWC: set([u'Hip circumference'])
# US:  None
#
# 17658951 rs9939609 gwas_central
# GWC: set([u'Hip circumference'])
# US:  None
#
# 17658951 rs9926289 gwas_central
# GWC: set([u'Hip circumference'])
# US:  None
#
# 17658951 rs965670 gwas_central
# GWC: set([u'Hip circumference'])
# US:  None
#
# 17658951 rs2180579 gwas_central
# GWC: set([u'Hip circumference'])
# US:  None
#
# 17658951 rs6602024 gwas_central
# GWC: set([u'Body mass index'])
# US:  None
#
# 17658951 rs658838 gwas_central
# GWC: set([u'Body mass index'])
# US:  None
#
# 17658951 rs41512445 gwas_central
# GWC: set([u'Weight'])
# US:  None
#
# ---
# 17684544 rs2066847 gwas_central
# GWC: set([u"Crohn's disease"])
# US:  set([('IBD Disease', '')])
#
# 17684544 rs2076756 gwas_central
# GWC: set([u"Crohn's disease"])
# US:  set([('IBD Disease', '')])
#
# 17684544 rs2066844 gwas_central
# GWC: set([u"Crohn's disease"])
# US:  set([('IBD Disease', '')])
#
# 17684544 rs2066845 gwas_central
# GWC: set([u"Crohn's disease"])
# US:  set([('IBD Disease', '')])
#
# 17684544 rs1992660 gwas_central
# GWC: set([u"Crohn's disease"])
# US:  set([('IBD Disease', '')])
#
# 17684544 rs1992662 gwas_central
# GWC: set([u"Crohn's disease"])
# US:  set([('IBD Disease', '')])
#
# 17684544 rs11209026 gwas_central
# GWC: set([u"Crohn's disease"])
# US:  set([('IBD Disease', '')])
#
# 17684544 rs10484545 gwas_central
# GWC: set([u"Crohn's disease"])
# US:  set([('IBD Disease', '')])
#
# 17684544 rs1793004 gwas_central
# GWC: set([u"Crohn's disease"])
# US:  set([('IBD Disease', '')])
#
# 17684544 rs2241880 gwas_central
# GWC: set([u"Crohn's disease"])
# US:  set([('IBD Disease', '')])
#
# 17684544 rs1553575 gwas_central
# GWC: set([u"Crohn's disease"])
# US:  set([('IBD Disease', '')])
#
# 17684544 rs10513059 gwas_central
# GWC: set([u"Crohn's disease"])
# US:  None
#
# 17684544 rs200354 gwas_central
# GWC: set([u"Crohn's disease"])
# US:  None
#
# 17684544 rs7725052 gwas_central
# GWC: set([u"Crohn's disease"])
# US:  None
#
# 17684544 rs2009530 gwas_central
# GWC: set([u"Crohn's disease"])
# US:  None
#
# 17684544 rs10484543 gwas_central
# GWC: set([u"Crohn's disease"])
# US:  None
#
# 17684544 rs2066847 gwas_central
# GWC: set([u"Crohn's disease"])
# US:  set([('IBD Disease', '')])
#
# 17684544 rs2076756 gwas_central
# GWC: set([u"Crohn's disease"])
# US:  set([('IBD Disease', '')])
#
# 17684544 rs2066844 gwas_central
# GWC: set([u"Crohn's disease"])
# US:  set([('IBD Disease', '')])
#
# 17684544 rs2066845 gwas_central
# GWC: set([u"Crohn's disease"])
# US:  set([('IBD Disease', '')])
#
# 17684544 rs1992660 gwas_central
# GWC: set([u"Crohn's disease"])
# US:  set([('IBD Disease', '')])
#
# 17684544 rs1992662 gwas_central
# GWC: set([u"Crohn's disease"])
# US:  set([('IBD Disease', '')])
#
# 17684544 rs11209026 gwas_central
# GWC: set([u"Crohn's disease"])
# US:  set([('IBD Disease', '')])
#
# 17684544 rs10484545 gwas_central
# GWC: set([u"Crohn's disease"])
# US:  set([('IBD Disease', '')])
#
# 17684544 rs1793004 gwas_central
# GWC: set([u"Crohn's disease"])
# US:  set([('IBD Disease', '')])
#
# 17684544 rs2241880 gwas_central
# GWC: set([u"Crohn's disease"])
# US:  set([('IBD Disease', '')])
#
# 17684544 rs1553575 gwas_central
# GWC: set([u"Crohn's disease"])
# US:  set([('IBD Disease', '')])
#
# 17684544 rs10513059 gwas_central
# GWC: set([u"Crohn's disease"])
# US:  None
#
# 17684544 rs200354 gwas_central
# GWC: set([u"Crohn's disease"])
# US:  None
#
# 17684544 rs7725052 gwas_central
# GWC: set([u"Crohn's disease"])
# US:  None
#
# 17684544 rs2009530 gwas_central
# GWC: set([u"Crohn's disease"])
# US:  None
#
# 17684544 rs10484543 gwas_central
# GWC: set([u"Crohn's disease"])
# US:  None
#
# ---
# 17903292 rs1712790 gwas_central
# GWC: set([u'Urinary albumin excretion'])
# US:  set([('endocrine-related traits', 'urinary albumin excretion')])
#
# 17903292 rs1243400 gwas_central
# GWC: set([u'Urinary albumin excretion'])
# US:  set([('endocrine-related traits', 'urinary albumin excretion')])
#
# 17903292 rs9305354 gwas_central
# GWC: set([u'Urinary albumin excretion'])
# US:  set([('endocrine-related traits', 'urinary albumin excretion')])
#
# 17903292 rs6977660 gwas_central
# GWC: set([u'Thyroid stimulating hormone'])
# US:  set([('endocrine-related traits', 'thyroid stimulating hormone')])
#
# 17903292 rs9322817 gwas_central
# GWC: set([u'Thyroid stimulating hormone'])
# US:  set([('endocrine-related traits', 'thyroid stimulating hormone')])
#
# 17903292 rs10499559 gwas_central
# GWC: set([u'Thyroid stimulating hormone'])
# US:  set([('endocrine-related traits', 'thyroid stimulating hormone')])
#
# 17903292 rs1158167 gwas_central
# GWC: set([u'Cystatin C'])
# US:  set([('endocrine-related traits', 'cystatin-c')])
#
# 17903292 rs1712790 gwas_central
# GWC: set([u'Urinary albumin excretion'])
# US:  set([('endocrine-related traits', 'urinary albumin excretion')])
#
# 17903292 rs1243400 gwas_central
# GWC: set([u'Urinary albumin excretion'])
# US:  set([('endocrine-related traits', 'urinary albumin excretion')])
#
# 17903292 rs9305354 gwas_central
# GWC: set([u'Urinary albumin excretion'])
# US:  set([('endocrine-related traits', 'urinary albumin excretion')])
#
# 17903292 rs6977660 gwas_central
# GWC: set([u'Thyroid stimulating hormone'])
# US:  set([('endocrine-related traits', 'thyroid stimulating hormone')])
#
# 17903292 rs9322817 gwas_central
# GWC: set([u'Thyroid stimulating hormone'])
# US:  set([('endocrine-related traits', 'thyroid stimulating hormone')])
#
# 17903292 rs10499559 gwas_central
# GWC: set([u'Thyroid stimulating hormone'])
# US:  set([('endocrine-related traits', 'thyroid stimulating hormone')])
#
# 17903292 rs1158167 gwas_central
# GWC: set([u'Cystatin C'])
# US:  set([('endocrine-related traits', 'cystatin-c')])
#
# 17903292 rs723464 set([('endocrine-related traits', 'urinary albumin excretion')])
# 17903292 rs10485409 set([('endocrine-related traits', 'urinary albumin excretion')])
# ---
# 17903293 rs1417352 gwas_central
# GWC: set([u'N-terminal pro-atrial natriuretic peptide'])
# US:  set([('biomarker traits', 'Atrial natriuretic peptide exam 6')])
#
# 17903293 rs1486139 gwas_central
# GWC: set([u'N-terminal pro-atrial natriuretic peptide'])
# US:  set([('biomarker traits', 'Atrial natriuretic peptide exam 6')])
#
# 17903293 rs1486140 gwas_central
# GWC: set([u'N-terminal pro-atrial natriuretic peptide'])
# US:  set([('biomarker traits', 'Atrial natriuretic peptide exam 6')])
#
# 17903293 rs1079596 gwas_central
# GWC: set([u'N-terminal pro-atrial natriuretic peptide'])
# US:  set([('biomarker traits', 'Atrial natriuretic peptide exam 6')])
#
# 17903293 rs1376544 gwas_central
# GWC: set([u'Vitamin D, Vitamin K phylloquinone, Vitamin K % undercaboxylated osteocalcin'])
# US:  set([('biomarker traits', 'Vitamin D, Vitamin K phylloquinone & Vitamin K % undercarboxylated osteocalcin')])
#
# 17903293 rs2494250 gwas_central
# GWC: set([u'Monocyte chemoattractant protein-1'])
# US:  set([('biomarker traits', 'Monocyte chemoattractant protein-1')])
#
# 17903293 rs4128725 gwas_central
# GWC: set([u'Monocyte chemoattractant protein-1'])
# US:  set([('biomarker traits', 'Monocyte chemoattractant protein-1')])
#
# 17903293 rs10489849 gwas_central
# GWC: set([u'Monocyte chemoattractant protein-1'])
# US:  set([('biomarker traits', 'Monocyte chemoattractant protein-1')])
#
# 17903293 rs1474747 gwas_central
# GWC: set([u'Monocyte chemoattractant protein-1'])
# US:  set([('biomarker traits', 'Monocyte chemoattractant protein-1')])
#
# 17903293 rs7778619 gwas_central
# GWC: set([u'Serum CD40 ligand'])
# US:  set([('biomarker traits', 'CD40 Ligand serum')])
#
# 17903293 rs8005745 gwas_central
# GWC: set([u'Serum CD40 ligand'])
# US:  set([('biomarker traits', 'CD40 Ligand serum')])
#
# 17903293 rs4664604 gwas_central
# GWC: set([u'Serum CD40 ligand'])
# US:  set([('biomarker traits', 'CD40 Ligand serum')])
#
# 17903293 rs9288125 gwas_central
# GWC: set([u'Serum CD40 ligand'])
# US:  set([('biomarker traits', 'CD40 Ligand serum')])
#
# 17903293 rs3849944 gwas_central
# GWC: set([u'Intracellular adhesion molecule-1'])
# US:  set([('biomarker traits', 'Intercellular adhesion molecule-1')])
#
# 17903293 rs2372184 gwas_central
# GWC: set([u'Plasma CD40 ligand'])
# US:  set([('biomarker traits', 'CD40 Ligand plasma')])
#
# 17903293 rs2387326 gwas_central
# GWC: set([u'Plasma vitamin K'])
# US:  set([('biomarker traits', 'Vitamin K plasma phylloquinone')])
#
# 17903293 rs7552393 gwas_central
# GWC: set([u'Tumor necrosis factor alpha'])
# US:  set([('biomarker traits', 'Tumor necrosis factor alpha')])
#
# 17903293 rs4911146 gwas_central
# GWC: set([u'Liver function test: alkaline phosphatase, AST, ALT, GGT'])
# US:  set([('biomarker traits', 'Liver function: Alkaline phosphatase; AST; ALT; gamma-glutamyl transferase')])
#
# 17903293 rs953402 gwas_central
# GWC: set([u'Liver function test: alkaline phosphatase, AST, ALT, GGT'])
# US:  set([('biomarker traits', 'Liver function: Alkaline phosphatase; AST; ALT; gamma-glutamyl transferase')])
#
# 17903293 rs1594468 gwas_central
# GWC: set([u'Bilirubin'])
# US:  None
#
# 17903293 rs496269 gwas_central
# GWC: set([u'Osteoprotegerin'])
# US:  set([('biomarker traits', 'Osteoprotegerin')])
#
# 17903293 rs1998303 gwas_central
# GWC: set([u'Alanine aminotransferase'])
# US:  set([('biomarker traits', 'Alanine aminotransferase')])
#
# 17903293 rs10492681 gwas_central
# GWC: set([u'Alanine aminotransferase'])
# US:  set([('biomarker traits', 'Alanine aminotransferase exam 2')])
#
# 17903293 rs2052028 gwas_central
# GWC: set([u'Vitamin K % undercarboxylated osteocalcin'])
# US:  set([('biomarker traits', 'Vitamin K % undercarboxylated osteocalcin')])
#
# 17903293 rs437021 gwas_central
# GWC: set([u'B-type natriuretic peptide'])
# US:  set([('biomarker traits', 'B-type natriuretic peptide')])
#
# 17903293 rs10518765 gwas_central
# GWC: set([u'Alkaline phosphatase'])
# US:  set([('biomarker traits', 'Alkaline phosphatase')])
#
# 17903293 rs2794520 gwas_central
# GWC: set([u'C-reactive protein'])
# US:  set([('biomarker traits', 'C-reactive protein average exams 2,6,7'), ('biomarker traits', 'C-reactive protein exam 6')])
#
# 17903293 rs2808629 gwas_central
# GWC: set([u'C-reactive protein'])
# US:  set([('biomarker traits', 'C-reactive protein average exams 2,6,7'), ('biomarker traits', 'C-reactive protein exam 6')])
#
# 17903293 rs746961 gwas_central
# GWC: set([u'C-reactive protein'])
# US:  set([('biomarker traits', 'C-reactive protein exam 6')])
#
# 17903293 rs465384 gwas_central
# GWC: set([u'C-reactive protein'])
# US:  None
#
# 17903293 rs583012 gwas_central
# GWC: set([u'C-reactive protein'])
# US:  set([('biomarker traits', 'C-reactive protein exam 2')])
#
# 17903293 rs1363258 gwas_central
# GWC: set([u'C-reactive protein'])
# US:  set([('biomarker traits', 'C-reactive protein exam 7')])
#
# 17903293 rs717145 gwas_central
# GWC: set([u'Urinary isoprostanes/creatinine'])
# US:  set([('biomarker traits', 'Urinary isoprostanes/creatinine')])
#
# 17903293 rs10485165 gwas_central
# GWC: set([u'Plasma vitamin D'])
# US:  set([('biomarker traits', 'Vitamin D plasma 25(OH)-D')])
#
# 17903293 rs10507577 gwas_central
# GWC: set([u'Plasma vitamin D'])
# US:  set([('biomarker traits', 'Vitamin D plasma 25(OH)-D')])
#
# 17903293 rs1417352 gwas_central
# GWC: set([u'N-terminal pro-atrial natriuretic peptide'])
# US:  set([('biomarker traits', 'Atrial natriuretic peptide exam 6')])
#
# 17903293 rs1486139 gwas_central
# GWC: set([u'N-terminal pro-atrial natriuretic peptide'])
# US:  set([('biomarker traits', 'Atrial natriuretic peptide exam 6')])
#
# 17903293 rs1486140 gwas_central
# GWC: set([u'N-terminal pro-atrial natriuretic peptide'])
# US:  set([('biomarker traits', 'Atrial natriuretic peptide exam 6')])
#
# 17903293 rs1079596 gwas_central
# GWC: set([u'N-terminal pro-atrial natriuretic peptide'])
# US:  set([('biomarker traits', 'Atrial natriuretic peptide exam 6')])
#
# 17903293 rs1376544 gwas_central
# GWC: set([u'Vitamin D, Vitamin K phylloquinone, Vitamin K % undercaboxylated osteocalcin'])
# US:  set([('biomarker traits', 'Vitamin D, Vitamin K phylloquinone & Vitamin K % undercarboxylated osteocalcin')])
#
# 17903293 rs2494250 gwas_central
# GWC: set([u'Monocyte chemoattractant protein-1'])
# US:  set([('biomarker traits', 'Monocyte chemoattractant protein-1')])
#
# 17903293 rs4128725 gwas_central
# GWC: set([u'Monocyte chemoattractant protein-1'])
# US:  set([('biomarker traits', 'Monocyte chemoattractant protein-1')])
#
# 17903293 rs10489849 gwas_central
# GWC: set([u'Monocyte chemoattractant protein-1'])
# US:  set([('biomarker traits', 'Monocyte chemoattractant protein-1')])
#
# 17903293 rs1474747 gwas_central
# GWC: set([u'Monocyte chemoattractant protein-1'])
# US:  set([('biomarker traits', 'Monocyte chemoattractant protein-1')])
#
# 17903293 rs7778619 gwas_central
# GWC: set([u'Serum CD40 ligand'])
# US:  set([('biomarker traits', 'CD40 Ligand serum')])
#
# 17903293 rs8005745 gwas_central
# GWC: set([u'Serum CD40 ligand'])
# US:  set([('biomarker traits', 'CD40 Ligand serum')])
#
# 17903293 rs4664604 gwas_central
# GWC: set([u'Serum CD40 ligand'])
# US:  set([('biomarker traits', 'CD40 Ligand serum')])
#
# 17903293 rs9288125 gwas_central
# GWC: set([u'Serum CD40 ligand'])
# US:  set([('biomarker traits', 'CD40 Ligand serum')])
#
# 17903293 rs3849944 gwas_central
# GWC: set([u'Intracellular adhesion molecule-1'])
# US:  set([('biomarker traits', 'Intercellular adhesion molecule-1')])
#
# 17903293 rs2372184 gwas_central
# GWC: set([u'Plasma CD40 ligand'])
# US:  set([('biomarker traits', 'CD40 Ligand plasma')])
#
# 17903293 rs2387326 gwas_central
# GWC: set([u'Plasma vitamin K'])
# US:  set([('biomarker traits', 'Vitamin K plasma phylloquinone')])
#
# 17903293 rs7552393 gwas_central
# GWC: set([u'Tumor necrosis factor alpha'])
# US:  set([('biomarker traits', 'Tumor necrosis factor alpha')])
#
# 17903293 rs4911146 gwas_central
# GWC: set([u'Liver function test: alkaline phosphatase, AST, ALT, GGT'])
# US:  set([('biomarker traits', 'Liver function: Alkaline phosphatase; AST; ALT; gamma-glutamyl transferase')])
#
# 17903293 rs953402 gwas_central
# GWC: set([u'Liver function test: alkaline phosphatase, AST, ALT, GGT'])
# US:  set([('biomarker traits', 'Liver function: Alkaline phosphatase; AST; ALT; gamma-glutamyl transferase')])
#
# 17903293 rs1594468 gwas_central
# GWC: set([u'Bilirubin'])
# US:  None
#
# 17903293 rs496269 gwas_central
# GWC: set([u'Osteoprotegerin'])
# US:  set([('biomarker traits', 'Osteoprotegerin')])
#
# 17903293 rs1998303 gwas_central
# GWC: set([u'Alanine aminotransferase'])
# US:  set([('biomarker traits', 'Alanine aminotransferase')])
#
# 17903293 rs10492681 gwas_central
# GWC: set([u'Alanine aminotransferase'])
# US:  set([('biomarker traits', 'Alanine aminotransferase exam 2')])
#
# 17903293 rs2052028 gwas_central
# GWC: set([u'Vitamin K % undercarboxylated osteocalcin'])
# US:  set([('biomarker traits', 'Vitamin K % undercarboxylated osteocalcin')])
#
# 17903293 rs437021 gwas_central
# GWC: set([u'B-type natriuretic peptide'])
# US:  set([('biomarker traits', 'B-type natriuretic peptide')])
#
# 17903293 rs10518765 gwas_central
# GWC: set([u'Alkaline phosphatase'])
# US:  set([('biomarker traits', 'Alkaline phosphatase')])
#
# 17903293 rs2794520 gwas_central
# GWC: set([u'C-reactive protein'])
# US:  set([('biomarker traits', 'C-reactive protein average exams 2,6,7'), ('biomarker traits', 'C-reactive protein exam 6')])
#
# 17903293 rs2808629 gwas_central
# GWC: set([u'C-reactive protein'])
# US:  set([('biomarker traits', 'C-reactive protein average exams 2,6,7'), ('biomarker traits', 'C-reactive protein exam 6')])
#
# 17903293 rs746961 gwas_central
# GWC: set([u'C-reactive protein'])
# US:  set([('biomarker traits', 'C-reactive protein exam 6')])
#
# 17903293 rs465384 gwas_central
# GWC: set([u'C-reactive protein'])
# US:  None
#
# 17903293 rs583012 gwas_central
# GWC: set([u'C-reactive protein'])
# US:  set([('biomarker traits', 'C-reactive protein exam 2')])
#
# 17903293 rs1363258 gwas_central
# GWC: set([u'C-reactive protein'])
# US:  set([('biomarker traits', 'C-reactive protein exam 7')])
#
# 17903293 rs717145 gwas_central
# GWC: set([u'Urinary isoprostanes/creatinine'])
# US:  set([('biomarker traits', 'Urinary isoprostanes/creatinine')])
#
# 17903293 rs10485165 gwas_central
# GWC: set([u'Plasma vitamin D'])
# US:  set([('biomarker traits', 'Vitamin D plasma 25(OH)-D')])
#
# 17903293 rs10507577 gwas_central
# GWC: set([u'Plasma vitamin D'])
# US:  set([('biomarker traits', 'Vitamin D plasma 25(OH)-D')])
#
# 17903293 rs17532515 set([('biomarker traits', 'Bilirubin')])
# 17903293 rs1119582 set([('biomarker traits', 'C-reactive protein average exams 2,6,7')])
# ---
# 17903294 rs7159841 gwas_central
# GWC: set([u'Viscosity'])
# US:  set([('hematological phenotypes', 'Viscosity')])
#
# 17903294 rs1397048 gwas_central
# GWC: set([u'Mean corpuscular hemoglobin'])
# US:  set([('hematological phenotypes', 'mean corpuscular hemoglobin')])
#
# 17903294 rs2412522 gwas_central
# GWC: set([u'Mean corpuscular hemoglobin'])
# US:  None
#
# 17903294 rs1829883 gwas_central
# GWC: set([u'Mean corpuscular hemoglobin'])
# US:  set([('hematological phenotypes', 'mean corpuscular hemoglobin')])
#
# 17903294 rs1200821 gwas_central
# GWC: set([u'Mean corpuscular hemoglobin'])
# US:  set([('hematological phenotypes', 'mean corpuscular hemoglobin')])
#
# 17903294 rs9253 gwas_central
# GWC: set([u'Red blood cell count'])
# US:  set([('hematological phenotypes', 'red blood cell count')])
#
# 17903294 rs10489087 gwas_central
# GWC: set([u'Red blood cell count'])
# US:  set([('hematological phenotypes', 'red blood cell count')])
#
# 17903294 rs6108011 gwas_central
# GWC: set([u'Red blood cell count'])
# US:  set([('hematological phenotypes', 'red blood cell count')])
#
# 17903294 rs636864 gwas_central
# GWC: set([u'Red blood cell count'])
# US:  set([('hematological phenotypes', 'red blood cell count')])
#
# 17903294 rs727979 gwas_central
# GWC: set([u'Red blood cell count'])
# US:  set([('hematological phenotypes', 'red blood cell count')])
#
# 17903294 rs6046 gwas_central
# GWC: set([u'Factor VII'])
# US:  None
#
# 17903294 rs561241 gwas_central
# GWC: set([u'Factor VII'])
# US:  set([('hematological phenotypes', 'FVII, exam 5'), ('hematological phenotypes', 'factor vii')])
#
# 17903294 rs10488360 gwas_central
# GWC: set([u'Factor VII'])
# US:  set([('hematological phenotypes', 'factor vii')])
#
# 17903294 rs966321 gwas_central
# GWC: set([u'Factor VII'])
# US:  set([('hematological phenotypes', 'factor vii')])
#
# 17903294 rs727435 gwas_central
# GWC: set([u'Factor VII'])
# US:  set([('hematological phenotypes', 'factor vii')])
#
# 17903294 rs565229 gwas_central
# GWC: set([u'Collagen-induced platelet aggregation'])
# US:  set([('hematological phenotypes', 'platelet aggregation (collagen-induced)')])
#
# 17903294 rs10506458 gwas_central
# GWC: set([u'Collagen-induced platelet aggregation'])
# US:  set([('hematological phenotypes', 'platelet aggregation (collagen-induced)')])
#
# 17903294 rs10493485 gwas_central
# GWC: set([u'Tissue plasminogen activator'])
# US:  set([('hematological phenotypes', 'tissue plasminogen activator')])
#
# 17903294 rs10484128 gwas_central
# GWC: set([u'ADP-induced platelet aggregation'])
# US:  set([('hematological phenotypes', 'platelet aggregation (ADP-induced)')])
#
# 17903294 rs1160297 gwas_central
# GWC: set([u'Hemoglobin'])
# US:  set([('hematological phenotypes', 'hemoglobin')])
#
# 17903294 rs7844723 gwas_central
# GWC: set([u'Hemoglobin'])
# US:  set([('hematological phenotypes', 'hemoglobin')])
#
# 17903294 rs7159841 gwas_central
# GWC: set([u'Viscosity'])
# US:  set([('hematological phenotypes', 'Viscosity')])
#
# 17903294 rs1397048 gwas_central
# GWC: set([u'Mean corpuscular hemoglobin'])
# US:  set([('hematological phenotypes', 'mean corpuscular hemoglobin')])
#
# 17903294 rs2412522 gwas_central
# GWC: set([u'Mean corpuscular hemoglobin'])
# US:  None
#
# 17903294 rs1829883 gwas_central
# GWC: set([u'Mean corpuscular hemoglobin'])
# US:  set([('hematological phenotypes', 'mean corpuscular hemoglobin')])
#
# 17903294 rs1200821 gwas_central
# GWC: set([u'Mean corpuscular hemoglobin'])
# US:  set([('hematological phenotypes', 'mean corpuscular hemoglobin')])
#
# 17903294 rs9253 gwas_central
# GWC: set([u'Red blood cell count'])
# US:  set([('hematological phenotypes', 'red blood cell count')])
#
# 17903294 rs10489087 gwas_central
# GWC: set([u'Red blood cell count'])
# US:  set([('hematological phenotypes', 'red blood cell count')])
#
# 17903294 rs6108011 gwas_central
# GWC: set([u'Red blood cell count'])
# US:  set([('hematological phenotypes', 'red blood cell count')])
#
# 17903294 rs636864 gwas_central
# GWC: set([u'Red blood cell count'])
# US:  set([('hematological phenotypes', 'red blood cell count')])
#
# 17903294 rs727979 gwas_central
# GWC: set([u'Red blood cell count'])
# US:  set([('hematological phenotypes', 'red blood cell count')])
#
# 17903294 rs6046 gwas_central
# GWC: set([u'Factor VII'])
# US:  None
#
# 17903294 rs561241 gwas_central
# GWC: set([u'Factor VII'])
# US:  set([('hematological phenotypes', 'FVII, exam 5'), ('hematological phenotypes', 'factor vii')])
#
# 17903294 rs10488360 gwas_central
# GWC: set([u'Factor VII'])
# US:  set([('hematological phenotypes', 'factor vii')])
#
# 17903294 rs966321 gwas_central
# GWC: set([u'Factor VII'])
# US:  set([('hematological phenotypes', 'factor vii')])
#
# 17903294 rs727435 gwas_central
# GWC: set([u'Factor VII'])
# US:  set([('hematological phenotypes', 'factor vii')])
#
# 17903294 rs565229 gwas_central
# GWC: set([u'Collagen-induced platelet aggregation'])
# US:  set([('hematological phenotypes', 'platelet aggregation (collagen-induced)')])
#
# 17903294 rs10506458 gwas_central
# GWC: set([u'Collagen-induced platelet aggregation'])
# US:  set([('hematological phenotypes', 'platelet aggregation (collagen-induced)')])
#
# 17903294 rs10493485 gwas_central
# GWC: set([u'Tissue plasminogen activator'])
# US:  set([('hematological phenotypes', 'tissue plasminogen activator')])
#
# 17903294 rs10484128 gwas_central
# GWC: set([u'ADP-induced platelet aggregation'])
# US:  set([('hematological phenotypes', 'platelet aggregation (ADP-induced)')])
#
# 17903294 rs1160297 gwas_central
# GWC: set([u'Hemoglobin'])
# US:  set([('hematological phenotypes', 'hemoglobin')])
#
# 17903294 rs7844723 gwas_central
# GWC: set([u'Hemoglobin'])
# US:  set([('hematological phenotypes', 'hemoglobin')])
#
# 17903294 rs1954971 set([('hematological phenotypes', 'von willebrand factor')])
# 17903294 rs4133289 set([('hematological phenotypes', 'hemoglobin')])
# 17903294 rs2357013 set([('hematological phenotypes', 'hemoglobin')])
# 17903294 rs4591494 set([('hematological phenotypes', 'factor vii')])
# 17903294 rs4460176 set([('hematological phenotypes', 'PAI1')])
# 17903294 rs1510107 set([('hematological phenotypes', 'hemoglobin')])
# ---
# 17903295 rs10496265 gwas_central
# GWC: set([u'Age at natural menopause'])
# US:  set([('longevity|age-related phenotypes', 'Age at natural menopause\xe2\x80\xa1')])
#
# 17903295 rs10496262 gwas_central
# GWC: set([u'Age at natural menopause'])
# US:  set([('longevity|age-related phenotypes', 'Age at natural menopause\xe2\x80\xa1')])
#
# 17903295 rs958672 gwas_central
# GWC: set([u'Age at natural menopause'])
# US:  set([('longevity|age-related phenotypes', 'Age at natural menopause\xe2\x80\xa1')])
#
# 17903295 rs291353 gwas_central
# GWC: set([u'Age at natural menopause'])
# US:  set([('longevity|age-related phenotypes', 'Age at natural menopause\xe2\x80\xa1')])
#
# 17903295 rs1412337 gwas_central
# GWC: set([u'Morbidity-free survival at age 65'])
# US:  set([('longevity|age-related phenotypes', 'Morbidity-free survival at age 65')])
#
# 17903295 rs32566 gwas_central
# GWC: set([u'Morbidity-free survival at age 65'])
# US:  set([('longevity|age-related phenotypes', 'Morbidity-free survival at age 65')])
#
# 17903295 rs10484246 gwas_central
# GWC: set([u'Morbidity-free survival at age 65'])
# US:  set([('longevity|age-related phenotypes', 'Morbidity-free survival at age 65')])
#
# 17903295 rs4831837 gwas_central
# GWC: set([u'Morbidity-free survival at age 65'])
# US:  set([('longevity|age-related phenotypes', 'Morbidity-free survival at age 65')])
#
# 17903295 rs2639889 gwas_central
# GWC: set([u'Morbidity-free survival at age 65'])
# US:  set([('longevity|age-related phenotypes', 'Morbidity-free survival at age 65')])
#
# 17903295 rs1463605 gwas_central
# GWC: set([u'Biologic age by osseographic scoring system'])
# US:  set([('longevity|age-related phenotypes', 'Biologic age by osseographic scoring system')])
#
# 17903295 rs7176093 gwas_central
# GWC: set([u'Biologic age by osseographic scoring system'])
# US:  set([('longevity|age-related phenotypes', 'Biologic age by osseographic scoring system')])
#
# 17903295 rs3772255 gwas_central
# GWC: set([u'Biologic age by osseographic scoring system'])
# US:  set([('longevity|age-related phenotypes', 'Biologic age by osseographic scoring system')])
#
# 17903295 rs1528753 gwas_central
# GWC: set([u'Age at death'])
# US:  set([('longevity|age-related phenotypes', 'Age at death')])
#
# 17903295 rs10493513 gwas_central
# GWC: set([u'Age at death'])
# US:  set([('longevity|age-related phenotypes', 'Age at death')])
#
# 17903295 rs2371208 gwas_central
# GWC: set([u'Age at death'])
# US:  set([('longevity|age-related phenotypes', 'Age at death')])
#
# 17903295 rs10493514 gwas_central
# GWC: set([u'Age at death'])
# US:  set([('longevity|age-related phenotypes', 'Age at death')])
#
# 17903295 rs2543600 gwas_central
# GWC: set([u'Age at death'])
# US:  set([('longevity|age-related phenotypes', 'Age at death')])
#
# 17903295 rs7137869 gwas_central
# GWC: set([u'Walking speed at advanced age'])
# US:  set([('longevity|age-related phenotypes', 'Walking speed exam 7')])
#
# 17903295 rs4471448 gwas_central
# GWC: set([u'Walking speed at advanced age'])
# US:  set([('longevity|age-related phenotypes', 'Walking speed exam 7')])
#
# 17903295 rs10496265 gwas_central
# GWC: set([u'Age at natural menopause'])
# US:  set([('longevity|age-related phenotypes', 'Age at natural menopause\xe2\x80\xa1')])
#
# 17903295 rs10496262 gwas_central
# GWC: set([u'Age at natural menopause'])
# US:  set([('longevity|age-related phenotypes', 'Age at natural menopause\xe2\x80\xa1')])
#
# 17903295 rs958672 gwas_central
# GWC: set([u'Age at natural menopause'])
# US:  set([('longevity|age-related phenotypes', 'Age at natural menopause\xe2\x80\xa1')])
#
# 17903295 rs291353 gwas_central
# GWC: set([u'Age at natural menopause'])
# US:  set([('longevity|age-related phenotypes', 'Age at natural menopause\xe2\x80\xa1')])
#
# 17903295 rs1412337 gwas_central
# GWC: set([u'Morbidity-free survival at age 65'])
# US:  set([('longevity|age-related phenotypes', 'Morbidity-free survival at age 65')])
#
# 17903295 rs32566 gwas_central
# GWC: set([u'Morbidity-free survival at age 65'])
# US:  set([('longevity|age-related phenotypes', 'Morbidity-free survival at age 65')])
#
# 17903295 rs10484246 gwas_central
# GWC: set([u'Morbidity-free survival at age 65'])
# US:  set([('longevity|age-related phenotypes', 'Morbidity-free survival at age 65')])
#
# 17903295 rs4831837 gwas_central
# GWC: set([u'Morbidity-free survival at age 65'])
# US:  set([('longevity|age-related phenotypes', 'Morbidity-free survival at age 65')])
#
# 17903295 rs2639889 gwas_central
# GWC: set([u'Morbidity-free survival at age 65'])
# US:  set([('longevity|age-related phenotypes', 'Morbidity-free survival at age 65')])
#
# 17903295 rs1463605 gwas_central
# GWC: set([u'Biologic age by osseographic scoring system'])
# US:  set([('longevity|age-related phenotypes', 'Biologic age by osseographic scoring system')])
#
# 17903295 rs7176093 gwas_central
# GWC: set([u'Biologic age by osseographic scoring system'])
# US:  set([('longevity|age-related phenotypes', 'Biologic age by osseographic scoring system')])
#
# 17903295 rs3772255 gwas_central
# GWC: set([u'Biologic age by osseographic scoring system'])
# US:  set([('longevity|age-related phenotypes', 'Biologic age by osseographic scoring system')])
#
# 17903295 rs1528753 gwas_central
# GWC: set([u'Age at death'])
# US:  set([('longevity|age-related phenotypes', 'Age at death')])
#
# 17903295 rs10493513 gwas_central
# GWC: set([u'Age at death'])
# US:  set([('longevity|age-related phenotypes', 'Age at death')])
#
# 17903295 rs2371208 gwas_central
# GWC: set([u'Age at death'])
# US:  set([('longevity|age-related phenotypes', 'Age at death')])
#
# 17903295 rs10493514 gwas_central
# GWC: set([u'Age at death'])
# US:  set([('longevity|age-related phenotypes', 'Age at death')])
#
# 17903295 rs2543600 gwas_central
# GWC: set([u'Age at death'])
# US:  set([('longevity|age-related phenotypes', 'Age at death')])
#
# 17903295 rs7137869 gwas_central
# GWC: set([u'Walking speed at advanced age'])
# US:  set([('longevity|age-related phenotypes', 'Walking speed exam 7')])
#
# 17903295 rs4471448 gwas_central
# GWC: set([u'Walking speed at advanced age'])
# US:  set([('longevity|age-related phenotypes', 'Walking speed exam 7')])
#
# ---
# 17903296 rs10506821 gwas_central
# GWC: set([u'Hip geometry, shaft width, gender differentiated in females'])
# US:  set([('tests', 'shaft width**')])
#
# 17903296 rs1452928 gwas_central
# GWC: set([u'Hip geometry, shaft width, gender differentiated in females'])
# US:  set([('tests', 'shaft width**')])
#
# 17903296 rs922948 gwas_central
# GWC: set([u'Hip geometry, shaft width, gender differentiated in females'])
# US:  set([('tests', 'shaft width**')])
#
# 17903296 rs10492096 gwas_central
# GWC: set([u'Hip geometry, shaft section modulus, gender differentiated in females'])
# US:  set([('tests', 'shaft section modulus**')])
#
# 17903296 rs9287234 gwas_central
# GWC: set([u'Hip geometry, shaft section modulus, gender differentiated in females'])
# US:  set([('tests', 'shaft section modulus**')])
#
# 17903296 rs1590305 gwas_central
# GWC: set([u'Hip geometry, neck section modulus, gender differentiated in males'])
# US:  set([('tests', 'neck section modulus**')])
#
# 17903296 rs7857590 gwas_central
# GWC: set([u'Hip geometry, neck section modulus, gender differentiated in males'])
# US:  set([('tests', 'neck section modulus**')])
#
# 17903296 rs10503887 gwas_central
# GWC: set([u'Hip geometry, shaft section modulus'])
# US:  set([('tests', 'shaft section modulus**')])
#
# 17903296 rs432446 gwas_central
# GWC: set([u'Hip geometery, neck shaft angle'])
# US:  set([('tests', 'neck-shaft angle**')])
#
# 17903296 rs1552896 gwas_central
# GWC: set([u'Hip geometery, neck shaft angle'])
# US:  set([('tests', 'neck-shaft angle**')])
#
# 17903296 rs2165468 gwas_central
# GWC: set([u'Femoral neck bone mineral density'])
# US:  set([('tests', 'femoral bmd**')])
#
# 17903296 rs1538173 gwas_central
# GWC: set([u'Femoral neck bone mineral density'])
# US:  set([('tests', 'femoral bmd**')])
#
# 17903296 rs4087296 gwas_central
# GWC: set([u'Trochanter bone mineral density, gender differentiated in females'])
# US:  set([('tests', 'trochanter bmd**')])
#
# 17903296 rs4811196 gwas_central
# GWC: set([u'Trochanter bone mineral density, gender differentiated in females'])
# US:  set([('tests', 'trochanter bmd**')])
#
# 17903296 rs9291683 gwas_central
# GWC: set([u'Quantitative broadband ultrasound attentuation of the calcaneus'])
# US:  set([('tests', 'broadband ultrasound attenuation**')])
#
# 17903296 rs2214681 gwas_central
# GWC: set([u'Quantitative broadband ultrasound attentuation of the calcaneus'])
# US:  set([('tests', 'broadband ultrasound attenuation**')])
#
# 17903296 rs10486661 gwas_central
# GWC: set([u'Combined bone mineral density phenotypes, femoral neck bone mineral density, trochanater bone mineral density, lumbar spine bone mineral density, gender differentiated in females'])
# US:  None
#
# 17903296 rs10514345 gwas_central
# GWC: set([u'Hip geometry, neck section modulus'])
# US:  set([('tests', 'lumbar spine bmd**')])
#
# 17903296 rs2053506 gwas_central
# GWC: set([u'Hip geometry, neck section modulus'])
# US:  set([('tests', 'NeckZ1')])
#
# 17903296 rs4131805 gwas_central
# GWC: set([u'Hip geometery, neck shaft angle, gender differentiated in males'])
# US:  set([('tests', 'neck-shaft angle**')])
#
# 17903296 rs3762397 gwas_central
# GWC: set([u'Trochanter bone mineral density'])
# US:  set([('tests', 'trochanter bmd**')])
#
# 17903296 rs10506701 gwas_central
# GWC: set([u'Trochanter bone mineral density'])
# US:  set([('tests', 'trochanter bmd**')])
#
# 17903296 rs914951 gwas_central
# GWC: set([u'Trochanter bone mineral density'])
# US:  set([('tests', 'trochanter bmd**')])
#
# 17903296 rs9317284 gwas_central
# GWC: set([u'Femoral neck bone mineral density, gender differentiated in males'])
# US:  set([('tests', 'femoral bmd**')])
#
# 17903296 rs10508076 gwas_central
# GWC: set([u'Femoral neck bone mineral density, gender differentiated in males'])
# US:  set([('tests', 'femoral bmd**')])
#
# 17903296 rs2054989 gwas_central
# GWC: set([u'Hip geometry, neck width, gender differentiated in females'])
# US:  set([('tests', 'neck width**')])
#
# 17903296 rs1395548 gwas_central
# GWC: set([u'Hip geometry, neck width, gender differentiated in females'])
# US:  set([('tests', 'neck width**')])
#
# 17903296 rs4715166 gwas_central
# GWC: set([u'Hip geometry, neck width, gender differentiated in females'])
# US:  set([('tests', 'neck width**')])
#
# 17903296 rs4143244 gwas_central
# GWC: set([u'Hip geometry, neck width'])
# US:  set([('tests', 'NeckW1')])
#
# 17903296 rs10510628 gwas_central
# GWC: set([u'Trochanter bone mineral density, gender differentiated in males'])
# US:  set([('tests', 'trochanter bmd**')])
#
# 17903296 rs2548003 gwas_central
# GWC: set([u'Hip geometry, neck section modulus, gender differentiated in females'])
# US:  set([('tests', 'neck section modulus**')])
#
# 17903296 rs6600671 gwas_central
# GWC: set([u'Hip geometry, neck section modulus, gender differentiated in females'])
# US:  set([('tests', 'neck section modulus**')])
#
# 17903296 rs10515148 gwas_central
# GWC: set([u'Hip geometry, neck section modulus, gender differentiated in females'])
# US:  set([('tests', 'neck section modulus**')])
#
# 17903296 rs638882 gwas_central
# GWC: set([u'Hip geometry, neck section modulus, gender differentiated in females'])
# US:  set([('tests', 'neck section modulus**')])
#
# 17903296 rs991258 gwas_central
# GWC: set([u'Hip geometry, shaft width'])
# US:  set([('tests', 'shaft width**')])
#
# 17903296 rs10506821 gwas_central
# GWC: set([u'Hip geometry, shaft width, gender differentiated in females'])
# US:  set([('tests', 'shaft width**')])
#
# 17903296 rs1452928 gwas_central
# GWC: set([u'Hip geometry, shaft width, gender differentiated in females'])
# US:  set([('tests', 'shaft width**')])
#
# 17903296 rs922948 gwas_central
# GWC: set([u'Hip geometry, shaft width, gender differentiated in females'])
# US:  set([('tests', 'shaft width**')])
#
# 17903296 rs10492096 gwas_central
# GWC: set([u'Hip geometry, shaft section modulus, gender differentiated in females'])
# US:  set([('tests', 'shaft section modulus**')])
#
# 17903296 rs9287234 gwas_central
# GWC: set([u'Hip geometry, shaft section modulus, gender differentiated in females'])
# US:  set([('tests', 'shaft section modulus**')])
#
# 17903296 rs1590305 gwas_central
# GWC: set([u'Hip geometry, neck section modulus, gender differentiated in males'])
# US:  set([('tests', 'neck section modulus**')])
#
# 17903296 rs7857590 gwas_central
# GWC: set([u'Hip geometry, neck section modulus, gender differentiated in males'])
# US:  set([('tests', 'neck section modulus**')])
#
# 17903296 rs10503887 gwas_central
# GWC: set([u'Hip geometry, shaft section modulus'])
# US:  set([('tests', 'shaft section modulus**')])
#
# 17903296 rs432446 gwas_central
# GWC: set([u'Hip geometery, neck shaft angle'])
# US:  set([('tests', 'neck-shaft angle**')])
#
# 17903296 rs1552896 gwas_central
# GWC: set([u'Hip geometery, neck shaft angle'])
# US:  set([('tests', 'neck-shaft angle**')])
#
# 17903296 rs2165468 gwas_central
# GWC: set([u'Femoral neck bone mineral density'])
# US:  set([('tests', 'femoral bmd**')])
#
# 17903296 rs1538173 gwas_central
# GWC: set([u'Femoral neck bone mineral density'])
# US:  set([('tests', 'femoral bmd**')])
#
# 17903296 rs4087296 gwas_central
# GWC: set([u'Trochanter bone mineral density, gender differentiated in females'])
# US:  set([('tests', 'trochanter bmd**')])
#
# 17903296 rs4811196 gwas_central
# GWC: set([u'Trochanter bone mineral density, gender differentiated in females'])
# US:  set([('tests', 'trochanter bmd**')])
#
# 17903296 rs9291683 gwas_central
# GWC: set([u'Quantitative broadband ultrasound attentuation of the calcaneus'])
# US:  set([('tests', 'broadband ultrasound attenuation**')])
#
# 17903296 rs2214681 gwas_central
# GWC: set([u'Quantitative broadband ultrasound attentuation of the calcaneus'])
# US:  set([('tests', 'broadband ultrasound attenuation**')])
#
# 17903296 rs10486661 gwas_central
# GWC: set([u'Combined bone mineral density phenotypes, femoral neck bone mineral density, trochanater bone mineral density, lumbar spine bone mineral density, gender differentiated in females'])
# US:  None
#
# 17903296 rs10514345 gwas_central
# GWC: set([u'Hip geometry, neck section modulus'])
# US:  set([('tests', 'lumbar spine bmd**')])
#
# 17903296 rs2053506 gwas_central
# GWC: set([u'Hip geometry, neck section modulus'])
# US:  set([('tests', 'NeckZ1')])
#
# 17903296 rs4131805 gwas_central
# GWC: set([u'Hip geometery, neck shaft angle, gender differentiated in males'])
# US:  set([('tests', 'neck-shaft angle**')])
#
# 17903296 rs3762397 gwas_central
# GWC: set([u'Trochanter bone mineral density'])
# US:  set([('tests', 'trochanter bmd**')])
#
# 17903296 rs10506701 gwas_central
# GWC: set([u'Trochanter bone mineral density'])
# US:  set([('tests', 'trochanter bmd**')])
#
# 17903296 rs914951 gwas_central
# GWC: set([u'Trochanter bone mineral density'])
# US:  set([('tests', 'trochanter bmd**')])
#
# 17903296 rs9317284 gwas_central
# GWC: set([u'Femoral neck bone mineral density, gender differentiated in males'])
# US:  set([('tests', 'femoral bmd**')])
#
# 17903296 rs10508076 gwas_central
# GWC: set([u'Femoral neck bone mineral density, gender differentiated in males'])
# US:  set([('tests', 'femoral bmd**')])
#
# 17903296 rs2054989 gwas_central
# GWC: set([u'Hip geometry, neck width, gender differentiated in females'])
# US:  set([('tests', 'neck width**')])
#
# 17903296 rs1395548 gwas_central
# GWC: set([u'Hip geometry, neck width, gender differentiated in females'])
# US:  set([('tests', 'neck width**')])
#
# 17903296 rs4715166 gwas_central
# GWC: set([u'Hip geometry, neck width, gender differentiated in females'])
# US:  set([('tests', 'neck width**')])
#
# 17903296 rs4143244 gwas_central
# GWC: set([u'Hip geometry, neck width'])
# US:  set([('tests', 'NeckW1')])
#
# 17903296 rs10510628 gwas_central
# GWC: set([u'Trochanter bone mineral density, gender differentiated in males'])
# US:  set([('tests', 'trochanter bmd**')])
#
# 17903296 rs2548003 gwas_central
# GWC: set([u'Hip geometry, neck section modulus, gender differentiated in females'])
# US:  set([('tests', 'neck section modulus**')])
#
# 17903296 rs6600671 gwas_central
# GWC: set([u'Hip geometry, neck section modulus, gender differentiated in females'])
# US:  set([('tests', 'neck section modulus**')])
#
# 17903296 rs10515148 gwas_central
# GWC: set([u'Hip geometry, neck section modulus, gender differentiated in females'])
# US:  set([('tests', 'neck section modulus**')])
#
# 17903296 rs638882 gwas_central
# GWC: set([u'Hip geometry, neck section modulus, gender differentiated in females'])
# US:  set([('tests', 'neck section modulus**')])
#
# 17903296 rs991258 gwas_central
# GWC: set([u'Hip geometry, shaft width'])
# US:  set([('tests', 'shaft width**')])
#
# ---
# 17903297 rs7124781 gwas_central
# GWC: set([u'Brain MRI, lateral ventricular volume'])
# US:  set([('brain|aging', 'ALLV')])
#
# 17903297 rs2847476 gwas_central
# GWC: set([u'Brain MRI, lateral ventricular volume'])
# US:  set([('brain|aging', 'ALLV')])
#
# 17903297 rs952700 gwas_central
# GWC: set([u'Brain MRI, frontal brain volume'])
# US:  set([('brain|aging', 'frontal brain volume')])
#
# 17903297 rs3852286 gwas_central
# GWC: set([u'Brain MRI, frontal brain volume'])
# US:  set([('brain|aging', 'frontal brain volume')])
#
# 17903297 rs5028798 gwas_central
# GWC: set([u'Brain MRI, temporal brain volume'])
# US:  set([('brain|aging', 'temporal brain volume')])
#
# 17903297 rs1155865 gwas_central
# GWC: set([u'Cognitive performance, Boston naming test'])
# US:  set([('brain|aging', 'boston naming test')])
#
# 17903297 rs530965 gwas_central
# GWC: set([u'Cognitive performance, Boston naming test'])
# US:  set([('brain|aging', 'boston naming test')])
#
# 17903297 rs9303401 gwas_central
# GWC: set([u'Cognitive performance, Boston naming test'])
# US:  set([('brain|aging', 'boston naming test')])
#
# 17903297 rs1831521 gwas_central
# GWC: set([u'Cognitive performance, Boston naming test'])
# US:  set([('brain|aging', 'boston naming test')])
#
# 17903297 rs3891355 gwas_central
# GWC: set([u'Cognitive performance, similarities'])
# US:  set([('brain|aging', 'similarities')])
#
# 17903297 rs1131497 gwas_central
# GWC: set([u'Cognitive performance, similarities'])
# US:  set([('brain|aging', 'similarities')])
#
# 17903297 rs360929 gwas_central
# GWC: set([u'Brain MRI, temporal horn volume'])
# US:  set([('brain|aging', 'ALTHBV')])
#
# 17903297 rs1970546 gwas_central
# GWC: set([u'Brain MRI, total cerebral brain volume'])
# US:  set([('brain|aging', 'total cerebral brain volume')])
#
# 17903297 rs502309 gwas_central
# GWC: set([u'Brain MRI, total cerebral brain volume'])
# US:  set([('brain|aging', 'total cerebral brain volume')])
#
# 17903297 rs2179965 gwas_central
# GWC: set([u'Cognitive performance, attention and executive function'])
# US:  set([('brain|aging', 'factor 3: measure of attention and executive function-trails a and b')])
#
# 17903297 rs2832077 gwas_central
# GWC: set([u'Cognitive performance, attention and executive function'])
# US:  set([('brain|aging', 'factor 3: measure of attention and executive function-trails a and b')])
#
# 17903297 rs1031381 gwas_central
# GWC: set([u'Cognitive performance, attention and executive function'])
# US:  set([('brain|aging', 'factor 3: measure of attention and executive function-trails a and b')])
#
# 17903297 rs934299 gwas_central
# GWC: set([u'Cognitive performance, attention and executive function'])
# US:  set([('brain|aging', 'factor 3: measure of attention and executive function-trails a and b')])
#
# 17903297 rs2352904 gwas_central
# GWC: set([u'Cognitive performance, visual memory and organization'])
# US:  set([('brain|aging', 'factor 2:visual memory and organization')])
#
# 17903297 rs6914079 gwas_central
# GWC: set([u'Cognitive performance, visual memory and organization'])
# US:  set([('brain|aging', 'factor 2:visual memory and organization')])
#
# 17903297 rs9325032 gwas_central
# GWC: set([u'Cognitive performance, visual memory and organization'])
# US:  set([('brain|aging', 'factor 2:visual memory and organization')])
#
# 17903297 rs10489896 gwas_central
# GWC: set([u'Cognitive performance, visual memory and organization'])
# US:  set([('brain|aging', 'factor 2:visual memory and organization')])
#
# 17903297 rs2893363 gwas_central
# GWC: set([u'Cognitive performance, visual memory and organization'])
# US:  set([('brain|aging', 'factor 2:visual memory and organization')])
#
# 17903297 rs10506065 gwas_central
# GWC: set([u'Cognitive performance, wide-range achievement test'])
# US:  set([('brain|aging', 'wide-range achievement test')])
#
# 17903297 rs9300212 gwas_central
# GWC: set([u'Cognitive performance, wide-range achievement test'])
# US:  set([('brain|aging', 'wide-range achievement test')])
#
# 17903297 rs7124781 gwas_central
# GWC: set([u'Brain MRI, lateral ventricular volume'])
# US:  set([('brain|aging', 'ALLV')])
#
# 17903297 rs2847476 gwas_central
# GWC: set([u'Brain MRI, lateral ventricular volume'])
# US:  set([('brain|aging', 'ALLV')])
#
# 17903297 rs952700 gwas_central
# GWC: set([u'Brain MRI, frontal brain volume'])
# US:  set([('brain|aging', 'frontal brain volume')])
#
# 17903297 rs3852286 gwas_central
# GWC: set([u'Brain MRI, frontal brain volume'])
# US:  set([('brain|aging', 'frontal brain volume')])
#
# 17903297 rs5028798 gwas_central
# GWC: set([u'Brain MRI, temporal brain volume'])
# US:  set([('brain|aging', 'temporal brain volume')])
#
# 17903297 rs1155865 gwas_central
# GWC: set([u'Cognitive performance, Boston naming test'])
# US:  set([('brain|aging', 'boston naming test')])
#
# 17903297 rs530965 gwas_central
# GWC: set([u'Cognitive performance, Boston naming test'])
# US:  set([('brain|aging', 'boston naming test')])
#
# 17903297 rs9303401 gwas_central
# GWC: set([u'Cognitive performance, Boston naming test'])
# US:  set([('brain|aging', 'boston naming test')])
#
# 17903297 rs1831521 gwas_central
# GWC: set([u'Cognitive performance, Boston naming test'])
# US:  set([('brain|aging', 'boston naming test')])
#
# 17903297 rs3891355 gwas_central
# GWC: set([u'Cognitive performance, similarities'])
# US:  set([('brain|aging', 'similarities')])
#
# 17903297 rs1131497 gwas_central
# GWC: set([u'Cognitive performance, similarities'])
# US:  set([('brain|aging', 'similarities')])
#
# 17903297 rs360929 gwas_central
# GWC: set([u'Brain MRI, temporal horn volume'])
# US:  set([('brain|aging', 'ALTHBV')])
#
# 17903297 rs1970546 gwas_central
# GWC: set([u'Brain MRI, total cerebral brain volume'])
# US:  set([('brain|aging', 'total cerebral brain volume')])
#
# 17903297 rs502309 gwas_central
# GWC: set([u'Brain MRI, total cerebral brain volume'])
# US:  set([('brain|aging', 'total cerebral brain volume')])
#
# 17903297 rs2179965 gwas_central
# GWC: set([u'Cognitive performance, attention and executive function'])
# US:  set([('brain|aging', 'factor 3: measure of attention and executive function-trails a and b')])
#
# 17903297 rs2832077 gwas_central
# GWC: set([u'Cognitive performance, attention and executive function'])
# US:  set([('brain|aging', 'factor 3: measure of attention and executive function-trails a and b')])
#
# 17903297 rs1031381 gwas_central
# GWC: set([u'Cognitive performance, attention and executive function'])
# US:  set([('brain|aging', 'factor 3: measure of attention and executive function-trails a and b')])
#
# 17903297 rs934299 gwas_central
# GWC: set([u'Cognitive performance, attention and executive function'])
# US:  set([('brain|aging', 'factor 3: measure of attention and executive function-trails a and b')])
#
# 17903297 rs2352904 gwas_central
# GWC: set([u'Cognitive performance, visual memory and organization'])
# US:  set([('brain|aging', 'factor 2:visual memory and organization')])
#
# 17903297 rs6914079 gwas_central
# GWC: set([u'Cognitive performance, visual memory and organization'])
# ...
# 20038947 rs6711718 set([('STAR*|major depression', '')])
# 20038947 rs389967 set([('STAR*|major depression', '')])
# 20038947 rs435206 set([('STAR*|major depression', '')])
# 20038947 rs867722 set([('STAR*|major depression', '')])
# 20038947 rs7977950 set([('STAR*|major depression', '')])
# 20038947 rs1855625 set([('STAR*|major depression', '')])
# 20038947 rs644377 set([('STAR*|major depression', '')])
# 20038947 rs270584 set([('STAR*|major depression', '')])
# 20038947 rs7151193 set([('STAR*|major depression', '')])
# 20038947 rs2147256 set([('STAR*|major depression', '')])
# 20038947 rs4620978 set([('STAR*|major depression', '')])
# 20038947 rs10187367 set([('STAR*|major depression', '')])
# 20038947 rs346101 set([('STAR*|major depression', '')])
# 20038947 rs11634319 set([('STAR*|major depression', '')])
# 20038947 rs17133921 set([('STAR*|major depression', '')])
# 20038947 rs17077540 set([('STAR*|major depression', '')])
# 20038947 rs7654559 set([('STAR*|major depression', '')])
# 20038947 rs6694643 set([('STAR*|major depression', '')])
# 20038947 rs7079573 set([('STAR*|major depression', '')])
# 20038947 rs10900126 set([('STAR*|major depression', '')])
# 20038947 rs329640 set([('STAR*|major depression', '')])
# 20038947 rs7978310 set([('STAR*|major depression', '')])
# 20038947 rs1456139 set([('STAR*|major depression', '')])
# 20038947 rs2203374 set([('STAR*|major depression', '')])
# 20038947 rs270592 set([('STAR*|major depression', '')])
# 20038947 rs6930508 set([('STAR*|major depression', '')])
# 20038947 rs7249956 set([('STAR*|major depression', '')])
# 20038947 rs10007831 set([('STAR*|major depression', '')])
# 20038947 rs12526133 set([('STAR*|major depression', '')])
# 20038947 rs11011581 set([('STAR*|major depression', '')])
# 20038947 rs11772451 set([('STAR*|major depression', '')])
# ---
# 20041166 rs9264942 gwas_central
# GWC: set([u'HIV-1 control, setpoint', u'HIV-1 control, progression'])
# US:  set([('HIV-1', '')])
#
# 20041166 rs2395029 gwas_central
# GWC: set([u'HIV-1 control, setpoint', u'HIV-1 control, progression'])
# US:  set([('HIV-1', '')])
#
# 20041166 rs7758512 gwas_central
# GWC: set([u'HIV-1 control, progression'])
# US:  None
#
# 20041166 rs17291045 gwas_central
# GWC: set([u'HIV-1 control, progression'])
# US:  None
#
# 20041166 rs9368699 gwas_central
# GWC: set([u'HIV-1 control, progression'])
# US:  None
#
# 20041166 rs9497975 gwas_central
# GWC: set([u'HIV-1 control, progression'])
# US:  None
#
# 20041166 rs8013190 gwas_central
# GWC: set([u'HIV-1 control, progression'])
# US:  None
#
# 20041166 rs38152 gwas_central
# GWC: set([u'HIV-1 control, progression'])
# US:  None
#
# 20041166 rs3815087 gwas_central
# GWC: set([u'HIV-1 control, progression'])
# US:  None
#
# 20041166 rs9367630 gwas_central
# GWC: set([u'HIV-1 control, progression'])
# US:  None
#
# 20041166 rs17324272 gwas_central
# GWC: set([u'HIV-1 control, progression'])
# US:  None
#
# 20041166 rs16914280 gwas_central
# GWC: set([u'HIV-1 control, progression'])
# US:  None
#
# 20041166 rs12274302 gwas_central
# GWC: set([u'HIV-1 control, progression'])
# US:  None
#
# 20041166 rs1777672 gwas_central
# GWC: set([u'HIV-1 control, progression'])
# US:  None
#
# 20041166 rs13394720 gwas_central
# GWC: set([u'HIV-1 control, progression'])
# US:  None
#
# 20041166 rs16948255 gwas_central
# GWC: set([u'HIV-1 control, progression'])
# US:  None
#
# 20041166 rs7756521 gwas_central
# GWC: set([u'HIV-1 control, progression'])
# US:  None
#
# 20041166 rs12122100 gwas_central
# GWC: set([u'HIV-1 control, progression'])
# US:  None
#
# 20041166 rs6751715 gwas_central
# GWC: set([u'HIV-1 control, progression'])
# US:  None
#
# 20041166 rs3734905 gwas_central
# GWC: set([u'HIV-1 control, progression'])
# US:  None
#
# 20041166 rs3763313 gwas_central
# GWC: set([u'HIV-1 control, progression'])
# US:  None
#
# 20041166 rs4838508 gwas_central
# GWC: set([u'HIV-1 control, progression'])
# US:  None
#
# 20041166 rs11818629 gwas_central
# GWC: set([u'HIV-1 control, progression'])
# US:  None
#
# 20041166 rs12198173 gwas_central
# GWC: set([u'HIV-1 control, progression'])
# US:  None
#
# 20041166 rs1385351 gwas_central
# GWC: set([u'HIV-1 control, progression'])
# US:  None
#
# 20041166 rs17027625 gwas_central
# GWC: set([u'HIV-1 control, progression'])
# US:  None
#
# 20041166 rs1405262 gwas_central
# GWC: set([u'HIV-1 control, progression'])
# US:  None
#
# 20041166 rs2069084 gwas_central
# GWC: set([u'HIV-1 control, progression'])
# US:  None
#
# 20041166 rs2304069 gwas_central
# GWC: set([u'HIV-1 control, progression'])
# US:  None
#
# 20041166 rs16936455 gwas_central
# GWC: set([u'HIV-1 control, progression'])
# US:  None
#
# 20041166 rs1120787 gwas_central
# GWC: set([u'HIV-1 control, progression'])
# US:  None
#
# 20041166 rs12012519 gwas_central
# GWC: set([u'HIV-1 control, progression'])
# US:  None
#
# 20041166 rs11143609 gwas_central
# GWC: set([u'HIV-1 control, progression'])
# US:  None
#
# 20041166 rs10928302 gwas_central
# GWC: set([u'HIV-1 control, progression'])
# US:  None
#
# 20041166 rs1463132 gwas_central
# GWC: set([u'HIV-1 control, progression'])
# US:  None
#
# 20041166 rs10159302 gwas_central
# GWC: set([u'HIV-1 control, progression'])
# US:  None
#
# 20041166 rs2834812 gwas_central
# GWC: set([u'HIV-1 control, progression'])
# US:  None
#
# 20041166 rs2637496 gwas_central
# GWC: set([u'HIV-1 control, progression'])
# US:  None
#
# 20041166 rs2395029 gwas_central
# GWC: set([u'HIV-1 control, setpoint', u'HIV-1 control, progression'])
# US:  set([('HIV-1', '')])
#
# 20041166 rs9264942 gwas_central
# GWC: set([u'HIV-1 control, setpoint', u'HIV-1 control, progression'])
# US:  set([('HIV-1', '')])
#
# 20041166 rs259919 gwas_central
# GWC: set([u'HIV-1 control, setpoint'])
# US:  None
#
# 20041166 rs9468692 gwas_central
# GWC: set([u'HIV-1 control, setpoint'])
# US:  None
#
# 20041166 rs333 set([('HIV-1', '')])
# ---
# 20062060 rs6800541 gwas_central
# GWC: set([u'PR interval'])
# US:  set([('PR interval', '')])
#
# 20062060 rs3807989 gwas_central
# GWC: set([u'PR interval'])
# US:  set([('PR interval', '')])
#
# 20062060 rs11708996 gwas_central
# GWC: set([u'PR interval'])
# US:  set([('PR interval', '')])
#
# 20062060 rs7692808 gwas_central
# GWC: set([u'PR interval'])
# US:  set([('PR interval', '')])
#
# 20062060 rs1896312 gwas_central
# GWC: set([u'PR interval'])
# US:  set([('PR interval', '')])
#
# 20062060 rs11047543 gwas_central
# GWC: set([u'PR interval'])
# US:  set([('PR interval', '')])
#
# 20062060 rs251253 gwas_central
# GWC: set([u'PR interval'])
# US:  set([('PR interval', '')])
#
# 20062060 rs11897119 gwas_central
# GWC: set([u'PR interval'])
# US:  set([('PR interval', '')])
#
# 20062060 rs4944092 gwas_central
# GWC: set([u'PR interval'])
# US:  set([('PR interval', '')])
#
# ---
# 20066028 rs1532624 gwas_central
# GWC: set([u'Cholesterol'])
# US:  set([('Cholesterol Levels', '')])
#
# 20066028 rs2292883 set([('Cholesterol Levels', '')])
# 20066028 rs9863761 set([('Cholesterol Levels', '')])
# 20066028 rs10513684 set([('Cholesterol Levels', '')])
# 20066028 rs5400 set([('Cholesterol Levels', '')])
# ---
# 20072603 rs13182402 gwas_central
# GWC: set([u'Osteoporosis'])
# US:  set([('Osteoporosis', '')])
#
# 20072603 rs3212217 set([('Osteoporosis', '')])
# 20072603 rs6711417 set([('Osteoporosis', '')])
# 20072603 rs6039266 set([('Osteoporosis', '')])
# 20072603 rs2504063 set([('Osteoporosis', '')])
# 20072603 rs16894980 set([('Osteoporosis', '')])
# ---
# ---
# 20081858 rs11071657 set([('glucose homeostasis|type 2 diabetes', '')])
# 20081858 rs35767 set([('glucose homeostasis|type 2 diabetes', '')])
# 20081858 rs4607517 set([('glucose homeostasis|type 2 diabetes', '')])
# 20081858 rs560887 set([('glucose homeostasis|type 2 diabetes', '')])
# 20081858 rs10830963 set([('glucose homeostasis|type 2 diabetes', '')])
# 20081858 rs2191349 set([('glucose homeostasis|type 2 diabetes', '')])
# 20081858 rs11558471 set([('glucose homeostasis|type 2 diabetes', '')])
# 20081858 rs10885122 set([('glucose homeostasis|type 2 diabetes', '')])
# 20081858 rs11708067 set([('glucose homeostasis|type 2 diabetes', '')])
# 20081858 rs7944584 set([('glucose homeostasis|type 2 diabetes', '')])
# 20081858 rs4506565 set([('glucose homeostasis|type 2 diabetes', '')])
# 20081858 rs11920090 set([('glucose homeostasis|type 2 diabetes', '')])
# 20081858 rs11605924 set([('glucose homeostasis|type 2 diabetes', '')])
# 20081858 rs780094 set([('glucose homeostasis|type 2 diabetes', '')])
# 20081858 rs174550 set([('glucose homeostasis|type 2 diabetes', '')])
# 20081858 rs340874 set([('glucose homeostasis|type 2 diabetes', '')])
# 20081858 rs7034200 set([('glucose homeostasis|type 2 diabetes', '')])
# ---
# 20169177 rs7097397 set([('Systemic Lupus Erythematosus', '')])
# 20169177 rs2736340 set([('Systemic Lupus Erythematosus', '')])
# 20169177 rs10857650 set([('Systemic Lupus Erythematosus', '')])
# 20169177 rs6590330 set([('Systemic Lupus Erythematosus', '')])
# 20169177 rs7574865 set([('Systemic Lupus Erythematosus', '')])
# 20169177 rs2230926 set([('Systemic Lupus Erythematosus', '')])
# 20169177 rs10893872 set([('Systemic Lupus Erythematosus', '')])
# 20169177 rs10168266 set([('Systemic Lupus Erythematosus', '')])
# 20169177 rs2663052 set([('Systemic Lupus Erythematosus', '')])
# 20169177 rs1128334 set([('Systemic Lupus Erythematosus', '')])
# 20169177 rs7922169 set([('Systemic Lupus Erythematosus', '')])
# 20169177 rs9271366 set([('Systemic Lupus Erythematosus', '')])
# 20169177 rs9275328 set([('Systemic Lupus Erythematosus', '')])
# 20169177 rs2254546 set([('Systemic Lupus Erythematosus', '')])
# 20169177 rs877819 set([('Systemic Lupus Erythematosus', '')])
# 20169177 rs729302 set([('Systemic Lupus Erythematosus', '')])
# ---
# 20173747 rs13376333 set([('Atrial Fibrillation', '')])
# 20173747 rs6843082 set([('Atrial Fibrillation', '')])
# 20173747 rs13038095 set([('Atrial Fibrillation', '')])
# ---
# 20173748 rs7671167 set([('chronic obstructive pulmonary disease|associated with chronic', '')])
# 20173748 rs2869967 set([('chronic obstructive pulmonary disease|associated with chronic', '')])
# 20173748 rs1903003 set([('chronic obstructive pulmonary disease|associated with chronic', '')])
# ---
# 20174558 rs4845624 set([('Type 2 Diabetes', '')])
# 20174558 rs7192960 set([('Type 2 Diabetes', '')])
# ---
# 20190752 rs11922594 set([('celiac disease|Multiple', '')])
# 20190752 rs13098911 set([('celiac disease|Multiple', '')])
# 20190752 rs6974491 set([('celiac disease|Multiple', '')])
# 20190752 rs13151961 set([('celiac disease|Multiple', '')])
# 20190752 rs1033180 set([('celiac disease|Multiple', '')])
# 20190752 rs6806528 set([('celiac disease|Multiple', '')])
# 20190752 rs13314993 set([('celiac disease|Multiple', '')])
# 20190752 rs12928822 set([('celiac disease|Multiple', '')])
# 20190752 rs4899260 set([('celiac disease|Multiple', '')])
# 20190752 rs653178 set([('celiac disease|Multiple', '')])
# 20190752 rs4675374 set([('celiac disease|Multiple', '')])
# 20190752 rs13003464 set([('celiac disease|Multiple', '')])
# 20190752 rs1738074 set([('celiac disease|Multiple', '')])
# 20190752 rs2074404 set([('celiac disease|Multiple', '')])
# 20190752 rs17810546 set([('celiac disease|Multiple', '')])
# 20190752 rs917997 set([('celiac disease|Multiple', '')])
# 20190752 rs6691768 set([('celiac disease|Multiple', '')])
# 20190752 rs9792269 set([('celiac disease|Multiple', '')])
# 20190752 rs10806425 set([('celiac disease|Multiple', '')])
# 20190752 rs4819388 set([('celiac disease|Multiple', '')])
# 20190752 rs842647 set([('celiac disease|Multiple', '')])
# 20190752 rs11221332 set([('celiac disease|Multiple', '')])
# 20190752 rs296547 set([('celiac disease|Multiple', '')])
# 20190752 rs2327832 set([('celiac disease|Multiple', '')])
# 20190752 rs802734 set([('celiac disease|Multiple', '')])
# 20190752 rs10936599 set([('celiac disease|Multiple', '')])
# 20190752 rs6441961 set([('celiac disease|Multiple', '')])
# 20190752 rs13010713 set([('celiac disease|Multiple', '')])
# 20190752 rs864537 set([('celiac disease|Multiple', '')])
# 20190752 rs1893217 set([('celiac disease|Multiple', '')])
# 20190752 rs2762051 set([('celiac disease|Multiple', '')])
# 20190752 rs12727642 set([('celiac disease|Multiple', '')])
# 20190752 rs10903122 set([('celiac disease|Multiple', '')])
# 20190752 rs3748816 set([('celiac disease|Multiple', '')])
# 20190752 rs1464510 set([('celiac disease|Multiple', '')])
# 20190752 rs17035378 set([('celiac disease|Multiple', '')])
# 20190752 rs3816281 set([('celiac disease|Multiple', '')])
# 20190752 rs5979785 set([('celiac disease|Multiple', '')])
# 20190752 rs11712165 set([('celiac disease|Multiple', '')])
# 20190752 rs1250552 set([('celiac disease|Multiple', '')])
# 20190752 rs859637 set([('celiac disease|Multiple', '')])
# 20190752 rs2298428 set([('celiac disease|Multiple', '')])
# ---
# 20195266 rs7105881 set([('to antipsychotic drugs|metabolic side effects', '')])
# 20195266 rs320209 set([('to antipsychotic drugs|metabolic side effects', '')])
# 20195266 rs518590 set([('to antipsychotic drugs|metabolic side effects', '')])
# 20195266 rs1967256 set([('to antipsychotic drugs|metabolic side effects', '')])
# 20195266 rs13134954 set([('to antipsychotic drugs|metabolic side effects', '')])
# 20195266 rs1991126 set([('to antipsychotic drugs|metabolic side effects', '')])
# 20195266 rs10202231 set([('to antipsychotic drugs|metabolic side effects', '')])
# 20195266 rs6092078 set([('to antipsychotic drugs|metabolic side effects', '')])
# 20195266 rs17651157 set([('to antipsychotic drugs|metabolic side effects', '')])
# 20195266 rs1187614 set([('to antipsychotic drugs|metabolic side effects', '')])
# 20195266 rs977396 set([('to antipsychotic drugs|metabolic side effects', '')])
# 20195266 rs17216786 set([('to antipsychotic drugs|metabolic side effects', '')])
# 20195266 rs8092443 set([('to antipsychotic drugs|metabolic side effects', '')])
# 20195266 rs6735179 set([('to antipsychotic drugs|metabolic side effects', '')])
# 20195266 rs17100498 set([('to antipsychotic drugs|metabolic side effects', '')])
# 20195266 rs1568679 set([('to antipsychotic drugs|metabolic side effects', '')])
# 20195266 rs17661538 set([('to antipsychotic drugs|metabolic side effects', '')])
# 20195266 rs7119817 set([('to antipsychotic drugs|metabolic side effects', '')])
# 20195266 rs1405687 set([('to antipsychotic drugs|metabolic side effects', '')])
# 20195266 rs10499504 set([('to antipsychotic drugs|metabolic side effects', '')])
# 20195266 rs13224682 set([('to antipsychotic drugs|metabolic side effects', '')])
# 20195266 rs7108821 set([('to antipsychotic drugs|metabolic side effects', '')])
# 20195266 rs1534238 set([('to antipsychotic drugs|metabolic side effects', '')])
# 20195266 rs620875 set([('to antipsychotic drugs|metabolic side effects', '')])
# 20195266 rs4783227 set([('to antipsychotic drugs|metabolic side effects', '')])
# 20195266 rs399885 set([('to antipsychotic drugs|metabolic side effects', '')])
# 20195266 rs9658108 set([('to antipsychotic drugs|metabolic side effects', '')])
# 20195266 rs13335336 set([('to antipsychotic drugs|metabolic side effects', '')])
# 20195266 rs17100506 set([('to antipsychotic drugs|metabolic side effects', '')])
# 20195266 rs1771628 set([('to antipsychotic drugs|metabolic side effects', '')])
# 20195266 rs2994684 set([('to antipsychotic drugs|metabolic side effects', '')])
# 20195266 rs11163585 set([('to antipsychotic drugs|metabolic side effects', '')])
# 20195266 rs6741819 set([('to antipsychotic drugs|metabolic side effects', '')])
# 20195266 rs153091 set([('to antipsychotic drugs|metabolic side effects', '')])
# 20195266 rs11954387 set([('to antipsychotic drugs|metabolic side effects', '')])
# 20195266 rs11663206 set([('to antipsychotic drugs|metabolic side effects', '')])
# 20195266 rs17385675 set([('to antipsychotic drugs|metabolic side effects', '')])
# 20195266 rs1117324 set([('to antipsychotic drugs|metabolic side effects', '')])
# 20195266 rs7570469 set([('to antipsychotic drugs|metabolic side effects', '')])
# 20195266 rs4838255 set([('to antipsychotic drugs|metabolic side effects', '')])
# 20195266 rs11735070 set([('to antipsychotic drugs|metabolic side effects', '')])
# 20195266 rs1577917 set([('to antipsychotic drugs|metabolic side effects', '')])
# 20195266 rs1464500 set([('to antipsychotic drugs|metabolic side effects', '')])
# 20195266 rs10502661 set([('to antipsychotic drugs|metabolic side effects', '')])
# 20195266 rs1979096 set([('to antipsychotic drugs|metabolic side effects', '')])
# 20195266 rs17410015 set([('to antipsychotic drugs|metabolic side effects', '')])
# ---

# %%
BLACKLIST=['19043545', '18464913', '17997608', '17447842', '19936222', '19503597', '20041166']

# %% [markdown]
# #### Error analysis over top 15 documents

# %% [markdown]
# Crohns disease (1st paper): Table is really messed up, but could solve it with a specialized extractor that looks at induced cells.
#
# Weight/bmi: The table is only a screenshot
#
# Acronyms at the end: The acronym explanations are in the caption of the table
#
# Some acroynms aren't resolved because an extra letter is added to them e.g. AXYZ instead of XYZ

# %% [markdown]
# ### Set up map of GWC to GWASDB phenotypes

# %%
out_set = set()
for a in assocs:
    s1 = gold_rel_dict[(a.paper.pubmed_id, a.snp.rs_id)]
    s2 = rel_dict.get((str(a.paper.pubmed_id), a.snp.rs_id), None)
    if a.paper.pubmed_id == 23400010: print s1, s2
    if s1 and s2:
        for name1 in s1:
            for name2a, name2b in s2:
                name1 = str(name1)
                score = phen_scores.get((name1, name2a, name2b), '')
                out_set.add('%s\t%s\t%s\t%s\n' % (name1, name2a, name2b, score))

with open('phenotype.mapping.tsv', 'w') as f:                    
    for out_str in out_set:
        f.write(out_str)
# Out:
# set([u'Thiazide-induced adverse metabolic effects in hypertensive patients']) None
# set([u'Thiazide-induced adverse metabolic effects in hypertensive patients']) None
# set([u'Thiazide-induced adverse metabolic effects in hypertensive patients']) None
# set([u'Thiazide-induced adverse metabolic effects in hypertensive patients']) None
# set([u'Thiazide-induced adverse metabolic effects in hypertensive patients']) None
# set([u'Thiazide-induced adverse metabolic effects in hypertensive patients']) None
# set([u'Thiazide-induced adverse metabolic effects in hypertensive patients']) None
# set([u'Thiazide-induced adverse metabolic effects in hypertensive patients']) None
# set([u'Thiazide-induced adverse metabolic effects in hypertensive patients']) None
# set([u'Thiazide-induced adverse metabolic effects in hypertensive patients']) None
# set([u'Thiazide-induced adverse metabolic effects in hypertensive patients']) None
# set([u'Thiazide-induced adverse metabolic effects in hypertensive patients']) None
# set([u'Thiazide-induced adverse metabolic effects in hypertensive patients']) None
# set([u'Thiazide-induced adverse metabolic effects in hypertensive patients']) None
# set([u'Thiazide-induced adverse metabolic effects in hypertensive patients']) None
# set([u'Thiazide-induced adverse metabolic effects in hypertensive patients']) None
# set([u'Thiazide-induced adverse metabolic effects in hypertensive patients']) None
# set([u'Thiazide-induced adverse metabolic effects in hypertensive patients']) None
# set([u'Thiazide-induced adverse metabolic effects in hypertensive patients']) None
# set([u'Thiazide-induced adverse metabolic effects in hypertensive patients']) None
# set([u'Thiazide-induced adverse metabolic effects in hypertensive patients']) None
# set([u'Thiazide-induced adverse metabolic effects in hypertensive patients']) None
# set([u'Thiazide-induced adverse metabolic effects in hypertensive patients']) None
# set([u'Thiazide-induced adverse metabolic effects in hypertensive patients']) None
# set([u'Thiazide-induced adverse metabolic effects in hypertensive patients']) None
# set([u'Thiazide-induced adverse metabolic effects in hypertensive patients']) None
# set([u'Thiazide-induced adverse metabolic effects in hypertensive patients']) None
# set([u'Thiazide-induced adverse metabolic effects in hypertensive patients']) None
# set([u'Thiazide-induced adverse metabolic effects in hypertensive patients']) None
# set([u'Thiazide-induced adverse metabolic effects in hypertensive patients']) None
# set([u'Thiazide-induced adverse metabolic effects in hypertensive patients']) None
# set([u'Thiazide-induced adverse metabolic effects in hypertensive patients']) None
# set([u'Thiazide-induced adverse metabolic effects in hypertensive patients']) None
# set([u'Thiazide-induced adverse metabolic effects in hypertensive patients']) None
# set([u'Thiazide-induced adverse metabolic effects in hypertensive patients']) None
# set([u'Thiazide-induced adverse metabolic effects in hypertensive patients']) None
# set([u'Thiazide-induced adverse metabolic effects in hypertensive patients']) None
# set([u'Thiazide-induced adverse metabolic effects in hypertensive patients']) None
# set([u'Thiazide-induced adverse metabolic effects in hypertensive patients']) None
# set([u'Thiazide-induced adverse metabolic effects in hypertensive patients']) None
# set([u'Thiazide-induced adverse metabolic effects in hypertensive patients']) None
# set([u'Thiazide-induced adverse metabolic effects in hypertensive patients']) None
# set([u'Thiazide-induced adverse metabolic effects in hypertensive patients']) None
# set([u'Thiazide-induced adverse metabolic effects in hypertensive patients']) None
# set([u'Thiazide-induced adverse metabolic effects in hypertensive patients']) None
# set([u'Thiazide-induced adverse metabolic effects in hypertensive patients']) None
# set([u'Thiazide-induced adverse metabolic effects in hypertensive patients']) None
# set([u'Thiazide-induced adverse metabolic effects in hypertensive patients']) None
# set([u'Thiazide-induced adverse metabolic effects in hypertensive patients']) None
# set([u'Thiazide-induced adverse metabolic effects in hypertensive patients']) None
# set([u'Thiazide-induced adverse metabolic effects in hypertensive patients']) None
# set([u'Thiazide-induced adverse metabolic effects in hypertensive patients']) None
# set([u'Thiazide-induced adverse metabolic effects in hypertensive patients']) None
# set([u'Thiazide-induced adverse metabolic effects in hypertensive patients']) None
# set([u'Thiazide-induced adverse metabolic effects in hypertensive patients']) None
# set([u'Thiazide-induced adverse metabolic effects in hypertensive patients']) None
# set([u'Thiazide-induced adverse metabolic effects in hypertensive patients']) None
# set([u'Thiazide-induced adverse metabolic effects in hypertensive patients']) None
# set([u'Thiazide-induced adverse metabolic effects in hypertensive patients']) None

# %% [markdown]
# Dictionary legend in 0: wrong, 1: acronym, 2: imprecise, 3: correct

# %%
phen_map = dict()
phen_scores = dict()
with open('phenotype.mapping.annotated.txt') as f:                    
    lines = f.read().split('\r')
    for line in lines:
        fields = line.strip().split('\t')
        if fields[0] == 'Thiazide-induced':
            print fields
        fields = [re.sub('"', '', f) for f in fields]
        try:
            orig_name, glob_name, loc_name, score = fields
        except ValueError:
            if len(fields) == 2:
                orig_name, glob_name = fields
                loc_name = ''
            else:
                orig_name, glob_name, loc_name = fields
            score = 3
        phen_scores[(orig_name, glob_name, loc_name)] = score
        if score in ('2', '3'):
            key = (glob_name, loc_name)
            if key not in phen_map: phen_map[key] = set()
            phen_map[key].add(orig_name)

# %% [markdown]
# ### Look at results!

# %%
import re

def paper_contains(pmid, quote):
    with open('../data/db/papers/%d.xml' % pmid) as f:
        txt = f.read()
        return True if re.search(quote, txt) else False

# %%
# display directly the results we found
n_correct = 0
n_imprecise = 0
n_missing = 0
n_wrong = 0
n_total = 0
n_new = 0
invalid_per_paper = { a.paper.pubmed_id : 0 for a in assocs }
seen = set()
for a in assocs:
#     if str(a.paper.pubmed_id) in BLACKLIST: continue
    if (a.paper.pubmed_id, a.snp.rs_id) in seen: continue
    seen.add((a.paper.pubmed_id, a.snp.rs_id))
    gold_phen_set = gold_rel_dict[(a.paper.pubmed_id, a.snp.rs_id)]
    pred_phen_set = rel_dict.get((str(a.paper.pubmed_id), a.snp.rs_id), {})
    tmp = list(pred_phen_set)
    if tmp and tmp[0][1].startswith('Age at'):
        n_correct += 1
        continue
    pred_phen_set2 = {m for p in pred_phen_set for m in phen_map.get(p, {})}
    if a.paper.pubmed_id == 23583980:
        print a.snp.rs_id, gold_phen_set, pred_phen_set, pred_phen_set2
    if gold_phen_set & pred_phen_set2: 
        n_correct += 1
        n_total += 1
    else:
#         if True:
        if paper_contains(a.paper.pubmed_id, a.snp.rs_id):
            if pred_phen_set2:
                n_wrong += 1
            else:
                n_missing += 1
            n_total += 1
            invalid_per_paper[a.paper.pubmed_id] += 1
#         print gold_phen_set
#         print pred_phen_set
#         print pred_phen_set2        
#         print

print n_correct, n_wrong, n_missing, n_total

print 'Biggest omissions:', sorted(invalid_per_paper.items(), key=lambda x: x[1], reverse=True)[:10]
# Out:
# rs7934606 set([u'Interstitial lung disease']) set([('pneumonias', '')]) set([])
# rs2076295 set([u'Interstitial lung disease']) set([('pneumonias', '')]) set([])
# rs2736100 set([u'Interstitial lung disease']) set([('pneumonias', '')]) set([])
# rs1981997 set([u'Interstitial lung disease']) set([('pneumonias', '')]) set([])
# rs6793295 set([u'Interstitial lung disease']) set([('pneumonias', '')]) set([])
# rs12610495 set([u'Interstitial lung disease']) set([('pneumonias', '')]) set([])
# rs2034650 set([u'Interstitial lung disease']) set([('pneumonias', '')]) set([])
# rs2609255 set([u'Interstitial lung disease']) set([('pneumonias', '')]) set([])
# rs1278769 set([u'Interstitial lung disease']) set([('pneumonias', '')]) set([])
# rs4727443 set([u'Interstitial lung disease']) set([('pneumonias', '')]) set([])
# rs11191865 set([u'Interstitial lung disease']) set([('pneumonias', '')]) set([])
# rs1379326 set([u'Interstitial lung disease']) {} set([])
# rs7005380 set([u'Interstitial lung disease']) {} set([])
# rs2441727 set([u'Interstitial lung disease']) {} set([])
# rs6496044 set([u'Interstitial lung disease']) {} set([])
# rs3132946 set([u'Interstitial lung disease']) {} set([])
# 2245 68 645 2949
# Biggest omissions: [(20195266, 37), (19197348, 28), (23382691, 18), (23455636, 17), (22829776, 16), (22832960, 16), (23400010, 14), (22760553, 13), (17903296, 13), (23583980, 12)]

# %% [markdown]
# #### Notes from all papers:
#
# 20195266: Add outcome column title
# 19197348: (Korsae islanders) No global phenotype, need to handle phenotype headers
# 23382691: "Shows pleitoropy with cancer and...". "glycosylation" in phenotype dict but fails because of "n-" prefix. Immunoglobulin not in dict, but igg is, but is not picked up because too short. Need to add "associated with" as a feature, and handle dashed, and if still fails, add all phenotypes from title. Could take out long words (>12 chars?) from long phenotypes in dict for individual matching.
# 23455636: RSID/Allele format that you need to parse
# 22829776: Incorrect global phenotype. But "sex hormone-binding globulin" is in dict, but doesn't get matched...
# 22832960: Should be correct with new phenotype
# 23400010: All the SNPs are in text!!
# 22760553: citalopram in dict but connected to a dash in title. Add "side effects" to matched keywords?
# 17903296: Incorrect global phenotype, but now should be "bone mineral density", although it's still wrong. "bone mass and geometry" hard to match. Sub-phenotype acronyms sometimes not correctly resolved. In many cases, GWAS central is wrong, e.g. rs10514345, "lumbar spine bmd" is correct, not "Hip geometry, neck section modulus".
# 23583980: Why is "fiboris not matched? It's the period? No: it's in shortened dict, but not in full.
#
# Idea: Match spans if they contain the same words, but potentially in a different order

# %% [markdown]
# #### Notes from first 100:
#
# 470 fully correct
#
# 19197348: Phenotype headers
# 18159244: Completely messed-up way of writing down p-values
# 17903302: Acronyms
# 17903305: Phenotype headers, errors (prostate vs breast cancer)
# 19043545: Mentions in text
# 17447842: Mentions in text (also: Messed-up way of writing table (induced cells should help)
# 17658951: Extraction from text
# 17903296: e.g. Neck phenotype acronym has an undocumented male/female suffix
# 19557161: In text, and one table entry strangely doesn't seem have been found

# %%
paper_id = '19557161'
for a in assocs:
    if str(a.paper.pubmed_id) == paper_id and paper_contains(a.paper.pubmed_id, a.snp.rs_id):
        print a.phenotype.name, a.snp.rs_id, rel_dict.get((paper_id, a.snp.rs_id), None)
# Out:
# Waist-hip ratio rs2605100 None
# Waist circumference rs987237 None
# Waist circumference rs545854 None
# Waist circumference rs6429082 None

# %%
with open('associations.tsv', 'w') as f:
    for (pmid, rsid, (glob_phen, loc_phen)) in associations:
        pval = min(pval_dict[pmid][rsid])
        loc_phen = '-' if not loc_phen else loc_phen

        f.write('%s\t%s\t%s\t%s\t%f\n' % (pmid, rsid, glob_phen, loc_phen, pval))
