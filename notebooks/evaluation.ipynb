# %% [markdown]
# # Evaluation notebook

# %% [markdown]
# Here, we will evaluate the relations extracted in all the other notebooks

# %%
# %load_ext autoreload
# %autoreload 2

import sys
import cPickle

# import snorkel and gwasdb
sys.path.append('../snorkel')
sys.path.append('../src')
sys.path.append('../src/crawler')

# set up paths
abstract_dir = '../data/db/papers'

# set up matplotlib
import numpy as np
import matplotlib
# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,4)

# %%
from snorkel.parser import XMLDocParser, HTMLParser, CorpusParser
from extractor.parser import UnicodeXMLTableDocParser, UnicodeTableParser

xml_parser = UnicodeXMLTableDocParser(
    path=abstract_dir,
    doc='./*',
    text='.//table',
    id='.//article-id[@pub-id-type="pmid"]/text()',
    keep_xml_tree=True)

table_parser = UnicodeTableParser()
html_parser = HTMLParser(path='../data/db/papers/')
cp = CorpusParser(xml_parser, table_parser, max_docs=15)
# %time corpus = cp.parse_corpus(name='GWAS Corpus')
# Out:
# CPU times: user 50.2 s, sys: 2.97 s, total: 53.2 s
# Wall time: 1min 16s

# %% [markdown]
# ## Loading results from other notebooks

# %% [markdown]
# #### Phenotype/rsid relations from tables

# %%
table_associations = []
with open('phen-rsid.table.rel.tsv') as f:
    for line in f:
        fields = line.strip().split('\t')
        pmid, rsid, phen, pval = fields[:4]
        table_associations.append((pmid, rsid, phen))
        
print len(table_associations), 'loaded, e.g.:'
print table_associations[:5]
# Out:
# 857 loaded, e.g.:
# [('17903292', 'rs1158167', 'cystatin-c'), ('17903292', 'rs1712790', 'urinary albumin excretion'), ('17903292', 'rs6977660', 'thyroid stimulating hormone'), ('17903292', 'rs9322817', 'thyroid stimulating hormone'), ('17903292', 'rs10499559', 'thyroid stimulating hormone')]

# %% [markdown]
# #### PMID/Phenotype relations extracted from titles/abstracts

# %%
text_associations = dict()
with open('phenotypes.extracted.tsv') as f:
    for line in f:
        name, phen = line.strip().split('\t')
        text_associations[name] = phen
        
print len(text_associations), 'loaded, e.g.:'
print text_associations.items()[:5]
# Out:
# 100 loaded, e.g.:
# [('20081856', 'major mood disorders'), ('19056611', 'Type 2 Diabetes'), ('20081858', 'glucose homeostasis|type 2 diabetes'), ('19503597', 'Uric Acid Concentrations.'), ('19734902', "Alzheimer's disease,")]

# %% [markdown]
# #### RSID/Pvalue relations extracted from tables

# %%
rsid_dict = dict()
with open('pval-rsid.raw.tsv') as f:
    for line in f:
        pmid, rsid, table_id, row_id, col_id, pval = line.strip().split('\t')
        pval, table_id, row_id, col_id = float(pval), int(table_id), int(row_id), int(col_id)
        
        if pval > 1e-5: continue
            
        if pmid not in rsid_dict: rsid_dict[pmid] = set()
        rsid_dict[pmid].add(rsid)

# %% [markdown]
# ## Construct a list valid relations

# %%
# TODO: load pvalues properly, use them to filter stuff downstream, do acroynm resolution here

# %%
table_pmids = {pmid for pmid, _, _ in table_associations}
associations = table_associations

for pmid in rsid_dict:
    if pmid in table_pmids: continue
    phen = text_associations[pmid]
    associations.append((pmid, rsid, phen))

# %% [markdown]
# ## Comparing to GWAS central

# %%
from db.kb import KnowledgeBase

kb = KnowledgeBase()
assocs = [assoc for doc in corpus.documents for assoc in kb.assoc_by_pmid(doc.name) if assoc.source == 'gwas_central' and assoc.pvalue < 1e-5]

print '%d documents, %d associations' % (len(corpus.documents), len(assocs))
# Out:
# 15 documents, 308 associations

# %%
rel_dict = { (pmid, rsid) : set() for (pmid, rsid, phen) in associations }
for (pmid, rsid, phen) in associations:
    rel_dict[(pmid, rsid)].add(phen)

gold_rel_dict = { (a.paper.pubmed_id, a.snp.rs_id) : set() for a in assocs }
for a in assocs:
    gold_rel_dict[(a.paper.pubmed_id, a.snp.rs_id)].add(a.phenotype.name)

# %%
# TODO: where crohns disease?? why weight/bmi, etc not extracted from table? why acronyms at the end are not resolved??
# display directly the results we found
for a in assocs:
#     continue
    
    s1 = gold_rel_dict[(a.paper.pubmed_id, a.snp.rs_id)]
    s2 = rel_dict.get((str(a.paper.pubmed_id), a.snp.rs_id), {})
    print a.paper.pubmed_id, a.snp.rs_id, a.source
    print 'GWC:', gold_rel_dict[(a.paper.pubmed_id, a.snp.rs_id)]
    print 'US: ', rel_dict.get((str(a.paper.pubmed_id), a.snp.rs_id), None)
    print
# Out:
# 17447842 rs11209026 gwas_central
# GWC: set([u"Crohn's disease"])
# US:  None
#
# 17447842 rs11465804 gwas_central
# GWC: set([u"Crohn's disease"])
# US:  None
#
# 17447842 rs1373692 gwas_central
# GWC: set([u"Crohn's disease"])
# US:  None
#
# 17447842 rs10512734 gwas_central
# GWC: set([u"Crohn's disease"])
# US:  None
#
# 17447842 rs4613763 gwas_central
# GWC: set([u"Crohn's disease"])
# US:  None
#
# 17447842 rs1002922 gwas_central
# GWC: set([u"Crohn's disease"])
# US:  None
#
# 17447842 rs1343151 gwas_central
# GWC: set([u"Crohn's disease"])
# US:  None
#
# 17447842 rs4495224 gwas_central
# GWC: set([u"Crohn's disease"])
# US:  None
#
# 17447842 rs348601 gwas_central
# GWC: set([u"Crohn's disease"])
# US:  None
#
# 17447842 rs5743289 gwas_central
# GWC: set([u"Crohn's disease"])
# US:  None
#
# 17447842 rs10889677 gwas_central
# GWC: set([u"Crohn's disease"])
# US:  None
#
# 17658951 rs9930506 gwas_central
# GWC: set([u'Hip circumference'])
# US:  None
#
# 17658951 rs8050136 gwas_central
# GWC: set([u'Hip circumference'])
# US:  None
#
# 17658951 rs9940128 gwas_central
# GWC: set([u'Hip circumference'])
# US:  None
#
# 17658951 rs9939973 gwas_central
# GWC: set([u'Hip circumference'])
# US:  None
#
# 17658951 rs1121980 gwas_central
# GWC: set([u'Hip circumference'])
# US:  None
#
# 17658951 rs7193144 gwas_central
# GWC: set([u'Hip circumference'])
# US:  None
#
# 17658951 rs9939609 gwas_central
# GWC: set([u'Hip circumference'])
# US:  None
#
# 17658951 rs9926289 gwas_central
# GWC: set([u'Hip circumference'])
# US:  None
#
# 17658951 rs965670 gwas_central
# GWC: set([u'Hip circumference'])
# US:  None
#
# 17658951 rs2180579 gwas_central
# GWC: set([u'Hip circumference'])
# US:  None
#
# 17658951 rs6602024 gwas_central
# GWC: set([u'Body mass index'])
# US:  None
#
# 17658951 rs658838 gwas_central
# GWC: set([u'Body mass index'])
# US:  None
#
# 17658951 rs41512445 gwas_central
# GWC: set([u'Weight'])
# US:  None
#
# 17684544 rs2066847 gwas_central
# GWC: set([u"Crohn's disease"])
# US:  None
#
# 17684544 rs2076756 gwas_central
# GWC: set([u"Crohn's disease"])
# US:  None
#
# 17684544 rs2066844 gwas_central
# GWC: set([u"Crohn's disease"])
# US:  None
#
# 17684544 rs2066845 gwas_central
# GWC: set([u"Crohn's disease"])
# US:  None
#
# 17684544 rs1992660 gwas_central
# GWC: set([u"Crohn's disease"])
# US:  None
#
# 17684544 rs1992662 gwas_central
# GWC: set([u"Crohn's disease"])
# US:  None
#
# 17684544 rs11209026 gwas_central
# GWC: set([u"Crohn's disease"])
# US:  None
#
# 17684544 rs10484545 gwas_central
# GWC: set([u"Crohn's disease"])
# US:  None
#
# 17684544 rs1793004 gwas_central
# GWC: set([u"Crohn's disease"])
# US:  None
#
# 17684544 rs2241880 gwas_central
# GWC: set([u"Crohn's disease"])
# US:  None
#
# 17684544 rs1553575 gwas_central
# GWC: set([u"Crohn's disease"])
# US:  None
#
# 17684544 rs10513059 gwas_central
# GWC: set([u"Crohn's disease"])
# US:  None
#
# 17684544 rs200354 gwas_central
# GWC: set([u"Crohn's disease"])
# US:  None
#
# 17684544 rs7725052 gwas_central
# GWC: set([u"Crohn's disease"])
# US:  None
#
# 17684544 rs2009530 gwas_central
# GWC: set([u"Crohn's disease"])
# US:  None
#
# 17684544 rs10484543 gwas_central
# GWC: set([u"Crohn's disease"])
# US:  None
#
# 17903292 rs1712790 gwas_central
# GWC: set([u'Urinary albumin excretion'])
# US:  set(['urinary albumin excretion'])
#
# 17903292 rs1243400 gwas_central
# GWC: set([u'Urinary albumin excretion'])
# US:  set(['urinary albumin excretion'])
#
# 17903292 rs9305354 gwas_central
# GWC: set([u'Urinary albumin excretion'])
# US:  set(['urinary albumin excretion'])
#
# 17684544 rs2066847 gwas_central
# GWC: set([u"Crohn's disease"])
# US:  None
#
# 17684544 rs2076756 gwas_central
# GWC: set([u"Crohn's disease"])
# US:  None
#
# 17684544 rs2066844 gwas_central
# GWC: set([u"Crohn's disease"])
# US:  None
#
# 17684544 rs2066845 gwas_central
# GWC: set([u"Crohn's disease"])
# US:  None
#
# 17684544 rs1992660 gwas_central
# GWC: set([u"Crohn's disease"])
# US:  None
#
# 17684544 rs1992662 gwas_central
# GWC: set([u"Crohn's disease"])
# US:  None
#
# 17684544 rs11209026 gwas_central
# GWC: set([u"Crohn's disease"])
# US:  None
#
# 17684544 rs10484545 gwas_central
# GWC: set([u"Crohn's disease"])
# US:  None
#
# 17684544 rs1793004 gwas_central
# GWC: set([u"Crohn's disease"])
# US:  None
#
# 17684544 rs2241880 gwas_central
# GWC: set([u"Crohn's disease"])
# US:  None
#
# 17684544 rs1553575 gwas_central
# GWC: set([u"Crohn's disease"])
# US:  None
#
# 17684544 rs10513059 gwas_central
# GWC: set([u"Crohn's disease"])
# US:  None
#
# 17684544 rs200354 gwas_central
# GWC: set([u"Crohn's disease"])
# US:  None
#
# 17684544 rs7725052 gwas_central
# GWC: set([u"Crohn's disease"])
# US:  None
#
# 17684544 rs2009530 gwas_central
# GWC: set([u"Crohn's disease"])
# US:  None
#
# 17684544 rs10484543 gwas_central
# GWC: set([u"Crohn's disease"])
# US:  None
#
# 17903292 rs6977660 gwas_central
# GWC: set([u'Thyroid stimulating hormone'])
# US:  set(['thyroid stimulating hormone'])
#
# 17903292 rs9322817 gwas_central
# GWC: set([u'Thyroid stimulating hormone'])
# US:  set(['thyroid stimulating hormone'])
#
# 17903292 rs10499559 gwas_central
# GWC: set([u'Thyroid stimulating hormone'])
# US:  set(['thyroid stimulating hormone'])
#
# 17903292 rs1158167 gwas_central
# GWC: set([u'Cystatin C'])
# US:  set(['cystatin-c'])
#
# 17903293 rs1417352 gwas_central
# GWC: set([u'N-terminal pro-atrial natriuretic peptide'])
# US:  set(['Atrial natriuretic peptide exam 6'])
#
# 17903293 rs1486139 gwas_central
# GWC: set([u'N-terminal pro-atrial natriuretic peptide'])
# US:  set(['Atrial natriuretic peptide exam 6'])
#
# 17903293 rs1486140 gwas_central
# GWC: set([u'N-terminal pro-atrial natriuretic peptide'])
# US:  set(['Atrial natriuretic peptide exam 6'])
#
# 17903293 rs1079596 gwas_central
# GWC: set([u'N-terminal pro-atrial natriuretic peptide'])
# US:  set(['Atrial natriuretic peptide exam 6'])
#
# 17903292 rs1712790 gwas_central
# GWC: set([u'Urinary albumin excretion'])
# US:  set(['urinary albumin excretion'])
#
# 17903292 rs1243400 gwas_central
# GWC: set([u'Urinary albumin excretion'])
# US:  set(['urinary albumin excretion'])
#
# 17903292 rs9305354 gwas_central
# GWC: set([u'Urinary albumin excretion'])
# US:  set(['urinary albumin excretion'])
#
# 17903293 rs10489849 gwas_central
# GWC: set([u'Monocyte chemoattractant protein-1'])
# US:  set(['Monocyte chemoattractant protein-1'])
#
# 17903293 rs1474747 gwas_central
# GWC: set([u'Monocyte chemoattractant protein-1'])
# US:  set(['Monocyte chemoattractant protein-1'])
#
# 17903293 rs7778619 gwas_central
# GWC: set([u'Serum CD40 ligand'])
# US:  set(['CD40 Ligand serum'])
#
# 17903293 rs8005745 gwas_central
# GWC: set([u'Serum CD40 ligand'])
# US:  set(['CD40 Ligand serum'])
#
# 17903293 rs4664604 gwas_central
# GWC: set([u'Serum CD40 ligand'])
# US:  set(['CD40 Ligand serum'])
#
# 17903293 rs9288125 gwas_central
# GWC: set([u'Serum CD40 ligand'])
# US:  set(['CD40 Ligand serum'])
#
# 17903293 rs3849944 gwas_central
# GWC: set([u'Intracellular adhesion molecule-1'])
# US:  set(['Intercellular adhesion molecule-1'])
#
# 17903293 rs2372184 gwas_central
# GWC: set([u'Plasma CD40 ligand'])
# US:  set(['CD40 Ligand plasma'])
#
# 17903293 rs2387326 gwas_central
# GWC: set([u'Plasma vitamin K'])
# US:  set(['Vitamin K plasma phylloquinone'])
#
# 17903293 rs7552393 gwas_central
# GWC: set([u'Tumor necrosis factor alpha'])
# US:  set(['Tumor necrosis factor alpha'])
#
# 17903293 rs4911146 gwas_central
# GWC: set([u'Liver function test: alkaline phosphatase, AST, ALT, GGT'])
# US:  set(['Liver function: Alkaline phosphatase; AST; ALT; gamma-glutamyl transferase'])
#
# 17903293 rs953402 gwas_central
# GWC: set([u'Liver function test: alkaline phosphatase, AST, ALT, GGT'])
# US:  set(['Liver function: Alkaline phosphatase; AST; ALT; gamma-glutamyl transferase'])
#
# 17903293 rs1594468 gwas_central
# GWC: set([u'Bilirubin'])
# US:  None
#
# 17903293 rs496269 gwas_central
# GWC: set([u'Osteoprotegerin'])
# US:  set(['Osteoprotegerin'])
#
# 17903293 rs1998303 gwas_central
# GWC: set([u'Alanine aminotransferase'])
# US:  set(['Alanine aminotransferase'])
#
# 17903292 rs6977660 gwas_central
# GWC: set([u'Thyroid stimulating hormone'])
# US:  set(['thyroid stimulating hormone'])
#
# 17903292 rs9322817 gwas_central
# GWC: set([u'Thyroid stimulating hormone'])
# US:  set(['thyroid stimulating hormone'])
#
# 17903292 rs10499559 gwas_central
# GWC: set([u'Thyroid stimulating hormone'])
# US:  set(['thyroid stimulating hormone'])
#
# 17903293 rs10518765 gwas_central
# GWC: set([u'Alkaline phosphatase'])
# US:  set(['Alkaline phosphatase'])
#
# 17903293 rs2794520 gwas_central
# GWC: set([u'C-reactive protein'])
# US:  set(['C-reactive protein average exams 2,6,7', 'C-reactive protein exam 6'])
#
# 17903293 rs2808629 gwas_central
# GWC: set([u'C-reactive protein'])
# US:  set(['C-reactive protein average exams 2,6,7', 'C-reactive protein exam 6'])
#
# 17903293 rs746961 gwas_central
# GWC: set([u'C-reactive protein'])
# US:  set(['C-reactive protein exam 6'])
#
# 17903293 rs465384 gwas_central
# GWC: set([u'C-reactive protein'])
# US:  None
#
# 17903293 rs583012 gwas_central
# GWC: set([u'C-reactive protein'])
# US:  set(['C-reactive protein exam 2'])
#
# 17903293 rs1363258 gwas_central
# GWC: set([u'C-reactive protein'])
# US:  set(['C-reactive protein exam 7'])
#
# 17903293 rs717145 gwas_central
# GWC: set([u'Urinary isoprostanes/creatinine'])
# US:  set(['Urinary isoprostanes/creatinine'])
#
# 17903293 rs10485165 gwas_central
# GWC: set([u'Plasma vitamin D'])
# US:  set(['Vitamin D plasma 25(OH)-D'])
#
# 17903292 rs1158167 gwas_central
# GWC: set([u'Cystatin C'])
# US:  set(['cystatin-c'])
#
# 17903294 rs7159841 gwas_central
# GWC: set([u'Viscosity'])
# US:  set(['Viscosity'])
#
# 17903294 rs1397048 gwas_central
# GWC: set([u'Mean corpuscular hemoglobin'])
# US:  set(['mean corpuscular hemoglobin'])
#
# 17903294 rs2412522 gwas_central
# GWC: set([u'Mean corpuscular hemoglobin'])
# US:  set(['hemoglobin'])
#
# 17903294 rs1829883 gwas_central
# GWC: set([u'Mean corpuscular hemoglobin'])
# US:  set(['mean corpuscular hemoglobin'])
#
# 17903294 rs1200821 gwas_central
# GWC: set([u'Mean corpuscular hemoglobin'])
# US:  set(['mean corpuscular hemoglobin'])
#
# 17903294 rs9253 gwas_central
# GWC: set([u'Red blood cell count'])
# US:  set(['red blood cell count'])
#
# 17903294 rs10489087 gwas_central
# GWC: set([u'Red blood cell count'])
# US:  set(['red blood cell count'])
#
# 17903294 rs6108011 gwas_central
# GWC: set([u'Red blood cell count'])
# US:  set(['red blood cell count'])
#
# 17903294 rs636864 gwas_central
# GWC: set([u'Red blood cell count'])
# US:  set(['red blood cell count'])
#
# 17903294 rs727979 gwas_central
# GWC: set([u'Red blood cell count'])
# US:  set(['red blood cell count'])
#
# 17903294 rs6046 gwas_central
# GWC: set([u'Factor VII'])
# US:  None
#
# 17903294 rs561241 gwas_central
# GWC: set([u'Factor VII'])
# US:  set(['FVII, exam 5', 'factor vii'])
#
# 17903294 rs10488360 gwas_central
# GWC: set([u'Factor VII'])
# US:  set(['factor vii'])
#
# 17903294 rs966321 gwas_central
# GWC: set([u'Factor VII'])
# US:  set(['factor vii'])
#
# 17903294 rs727435 gwas_central
# GWC: set([u'Factor VII'])
# US:  set(['factor vii'])
#
# 17903294 rs565229 gwas_central
# GWC: set([u'Collagen-induced platelet aggregation'])
# US:  set(['platelet aggregation (collagen-induced)'])
#
# 17903294 rs10506458 gwas_central
# GWC: set([u'Collagen-induced platelet aggregation'])
# US:  set(['platelet aggregation (collagen-induced)'])
#
# 17903293 rs1417352 gwas_central
# GWC: set([u'N-terminal pro-atrial natriuretic peptide'])
# US:  set(['Atrial natriuretic peptide exam 6'])
#
# 17903293 rs1486139 gwas_central
# GWC: set([u'N-terminal pro-atrial natriuretic peptide'])
# US:  set(['Atrial natriuretic peptide exam 6'])
#
# 17903293 rs1486140 gwas_central
# GWC: set([u'N-terminal pro-atrial natriuretic peptide'])
# US:  set(['Atrial natriuretic peptide exam 6'])
#
# 17903293 rs1079596 gwas_central
# GWC: set([u'N-terminal pro-atrial natriuretic peptide'])
# US:  set(['Atrial natriuretic peptide exam 6'])
#
# 17903293 rs1376544 gwas_central
# GWC: set([u'Vitamin D, Vitamin K phylloquinone, Vitamin K % undercaboxylated osteocalcin'])
# US:  set(['Vitamin D, Vitamin K phylloquinone & Vitamin K % undercarboxylated osteocalcin'])
#
# 17903293 rs2494250 gwas_central
# GWC: set([u'Monocyte chemoattractant protein-1'])
# US:  set(['Monocyte chemoattractant protein-1'])
#
# 17903293 rs4128725 gwas_central
# GWC: set([u'Monocyte chemoattractant protein-1'])
# US:  set(['Monocyte chemoattractant protein-1'])
#
# 17903293 rs10489849 gwas_central
# GWC: set([u'Monocyte chemoattractant protein-1'])
# US:  set(['Monocyte chemoattractant protein-1'])
#
# 17903293 rs1474747 gwas_central
# GWC: set([u'Monocyte chemoattractant protein-1'])
# US:  set(['Monocyte chemoattractant protein-1'])
#
# 17903295 rs10496265 gwas_central
# GWC: set([u'Age at natural menopause'])
# US:  set(['Age at natural menopause\xe2\x80\xa1'])
#
# 17903295 rs10496262 gwas_central
# GWC: set([u'Age at natural menopause'])
# US:  set(['Age at natural menopause\xe2\x80\xa1'])
#
# 17903295 rs958672 gwas_central
# GWC: set([u'Age at natural menopause'])
# US:  set(['Age at natural menopause\xe2\x80\xa1'])
#
# 17903295 rs291353 gwas_central
# GWC: set([u'Age at natural menopause'])
# US:  set(['Age at natural menopause\xe2\x80\xa1'])
#
# 17903293 rs7778619 gwas_central
# GWC: set([u'Serum CD40 ligand'])
# US:  set(['CD40 Ligand serum'])
#
# 17903293 rs8005745 gwas_central
# GWC: set([u'Serum CD40 ligand'])
# US:  set(['CD40 Ligand serum'])
#
# 17903293 rs4664604 gwas_central
# GWC: set([u'Serum CD40 ligand'])
# US:  set(['CD40 Ligand serum'])
#
# 17903293 rs9288125 gwas_central
# GWC: set([u'Serum CD40 ligand'])
# US:  set(['CD40 Ligand serum'])
#
# 17903295 rs1412337 gwas_central
# GWC: set([u'Morbidity-free survival at age 65'])
# US:  set(['Morbidity-free survival at age 65'])
#
# 17903295 rs32566 gwas_central
# GWC: set([u'Morbidity-free survival at age 65'])
# US:  set(['Morbidity-free survival at age 65'])
#
# 17903295 rs10484246 gwas_central
# GWC: set([u'Morbidity-free survival at age 65'])
# US:  set(['Morbidity-free survival at age 65'])
#
# 17903293 rs3849944 gwas_central
# GWC: set([u'Intracellular adhesion molecule-1'])
# US:  set(['Intercellular adhesion molecule-1'])
#
# 17903295 rs2639889 gwas_central
# GWC: set([u'Morbidity-free survival at age 65'])
# US:  set(['Morbidity-free survival at age 65'])
#
# 17903293 rs2372184 gwas_central
# GWC: set([u'Plasma CD40 ligand'])
# US:  set(['CD40 Ligand plasma'])
#
# 17903293 rs2387326 gwas_central
# GWC: set([u'Plasma vitamin K'])
# US:  set(['Vitamin K plasma phylloquinone'])
#
# 17903293 rs7552393 gwas_central
# GWC: set([u'Tumor necrosis factor alpha'])
# US:  set(['Tumor necrosis factor alpha'])
#
# 17903295 rs1463605 gwas_central
# GWC: set([u'Biologic age by osseographic scoring system'])
# US:  set(['Biologic age by osseographic scoring system'])
#
# 17903293 rs4911146 gwas_central
# GWC: set([u'Liver function test: alkaline phosphatase, AST, ALT, GGT'])
# US:  set(['Liver function: Alkaline phosphatase; AST; ALT; gamma-glutamyl transferase'])
#
# 17903293 rs953402 gwas_central
# GWC: set([u'Liver function test: alkaline phosphatase, AST, ALT, GGT'])
# US:  set(['Liver function: Alkaline phosphatase; AST; ALT; gamma-glutamyl transferase'])
#
# 17903293 rs1594468 gwas_central
# GWC: set([u'Bilirubin'])
# US:  None
#
# 17903293 rs496269 gwas_central
# GWC: set([u'Osteoprotegerin'])
# US:  set(['Osteoprotegerin'])
#
# 17903295 rs1528753 gwas_central
# GWC: set([u'Age at death'])
# US:  set(['Age at death'])
#
# 17903295 rs10493513 gwas_central
# GWC: set([u'Age at death'])
# US:  set(['Age at death'])
#
# 17903295 rs2371208 gwas_central
# GWC: set([u'Age at death'])
# US:  set(['Age at death'])
#
# 17903295 rs10493514 gwas_central
# GWC: set([u'Age at death'])
# US:  set(['Age at death'])
#
# 17903295 rs2543600 gwas_central
# GWC: set([u'Age at death'])
# US:  set(['Age at death'])
#
# 17903295 rs7137869 gwas_central
# GWC: set([u'Walking speed at advanced age'])
# US:  set(['Walking speed exam 7'])
#
# 17903295 rs4471448 gwas_central
# GWC: set([u'Walking speed at advanced age'])
# US:  set(['Walking speed exam 7'])
#
# 17903293 rs1998303 gwas_central
# GWC: set([u'Alanine aminotransferase'])
# US:  set(['Alanine aminotransferase'])
#
# 17903293 rs10492681 gwas_central
# GWC: set([u'Alanine aminotransferase'])
# US:  set(['Alanine aminotransferase exam 2'])
#
# 17903293 rs2052028 gwas_central
# GWC: set([u'Vitamin K % undercarboxylated osteocalcin'])
# US:  set(['Vitamin K % undercarboxylated osteocalcin'])
#
# 17903293 rs437021 gwas_central
# GWC: set([u'B-type natriuretic peptide'])
# US:  set(['B-type natriuretic peptide'])
#
# 17903293 rs10518765 gwas_central
# GWC: set([u'Alkaline phosphatase'])
# US:  set(['Alkaline phosphatase'])
#
# 17903293 rs2794520 gwas_central
# GWC: set([u'C-reactive protein'])
# US:  set(['C-reactive protein average exams 2,6,7', 'C-reactive protein exam 6'])
#
# 17903293 rs2808629 gwas_central
# GWC: set([u'C-reactive protein'])
# US:  set(['C-reactive protein average exams 2,6,7', 'C-reactive protein exam 6'])
#
# 17903293 rs746961 gwas_central
# GWC: set([u'C-reactive protein'])
# US:  set(['C-reactive protein exam 6'])
#
# 17903293 rs465384 gwas_central
# GWC: set([u'C-reactive protein'])
# US:  None
#
# 17903293 rs583012 gwas_central
# GWC: set([u'C-reactive protein'])
# US:  set(['C-reactive protein exam 2'])
#
# 17903293 rs1363258 gwas_central
# GWC: set([u'C-reactive protein'])
# US:  set(['C-reactive protein exam 7'])
#
# 17903296 rs1590305 gwas_central
# GWC: set([u'Hip geometry, neck section modulus, gender differentiated in males'])
# US:  set(['neck section modulus**'])
#
# 17903296 rs7857590 gwas_central
# GWC: set([u'Hip geometry, neck section modulus, gender differentiated in males'])
# US:  set(['neck section modulus**'])
#
# 17903296 rs10503887 gwas_central
# GWC: set([u'Hip geometry, shaft section modulus'])
# US:  set(['shaft section modulus**'])
#
# 17903296 rs432446 gwas_central
# GWC: set([u'Hip geometery, neck shaft angle'])
# US:  set(['neck-shaft angle**'])
#
# 17903296 rs1552896 gwas_central
# GWC: set([u'Hip geometery, neck shaft angle'])
# US:  set(['neck-shaft angle**'])
#
# 17903293 rs717145 gwas_central
# GWC: set([u'Urinary isoprostanes/creatinine'])
# US:  set(['Urinary isoprostanes/creatinine'])
#
# 17903296 rs1538173 gwas_central
# GWC: set([u'Femoral neck bone mineral density'])
# US:  set(['femoral bmd**'])
#
# 17903293 rs10485165 gwas_central
# GWC: set([u'Plasma vitamin D'])
# US:  set(['Vitamin D plasma 25(OH)-D'])
#
# 17903293 rs10507577 gwas_central
# GWC: set([u'Plasma vitamin D'])
# US:  set(['Vitamin D plasma 25(OH)-D'])
#
# 17903294 rs7159841 gwas_central
# GWC: set([u'Viscosity'])
# US:  set(['Viscosity'])
#
# 17903296 rs4811196 gwas_central
# GWC: set([u'Trochanter bone mineral density, gender differentiated in females'])
# US:  set(['trochanter bmd**'])
#
# 17903294 rs1397048 gwas_central
# GWC: set([u'Mean corpuscular hemoglobin'])
# US:  set(['mean corpuscular hemoglobin'])
#
# 17903294 rs2412522 gwas_central
# GWC: set([u'Mean corpuscular hemoglobin'])
# US:  set(['hemoglobin'])
#
# 17903294 rs1829883 gwas_central
# GWC: set([u'Mean corpuscular hemoglobin'])
# US:  set(['mean corpuscular hemoglobin'])
#
# 17903294 rs1200821 gwas_central
# GWC: set([u'Mean corpuscular hemoglobin'])
# US:  set(['mean corpuscular hemoglobin'])
#
# 17903294 rs9253 gwas_central
# GWC: set([u'Red blood cell count'])
# US:  set(['red blood cell count'])
#
# 17903294 rs10489087 gwas_central
# GWC: set([u'Red blood cell count'])
# US:  set(['red blood cell count'])
#
# 17903294 rs6108011 gwas_central
# GWC: set([u'Red blood cell count'])
# US:  set(['red blood cell count'])
#
# 17903294 rs636864 gwas_central
# GWC: set([u'Red blood cell count'])
# US:  set(['red blood cell count'])
#
# 17903294 rs727979 gwas_central
# GWC: set([u'Red blood cell count'])
# US:  set(['red blood cell count'])
#
# 17903296 rs3762397 gwas_central
# GWC: set([u'Trochanter bone mineral density'])
# US:  set(['trochanter bmd**'])
#
# 17903296 rs10506701 gwas_central
# GWC: set([u'Trochanter bone mineral density'])
# US:  set(['trochanter bmd**'])
#
# 17903296 rs914951 gwas_central
# GWC: set([u'Trochanter bone mineral density'])
# US:  set(['trochanter bmd**'])
#
# 17903296 rs9317284 gwas_central
# GWC: set([u'Femoral neck bone mineral density, gender differentiated in males'])
# US:  set(['femoral bmd**'])
#
# 17903296 rs10508076 gwas_central
# GWC: set([u'Femoral neck bone mineral density, gender differentiated in males'])
# US:  set(['femoral bmd**'])
#
# 17903296 rs2054989 gwas_central
# GWC: set([u'Hip geometry, neck width, gender differentiated in females'])
# US:  set(['neck width**'])
#
# 17903296 rs1395548 gwas_central
# GWC: set([u'Hip geometry, neck width, gender differentiated in females'])
# US:  set(['neck width**'])
#
# 17903296 rs4715166 gwas_central
# GWC: set([u'Hip geometry, neck width, gender differentiated in females'])
# US:  set(['neck width**'])
#
# 17903296 rs4143244 gwas_central
# GWC: set([u'Hip geometry, neck width'])
# US:  set(['NeckW1'])
#
# 17903294 rs6046 gwas_central
# GWC: set([u'Factor VII'])
# US:  None
#
# 17903294 rs561241 gwas_central
# GWC: set([u'Factor VII'])
# US:  set(['FVII, exam 5', 'factor vii'])
#
# 17903294 rs10488360 gwas_central
# GWC: set([u'Factor VII'])
# US:  set(['factor vii'])
#
# 17903294 rs966321 gwas_central
# GWC: set([u'Factor VII'])
# US:  set(['factor vii'])
#
# 17903294 rs727435 gwas_central
# GWC: set([u'Factor VII'])
# US:  set(['factor vii'])
#
# 17903296 rs991258 gwas_central
# GWC: set([u'Hip geometry, shaft width'])
# US:  set(['shaft width**'])
#
# 17903297 rs7124781 gwas_central
# GWC: set([u'Brain MRI, lateral ventricular volume'])
# US:  set(['ALLV'])
#
# 17903297 rs2847476 gwas_central
# GWC: set([u'Brain MRI, lateral ventricular volume'])
# US:  set(['ALLV'])
#
# 17903297 rs952700 gwas_central
# GWC: set([u'Brain MRI, frontal brain volume'])
# US:  set(['frontal brain volume'])
#
# 17903297 rs3852286 gwas_central
# GWC: set([u'Brain MRI, frontal brain volume'])
# US:  set(['frontal brain volume'])
#
# 17903297 rs5028798 gwas_central
# GWC: set([u'Brain MRI, temporal brain volume'])
# US:  set(['temporal brain volume'])
#
# 17903297 rs1155865 gwas_central
# GWC: set([u'Cognitive performance, Boston naming test'])
# US:  set(['boston naming test'])
#
# 17903297 rs530965 gwas_central
# GWC: set([u'Cognitive performance, Boston naming test'])
# US:  set(['boston naming test'])
#
# 17903297 rs9303401 gwas_central
# GWC: set([u'Cognitive performance, Boston naming test'])
# US:  set(['boston naming test'])
#
# 17903297 rs1831521 gwas_central
# GWC: set([u'Cognitive performance, Boston naming test'])
# US:  set(['boston naming test'])
#
# 17903297 rs3891355 gwas_central
# GWC: set([u'Cognitive performance, similarities'])
# US:  set(['similarities'])
#
# 17903297 rs1131497 gwas_central
# GWC: set([u'Cognitive performance, similarities'])
# US:  set(['similarities'])
#
# 17903297 rs360929 gwas_central
# GWC: set([u'Brain MRI, temporal horn volume'])
# US:  set(['ALTHBV'])
#
# 17903297 rs1970546 gwas_central
# GWC: set([u'Brain MRI, total cerebral brain volume'])
# US:  set(['total cerebral brain volume'])
#
# 17903297 rs502309 gwas_central
# GWC: set([u'Brain MRI, total cerebral brain volume'])
# US:  set(['total cerebral brain volume'])
#
# 17903297 rs2179965 gwas_central
# GWC: set([u'Cognitive performance, attention and executive function'])
# US:  set(['factor 3: measure of attention and executive function-trails a and b'])
#
# 17903297 rs2832077 gwas_central
# GWC: set([u'Cognitive performance, attention and executive function'])
# US:  set(['factor 3: measure of attention and executive function-trails a and b'])
#
# 17903297 rs1031381 gwas_central
# GWC: set([u'Cognitive performance, attention and executive function'])
# US:  set(['factor 3: measure of attention and executive function-trails a and b'])
#
# 17903297 rs934299 gwas_central
# GWC: set([u'Cognitive performance, attention and executive function'])
# US:  set(['factor 3: measure of attention and executive function-trails a and b'])
#
# 17903297 rs2352904 gwas_central
# GWC: set([u'Cognitive performance, visual memory and organization'])
# US:  set(['factor 2:visual memory and organization'])
#
# 17903297 rs6914079 gwas_central
# GWC: set([u'Cognitive performance, visual memory and organization'])
# US:  set(['factor 2:visual memory and organization'])
#
# 17903297 rs9325032 gwas_central
# GWC: set([u'Cognitive performance, visual memory and organization'])
# US:  set(['factor 2:visual memory and organization'])
#
# 17903297 rs10489896 gwas_central
# GWC: set([u'Cognitive performance, visual memory and organization'])
# US:  set(['factor 2:visual memory and organization'])
#
# 17903297 rs2893363 gwas_central
# GWC: set([u'Cognitive performance, visual memory and organization'])
# US:  set(['factor 2:visual memory and organization'])
#
# 17903297 rs10506065 gwas_central
# GWC: set([u'Cognitive performance, wide-range achievement test'])
# US:  set(['wide-range achievement test'])
#
# 17903297 rs9300212 gwas_central
# GWC: set([u'Cognitive performance, wide-range achievement test'])
# US:  set(['wide-range achievement test'])
#
# 17903298 rs180730 gwas_central
# GWC: set([u'Fasting plasma glucose'])
# US:  set(['28 yr time averaged fpg', 'fasting plasma glucose'])
#
# 17903298 rs7731657 gwas_central
# GWC: set([u'28-yr time-averaged fasting plasma glucose'])
# US:  set(['28 yr time averaged fpg'])
#
# 17903298 rs10486607 gwas_central
# GWC: set([u'Glycated hemoglobin'])
# US:  set(['hemoglobin a1c'])
#
# 17903298 rs2066219 gwas_central
# GWC: set([u'0- to 120-min insulin sensitivity index'])
# US:  set(['0\xe2\x80\x93120 min insulin sensitivity'])
#
# 17903300 rs4471028 gwas_central
# GWC: set([u'Mean waist circumference'])
# US:  set(['Mean waist circumference'])
#
# 17903300 rs4469448 gwas_central
# GWC: set([u'Mean waist circumference'])
# US:  set(['Mean waist circumference'])
#
# 17903300 rs6996971 gwas_central
# GWC: set([u'Mean waist circumference'])
# US:  set(['Mean waist circumference'])
#
# 17903300 rs10504576 gwas_central
# GWC: set([u'Mean waist circumference'])
# US:  set(['Mean waist circumference'])
#
# 17903300 rs1875517 gwas_central
# GWC: set([u'Mean waist circumference'])
# US:  set(['Mean waist circumference'])
#
# 17903300 rs10488165 gwas_central
# GWC: set([u'Mean waist circumference'])
# US:  set(['Mean waist circumference'])
#
# 17903300 rs2206682 gwas_central
# GWC: set([u'Mean waist circumference'])
# US:  set(['Mean waist circumference'])
#
# 17903300 rs2223662 gwas_central
# GWC: set([u'Mean waist circumference'])
# US:  set(['Mean waist circumference'])
#
# 17903300 rs953536 gwas_central
# GWC: set([u'Mean waist circumference'])
# US:  set(['Mean waist circumference'])
#
# 17903300 rs1106683 gwas_central
# GWC: set([u'Mean body mass index'])
# US:  set(['Mean body mass index'])
#
# 17903300 rs1106684 gwas_central
# GWC: set([u'Mean body mass index'])
# US:  set(['Mean body mass index'])
#
# 17903300 rs1333026 gwas_central
# GWC: set([u'Mean body mass index'])
# US:  set(['Mean body mass index'])
#
# 17903301 rs10504543 gwas_central
# GWC: set([u'Left ventricular systolic dimension'])
# US:  set(['left ventricular systolic dimension', 'Across left ventricular phenotypes'])
#
# 17903301 rs1392284 gwas_central
# GWC: set([u'Left ventricular systolic dimension'])
# US:  set(['left ventricular systolic dimension'])
#
# 17903301 rs10498091 gwas_central
# GWC: set([u'Left ventricular mass'])
# US:  set(['left ventricular mass', 'Across left ventricular phenotypes'])
#
# 17903301 rs6847149 gwas_central
# GWC: set([u'Stage 2 exercise heart rate'])
# US:  set(['Stage 2 Exercise heart rate'])
#
# 17903301 rs2819770 gwas_central
# GWC: set([u'Stage 2 exercise heart rate'])
# US:  set(['Stage 2 Exercise heart rate'])
#
# 17903301 rs2056387 gwas_central
# GWC: set([u'Stage 2 exercise heart rate'])
# US:  set(['Across phenotypes', 'Stage 2 Exercise heart rate'])
#
# 17903301 rs1958055 gwas_central
# GWC: set([u'Stage 2 exercise heart rate'])
# US:  set(['Stage 2 Exercise heart rate'])
#
# 17903301 rs2553268 gwas_central
# GWC: set([u'Stage 2 exercise systolic blood pressure'])
# US:  set(['Stage 2 Exercise systolic blood pressure'])
#
# 17903301 rs3814219 gwas_central
# GWC: set([u'Baseline brachial artery flow velocity'])
# US:  set(['Baseline brachial artery flow velocity'])
#
# 17903301 rs1379659 gwas_central
# GWC: set([u'Left ventricular diastolic dimension'])
# US:  set(['Across left ventricular phenotypes', 'left ventricular diastolic dimension'])
#
# 17903301 rs666088 gwas_central
# GWC: set([u'Left ventricular diastolic dimension'])
# US:  set(['left ventricular diastolic dimension'])
#
# 17903301 rs4920799 gwas_central
# GWC: set([u'Left ventricular diastolic dimension'])
# US:  set(['left ventricular diastolic dimension'])
#
# 17903301 rs2016718 gwas_central
# GWC: set([u'Post-exercise 3 minute recovery: systolic blood pressure'])
# US:  set(['Post-exercise 3 minute recovery systolic blood pressure'])
#
# 17903301 rs746463 gwas_central
# GWC: set([u'Post-exercise 3 minute recovery: systolic blood pressure'])
# US:  set(['Post-exercise 3 minute recovery systolic blood pressure'])
#
# 17903301 rs7828552 gwas_central
# GWC: set([u'Post-exercise 3 minute recovery: systolic blood pressure'])
# US:  set(['Post-exercise 3 minute recovery systolic blood pressure'])
#
# 17903301 rs366676 gwas_central
# GWC: set([u'Left ventricular fractional shortening'])
# US:  set(['left ventricular fractional shortening'])
#
# 17903301 rs1935881 gwas_central
# GWC: set([u'Left atrial diameter'])
# US:  set(['Left atrial diameter'])
#
# 17903301 rs10493389 gwas_central
# GWC: set([u'Left atrial diameter'])
# US:  set(['Left atrial diameter'])
#
# 17903301 rs1029947 gwas_central
# GWC: set([u'Post-exercise 3 minute recovery: heart rate'])
# US:  set(['Post-exercise 3 minute recovery heart rate'])
#
# 17903301 rs1029946 gwas_central
# GWC: set([u'Post-exercise 3 minute recovery: heart rate'])
# US:  set(['Post-exercise 3 minute recovery heart rate'])
#
# 17903302 rs3773643 gwas_central
# GWC: set([u'Mean artierial pressure'])
# US:  set(['MAP'])
#
# 17903302 rs1322512 gwas_central
# GWC: set([u'Mean artierial pressure'])
# US:  set(['MAP'])
#
# 17903302 rs770189 gwas_central
# GWC: set([u'Carotid-brachial pulse wave velocity'])
# US:  set(['CB-PWV'])
#
# 17903302 rs10514688 gwas_central
# GWC: set([u'Carotid-brachial pulse wave velocity'])
# US:  set(['CB-PWV'])
#
# 17903302 rs7042864 gwas_central
# GWC: set([u'Carotid-brachial pulse wave velocity'])
# US:  set(['CB-PWV'])
#
# 17903302 rs1367248 gwas_central
# GWC: set([u'Carotid-femoral pulse wave velocity'])
# US:  set(['CF-PWV'])
#
# 17903302 rs10521232 gwas_central
# GWC: set([u'Carotid-femoral pulse wave velocity'])
# US:  set(['CF-PWV'])
#
# 17903302 rs6063312 gwas_central
# GWC: set([u'Reflected wave amplitude'])
# US:  set(['RW'])
#
# 17903302 rs1116260 gwas_central
# GWC: set([u'Reflected wave amplitude'])
# US:  None
#
# 17903302 rs1371924 gwas_central
# GWC: set([u'Reflected wave amplitude'])
# US:  set(['RW'])
#
# 17903302 rs792833 gwas_central
# GWC: set([u'Reflected wave amplitude'])
# US:  set(['RW'])
#
# 17903302 rs10488172 gwas_central
# GWC: set([u'Reflected wave amplitude'])
# US:  set(['RW'])
#
# 17903302 rs7591163 gwas_central
# GWC: set([u'Diastolic blood pressure'])
# US:  set(['blood-pressure'])
#
# 17903302 rs1590919 gwas_central
# GWC: set([u'Diastolic blood pressure'])
# US:  set(['blood-pressure'])
#
# 17903302 rs636864 gwas_central
# GWC: set([u'Diastolic blood pressure'])
# US:  set(['blood-pressure'])
#
# 17903302 rs1963982 gwas_central
# GWC: set([u'Diastolic blood pressure'])
# US:  set(['blood-pressure'])
#
# 17903302 rs935334 gwas_central
# GWC: set([u'Diastolic blood pressure'])
# US:  set(['blood-pressure'])
#
# 17903302 rs4370013 gwas_central
# GWC: set([u'Diastolic blood pressure'])
# US:  set(['blood-pressure'])
#
# 17903302 rs10491334 gwas_central
# GWC: set([u'Diastolic blood pressure'])
# US:  set(['blood-pressure'])
#
# 17903302 rs2121070 gwas_central
# GWC: set([u'Diastolic blood pressure'])
# US:  set(['blood-pressure'])
#
# 17903302 rs2509458 gwas_central
# GWC: set([u'Diastolic blood pressure'])
# US:  set(['blood-pressure'])
#
# 17903302 rs3793427 gwas_central
# GWC: set([u'Forward wave amplitude'])
# US:  set(['FW'])
#
# 17903302 rs3766680 gwas_central
# GWC: set([u'Forward wave amplitude'])
# US:  set(['FW'])
#
# 17903302 rs1539377 gwas_central
# GWC: set([u'Forward wave amplitude'])
# US:  set(['FW'])
#
# 17903302 rs3096277 gwas_central
# GWC: set([u'Systolic blood pressure'])
# US:  set(['blood-pressure'])
#
# 17903302 rs10493340 gwas_central
# GWC: set([u'Systolic blood pressure'])
# US:  set(['blood-pressure'])
#
# 17903302 rs1588260 gwas_central
# GWC: set([u'Systolic blood pressure'])
# US:  set(['blood-pressure'])
#
# 17903303 rs2390582 gwas_central
# GWC: set([u'Coronary artery calcification'])
# US:  set(['Coronary artery calcification'])
#
# 17903303 rs10483853 gwas_central
# GWC: set([u'Coronary artery calcification'])
# US:  set(['Coronary artery calcification'])
#
# 17903303 rs10507130 gwas_central
# GWC: set([u'Coronary artery calcification'])
# US:  set(['Coronary artery calcification'])
#
# 17903303 rs10499903 gwas_central
# GWC: set([u'Ankle brachial index'])
# US:  set(['Ankle brachial index'])
#
# 17903303 rs2896103 gwas_central
# GWC: set([u'Ankle brachial index'])
# US:  set(['Ankle brachial index'])
#
# 17903303 rs9302997 gwas_central
# GWC: set([u'Ankle brachial index'])
# US:  set(['Ankle brachial index'])
#
# 17903303 rs7715811 gwas_central
# GWC: set([u'Ankle brachial index'])
# US:  set(['Ankle brachial index'])
#
# 17903303 rs1320267 gwas_central
# GWC: set([u'Ankle brachial index'])
# US:  set(['Ankle brachial index'])
#
# 17903303 rs1350445 gwas_central
# GWC: set([u'Ankle brachial index'])
# US:  set(['Ankle brachial index'])
#
# 17903303 rs590183 gwas_central
# GWC: set([u'Ankle brachial index'])
# US:  set(['Ankle brachial index'])
#
# 17903303 rs1502050 gwas_central
# GWC: set([u'Ankle brachial index'])
# US:  set(['Ankle brachial index'])
#
# 17903303 rs4814615 gwas_central
# GWC: set([u'Common carotid artery intimal medial thickness'])
# US:  set(['Common carotid artery intimal medial thickness'])
#
# 17903303 rs6053733 gwas_central
# GWC: set([u'Common carotid artery intimal medial thickness'])
# US:  set(['Common carotid artery intimal medial thickness'])
#
# 17903303 rs1400544 gwas_central
# GWC: set([u'Common carotid artery intimal medial thickness'])
# US:  set(['Common carotid artery intimal medial thickness'])
#
# 17903303 rs1376877 gwas_central
# GWC: set([u'Internal carotid artery intimal medial thickness'])
# US:  set(['Internal carotid artery intimal medial thickness'])
#
# 17903303 rs3849150 gwas_central
# GWC: set([u'Abdominal aortic calcification'])
# US:  set(['Abdominal aortic calcification'])
#
# 17903304 rs740363 gwas_central
# GWC: set([u'Heart failure'])
# US:  set(['heart failure'])
#
# 17903304 rs2549513 gwas_central
# GWC: set([u'Coronary heart disease including myocardial infarction, coronary insufficiency, CHD death'])
# US:  set(['Major coronary heart disease'])
#
# 17903304 rs958546 gwas_central
# GWC: set([u'Atrial fibrillation'])
# US:  set(['atrial fibrillation'])
#
# 17903304 rs4776472 gwas_central
# GWC: set([u'Atrial fibrillation'])
# US:  set(['atrial fibrillation'])
#
# 17903304 rs10501920 gwas_central
# GWC: set([u'Atrial fibrillation'])
# US:  set(['atrial fibrillation'])
#
# 17903304 rs499818 gwas_central
# GWC: set([u'Cardiovascular disease including myocardial infarction, coronary insufficiency, CHD death, atherothrombotic stroke'])
# US:  set(['Major cardiovascular disease'])
