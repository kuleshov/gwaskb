# %% [markdown]
# # Evaluation notebook

# %% [markdown]
# Here, we will evaluate the relations extracted in all the other notebooks

# %%
# %load_ext autoreload
# %autoreload 2

import sys
import cPickle
import numpy as np

# import snorkel and gwasdb
sys.path.append('../snorkel')
sys.path.append('../src')
sys.path.append('../src/crawler')

# set up paths
abstract_dir = '../data/db/papers'

# %%
from snorkel.parser import XMLDocParser, HTMLParser, CorpusParser
from extractor.parser import UnicodeXMLTableDocParser, UnicodeTableParser

xml_parser = UnicodeXMLTableDocParser(
    path=abstract_dir,
    doc='./*',
    text='.//table',
    id='.//article-id[@pub-id-type="pmid"]/text()',
    keep_xml_tree=True)

table_parser = UnicodeTableParser()
html_parser = HTMLParser(path='../data/db/papers/')
cp = CorpusParser(xml_parser, table_parser)
# %time corpus = cp.parse_corpus(name='GWAS Corpus')
# Out:
# CPU times: user 14min 49s, sys: 47.4 s, total: 15min 37s
# Wall time: 23min 30s

# %% [markdown]
# ## Loading results from other notebooks

# %% [markdown]
# #### Phenotype/rsid relations from tables

# %%
phen_table_associations = dict()
with open('phen-rsid.table.rel.all.tsv') as f:
    for line in f:
        fields = line.strip().split('\t')
        pmid, rsid, phen, pval, _, table_id, row_id, col_id = fields
        # note that we assume that an rsid at a givel location will correspond to 1 phenotype
        phen_table_associations[pmid, table_id, row_id, col_id] = (rsid, phen)
        
print len(phen_table_associations), 'loaded, e.g.:'
print phen_table_associations.items()[:5]
# Out:
# 2130 loaded, e.g.:
# [(('21347282', '1', '3', '1'), ('rs937254', 'HDL-C')), (('23836780', '0', '3', '1'), ('rs3213787', 'Glaucoma')), (('17903302', '4', '31', '2'), ('rs9307847', 'CB-PWV')), (('17903307', '3', '2', '2'), ('rs9325117', 'longitudinal slope of fef mean fev')), (('17903298', '3', '12', '3'), ('rs10510418', 'Fasting insulin'))]

# %% [markdown]
# #### PMID/Phenotype relations extracted from titles/abstracts

# %%
phen_text_associations = dict()
with open('phenotypes.extracted.tsv') as f:
    for line in f:
        pmid, phen = line.strip().split('\t')
        phen_text_associations[pmid] = phen
        
print len(phen_text_associations), 'loaded, e.g.:'
print phen_text_associations.items()[:5]
# Out:
# 589 loaded, e.g.:
# [('23738518', 'reading|language'), ('19056611', 'Type 2 Diabetes'), ('21298047', 'European-Origin|Substance Dependence'), ('23104006', 'endometriosis'), ('20072603', 'Osteoporosis')]

# %% [markdown]
# #### RSID/Pvalue relations extracted from tables

# %%
pval_table_associations = dict()
with open('pval-rsid.raw.tsv') as f:
    for line in f:
        pmid, rsid, table_id, row_id, col_id, pval = line.strip().split('\t')
        pval, table_id, row_id, col_id = float(pval), int(table_id), int(row_id), int(col_id)
        
        key = pmid, table_id, row_id, col_id, rsid
        if key not in pval_table_associations: pval_table_associations[key] = set()
        pval_table_associations[key].add(pval)

print len(pval_table_associations), 'loaded, e.g.:'
print pval_table_associations.items()[:5]
# Out:
# 10681 loaded, e.g.:
# [(('22504420', 0, 33, 0, 'rs4790881'), set([0.0, 0.0006, 2e-06])), (('22396660', 1, 6, 1, 'rs11746443'), set([0.98])), (('17903302', 1, 21, 2, 'rs1408263'), set([2.4e-05])), (('17903294', 2, 20, 1, 'rs727979'), set([2.6e-05, 7e-06])), (('17903307', 1, 47, 1, 'rs1409149'), set([9e-06]))]

# %% [markdown]
# #### Singleton RSids

# %%
singleton_associations = dict()
with open('rsids.singletons.all.tsv') as f:
    for line in f:
        pmid, table_id, row_num, col_num, rsid = line.strip().split()
        singleton_associations[pmid, table_id, row_num, col_num] = rsid

print len(singleton_associations), 'loaded, e.g.:'
print singleton_associations.items()[:5]
# Out:
# 12309 loaded, e.g.:
# [(('17903303', '2', '9', '2'), 'rs28207'), (('25742292', '1', '13', '5'), 'rs7919841'), (('17903302', '4', '31', '2'), 'rs9307847'), (('25129146', '0', '2', '0'), 'rs7447927'), (('19096518', '0', '3', '0'), 'rs563694')]

# %% [markdown]
# ## Construct a list valid relations

# %%
# TODO: load pvalues properly, use them to filter stuff downstream, do acroynm resolution here

# %%
import re

def clean(phen):
    phen = re.sub('[)():.]+', '', phen)
    phen = re.sub('^or ', '', phen)
    phen = phen.strip()
    return phen

associations = []

# record table associations wth pval < 1e-5 or no pval reported
chosen_rsids = set()
for (pmid, table_id, row_id, col_id), (rsid, loc_phen) in phen_table_associations.items():
    pvals = pval_table_associations.get((pmid, table_id, row_id, col_id, rsid), [-1])
    glob_phen = clean(phen_text_associations[pmid])
    if min(pvals) < 1e-5:
        associations.append((pmid, rsid, (glob_phen, loc_phen)))
        chosen_rsids.add((pmid, table_id, row_id, col_id, rsid))


# record associations with no local phenotype
for (pmid, table_id, row_id, col_id, rsid), pvals in pval_table_associations.items():
    # skip low-pvalue snps and snps that we already added
    if pvals and min(pvals) > 1e-5: continue
    if (pmid, table_id, row_id, col_id, rsid) in chosen_rsids: continue
    
    # append with global phenotype
    phen = clean(phen_text_associations[pmid])
    associations.append((pmid, rsid, (phen, '')))    
    chosen_rsids.add((pmid, table_id, row_id, col_id, rsid))

# record singletons
tables_found = {table_id for _, table_id, _, _, _ in pval_table_associations}
for (pmid, table_id, row_id, col_id), rsid in singleton_associations.items():
    if (pmid, table_id, row_id, col_id, rsid) in chosen_rsids: continue
    if table_id in tables_found: continue
    phen = clean(phen_text_associations[pmid])
    associations.append((pmid, rsid, (phen, '')))

# %% [markdown]
# ## Comparing to GWAS central

# %%
from db.kb import KnowledgeBase

kb = KnowledgeBase()
assocs = [assoc for doc in corpus.documents for assoc in kb.assoc_by_pmid(doc.name) if assoc.source == 'gwas_central' and assoc.pvalue < 1e-5]

print '%d documents, %d associations' % (len(corpus.documents), len(assocs))
# Out:
# 589 documents, 7629 associations

# %%
rel_dict = { (pmid, rsid) : set() for (pmid, rsid, phen) in associations }
for (pmid, rsid, phen) in associations:
    rel_dict[(pmid, rsid)].add(phen)

gold_rel_dict = { (a.paper.pubmed_id, a.snp.rs_id) : set() for a in assocs }
for a in assocs:
    gold_rel_dict[(a.paper.pubmed_id, a.snp.rs_id)].add(a.phenotype.name)

# %%
# display directly the results we found
for doc in corpus.documents:
#     continue
    rsids_seen = set()
    for a in assocs:
        if str(a.paper.pubmed_id) != doc.name: continue
        rsids_seen.add(a.snp.rs_id)
        
        print a.paper.pubmed_id, a.snp.rs_id, a.source
        print 'GWC:', gold_rel_dict[(a.paper.pubmed_id, a.snp.rs_id)]
        print 'US: ', rel_dict.get((str(a.paper.pubmed_id), a.snp.rs_id), None)
        print
    
    for (pmid, rsid), phens in rel_dict.items():
        if pmid != doc.name: continue
        if rsid in rsids_seen: continue
        print pmid, rsid, phens
    print '---'
# Out:
# 17447842 rs11209026 gwas_central
# GWC: set([u"Crohn's disease"])
# US:  None
#
# 17447842 rs11465804 gwas_central
# GWC: set([u"Crohn's disease"])
# US:  None
#
# 17447842 rs1373692 gwas_central
# GWC: set([u"Crohn's disease"])
# US:  None
#
# 17447842 rs10512734 gwas_central
# GWC: set([u"Crohn's disease"])
# US:  None
#
# 17447842 rs4613763 gwas_central
# GWC: set([u"Crohn's disease"])
# US:  None
#
# 17447842 rs1002922 gwas_central
# GWC: set([u"Crohn's disease"])
# US:  None
#
# 17447842 rs1343151 gwas_central
# GWC: set([u"Crohn's disease"])
# US:  None
#
# 17447842 rs4495224 gwas_central
# GWC: set([u"Crohn's disease"])
# US:  None
#
# 17447842 rs348601 gwas_central
# GWC: set([u"Crohn's disease"])
# US:  None
#
# 17447842 rs5743289 gwas_central
# GWC: set([u"Crohn's disease"])
# US:  None
#
# 17447842 rs10889677 gwas_central
# GWC: set([u"Crohn's disease"])
# US:  None
#
# 17447842 rs11209026 gwas_central
# GWC: set([u"Crohn's disease"])
# US:  None
#
# 17447842 rs11465804 gwas_central
# GWC: set([u"Crohn's disease"])
# US:  None
#
# 17447842 rs1373692 gwas_central
# GWC: set([u"Crohn's disease"])
# US:  None
#
# 17447842 rs10512734 gwas_central
# GWC: set([u"Crohn's disease"])
# US:  None
#
# 17447842 rs4613763 gwas_central
# GWC: set([u"Crohn's disease"])
# US:  None
#
# 17447842 rs1002922 gwas_central
# GWC: set([u"Crohn's disease"])
# US:  None
#
# 17447842 rs1343151 gwas_central
# GWC: set([u"Crohn's disease"])
# US:  None
#
# 17447842 rs4495224 gwas_central
# GWC: set([u"Crohn's disease"])
# US:  None
#
# 17447842 rs348601 gwas_central
# GWC: set([u"Crohn's disease"])
# US:  None
#
# 17447842 rs5743289 gwas_central
# GWC: set([u"Crohn's disease"])
# US:  None
#
# 17447842 rs10889677 gwas_central
# GWC: set([u"Crohn's disease"])
# US:  None
#
# ---
# 17658951 rs9930506 gwas_central
# GWC: set([u'Hip circumference'])
# US:  None
#
# 17658951 rs8050136 gwas_central
# GWC: set([u'Hip circumference'])
# US:  None
#
# 17658951 rs9940128 gwas_central
# GWC: set([u'Hip circumference'])
# US:  None
#
# 17658951 rs9939973 gwas_central
# GWC: set([u'Hip circumference'])
# US:  None
#
# 17658951 rs1121980 gwas_central
# GWC: set([u'Hip circumference'])
# US:  None
#
# 17658951 rs7193144 gwas_central
# GWC: set([u'Hip circumference'])
# US:  None
#
# 17658951 rs9939609 gwas_central
# GWC: set([u'Hip circumference'])
# US:  None
#
# 17658951 rs9926289 gwas_central
# GWC: set([u'Hip circumference'])
# US:  None
#
# 17658951 rs965670 gwas_central
# GWC: set([u'Hip circumference'])
# US:  None
#
# 17658951 rs2180579 gwas_central
# GWC: set([u'Hip circumference'])
# US:  None
#
# 17658951 rs6602024 gwas_central
# GWC: set([u'Body mass index'])
# US:  None
#
# 17658951 rs658838 gwas_central
# GWC: set([u'Body mass index'])
# US:  None
#
# 17658951 rs41512445 gwas_central
# GWC: set([u'Weight'])
# US:  None
#
# 17658951 rs9930506 gwas_central
# GWC: set([u'Hip circumference'])
# US:  None
#
# 17658951 rs8050136 gwas_central
# GWC: set([u'Hip circumference'])
# US:  None
#
# 17658951 rs9940128 gwas_central
# GWC: set([u'Hip circumference'])
# US:  None
#
# 17658951 rs9939973 gwas_central
# GWC: set([u'Hip circumference'])
# US:  None
#
# 17658951 rs1121980 gwas_central
# GWC: set([u'Hip circumference'])
# US:  None
#
# 17658951 rs7193144 gwas_central
# GWC: set([u'Hip circumference'])
# US:  None
#
# 17658951 rs9939609 gwas_central
# GWC: set([u'Hip circumference'])
# US:  None
#
# 17658951 rs9926289 gwas_central
# GWC: set([u'Hip circumference'])
# US:  None
#
# 17658951 rs965670 gwas_central
# GWC: set([u'Hip circumference'])
# US:  None
#
# 17658951 rs2180579 gwas_central
# GWC: set([u'Hip circumference'])
# US:  None
#
# 17658951 rs6602024 gwas_central
# GWC: set([u'Body mass index'])
# US:  None
#
# 17658951 rs658838 gwas_central
# GWC: set([u'Body mass index'])
# US:  None
#
# 17658951 rs41512445 gwas_central
# GWC: set([u'Weight'])
# US:  None
#
# ---
# 17684544 rs2066847 gwas_central
# GWC: set([u"Crohn's disease"])
# US:  set([('IBD Disease', '')])
#
# 17684544 rs2076756 gwas_central
# GWC: set([u"Crohn's disease"])
# US:  set([('IBD Disease', '')])
#
# 17684544 rs2066844 gwas_central
# GWC: set([u"Crohn's disease"])
# US:  set([('IBD Disease', '')])
#
# 17684544 rs2066845 gwas_central
# GWC: set([u"Crohn's disease"])
# US:  set([('IBD Disease', '')])
#
# 17684544 rs1992660 gwas_central
# GWC: set([u"Crohn's disease"])
# US:  set([('IBD Disease', '')])
#
# 17684544 rs1992662 gwas_central
# GWC: set([u"Crohn's disease"])
# US:  set([('IBD Disease', '')])
#
# 17684544 rs11209026 gwas_central
# GWC: set([u"Crohn's disease"])
# US:  set([('IBD Disease', '')])
#
# 17684544 rs10484545 gwas_central
# GWC: set([u"Crohn's disease"])
# US:  set([('IBD Disease', '')])
#
# 17684544 rs1793004 gwas_central
# GWC: set([u"Crohn's disease"])
# US:  set([('IBD Disease', '')])
#
# 17684544 rs2241880 gwas_central
# GWC: set([u"Crohn's disease"])
# US:  set([('IBD Disease', '')])
#
# 17684544 rs1553575 gwas_central
# GWC: set([u"Crohn's disease"])
# US:  set([('IBD Disease', '')])
#
# 17684544 rs10513059 gwas_central
# GWC: set([u"Crohn's disease"])
# US:  None
#
# 17684544 rs200354 gwas_central
# GWC: set([u"Crohn's disease"])
# US:  None
#
# 17684544 rs7725052 gwas_central
# GWC: set([u"Crohn's disease"])
# US:  None
#
# 17684544 rs2009530 gwas_central
# GWC: set([u"Crohn's disease"])
# US:  None
#
# 17684544 rs10484543 gwas_central
# GWC: set([u"Crohn's disease"])
# US:  None
#
# 17684544 rs2066847 gwas_central
# GWC: set([u"Crohn's disease"])
# US:  set([('IBD Disease', '')])
#
# 17684544 rs2076756 gwas_central
# GWC: set([u"Crohn's disease"])
# US:  set([('IBD Disease', '')])
#
# 17684544 rs2066844 gwas_central
# GWC: set([u"Crohn's disease"])
# US:  set([('IBD Disease', '')])
#
# 17684544 rs2066845 gwas_central
# GWC: set([u"Crohn's disease"])
# US:  set([('IBD Disease', '')])
#
# 17684544 rs1992660 gwas_central
# GWC: set([u"Crohn's disease"])
# US:  set([('IBD Disease', '')])
#
# 17684544 rs1992662 gwas_central
# GWC: set([u"Crohn's disease"])
# US:  set([('IBD Disease', '')])
#
# 17684544 rs11209026 gwas_central
# GWC: set([u"Crohn's disease"])
# US:  set([('IBD Disease', '')])
#
# 17684544 rs10484545 gwas_central
# GWC: set([u"Crohn's disease"])
# US:  set([('IBD Disease', '')])
#
# 17684544 rs1793004 gwas_central
# GWC: set([u"Crohn's disease"])
# US:  set([('IBD Disease', '')])
#
# 17684544 rs2241880 gwas_central
# GWC: set([u"Crohn's disease"])
# US:  set([('IBD Disease', '')])
#
# 17684544 rs1553575 gwas_central
# GWC: set([u"Crohn's disease"])
# US:  set([('IBD Disease', '')])
#
# 17684544 rs10513059 gwas_central
# GWC: set([u"Crohn's disease"])
# US:  None
#
# 17684544 rs200354 gwas_central
# GWC: set([u"Crohn's disease"])
# US:  None
#
# 17684544 rs7725052 gwas_central
# GWC: set([u"Crohn's disease"])
# US:  None
#
# 17684544 rs2009530 gwas_central
# GWC: set([u"Crohn's disease"])
# US:  None
#
# 17684544 rs10484543 gwas_central
# GWC: set([u"Crohn's disease"])
# US:  None
#
# ---
# 17903292 rs1712790 gwas_central
# GWC: set([u'Urinary albumin excretion'])
# US:  set([('kidney|endocrine-related traits', 'urinary albumin excretion')])
#
# 17903292 rs1243400 gwas_central
# GWC: set([u'Urinary albumin excretion'])
# US:  set([('kidney|endocrine-related traits', 'urinary albumin excretion')])
#
# 17903292 rs9305354 gwas_central
# GWC: set([u'Urinary albumin excretion'])
# US:  set([('kidney|endocrine-related traits', 'urinary albumin excretion')])
#
# 17903292 rs6977660 gwas_central
# GWC: set([u'Thyroid stimulating hormone'])
# US:  set([('kidney|endocrine-related traits', 'thyroid stimulating hormone')])
#
# 17903292 rs9322817 gwas_central
# GWC: set([u'Thyroid stimulating hormone'])
# US:  set([('kidney|endocrine-related traits', 'thyroid stimulating hormone')])
#
# 17903292 rs10499559 gwas_central
# GWC: set([u'Thyroid stimulating hormone'])
# US:  set([('kidney|endocrine-related traits', 'thyroid stimulating hormone')])
#
# 17903292 rs1158167 gwas_central
# GWC: set([u'Cystatin C'])
# US:  set([('kidney|endocrine-related traits', 'cst3')])
#
# 17903292 rs1712790 gwas_central
# GWC: set([u'Urinary albumin excretion'])
# US:  set([('kidney|endocrine-related traits', 'urinary albumin excretion')])
#
# 17903292 rs1243400 gwas_central
# GWC: set([u'Urinary albumin excretion'])
# US:  set([('kidney|endocrine-related traits', 'urinary albumin excretion')])
#
# 17903292 rs9305354 gwas_central
# GWC: set([u'Urinary albumin excretion'])
# US:  set([('kidney|endocrine-related traits', 'urinary albumin excretion')])
#
# 17903292 rs6977660 gwas_central
# GWC: set([u'Thyroid stimulating hormone'])
# US:  set([('kidney|endocrine-related traits', 'thyroid stimulating hormone')])
#
# 17903292 rs9322817 gwas_central
# GWC: set([u'Thyroid stimulating hormone'])
# US:  set([('kidney|endocrine-related traits', 'thyroid stimulating hormone')])
#
# 17903292 rs10499559 gwas_central
# GWC: set([u'Thyroid stimulating hormone'])
# US:  set([('kidney|endocrine-related traits', 'thyroid stimulating hormone')])
#
# 17903292 rs1158167 gwas_central
# GWC: set([u'Cystatin C'])
# US:  set([('kidney|endocrine-related traits', 'cst3')])
#
# 17903292 rs10502302 set([('kidney|endocrine-related traits', 'Serum creatinine (exam 5)')])
# 17903292 rs754958 set([('kidney|endocrine-related traits', 'Serum Phosphorous')])
# 17903292 rs2374688 set([('kidney|endocrine-related traits', '')])
# 17903292 rs727087 set([('kidney|endocrine-related traits', 'glomerular filtration rate')])
# 17903292 rs1856190 set([('kidney|endocrine-related traits', '')])
# 17903292 rs10507344 set([('kidney|endocrine-related traits', '')])
# 17903292 rs784490 set([('kidney|endocrine-related traits', '')])
# 17903292 rs9308765 set([('kidney|endocrine-related traits', '')])
# 17903292 rs2121267 set([('kidney|endocrine-related traits', '')])
# 17903292 rs278021 set([('kidney|endocrine-related traits', '')])
# 17903292 rs295136 set([('kidney|endocrine-related traits', '')])
# 17903292 rs10504244 set([('kidney|endocrine-related traits', '')])
# 17903292 rs6434804 set([('kidney|endocrine-related traits', '')])
# 17903292 rs10492025 set([('kidney|endocrine-related traits', '')])
# 17903292 rs827640 set([('kidney|endocrine-related traits', '')])
# 17903292 rs6942231 set([('kidney|endocrine-related traits', '')])
# 17903292 rs1400306 set([('kidney|endocrine-related traits', '')])
# 17903292 rs2077678 set([('kidney|endocrine-related traits', '')])
# 17903292 rs2839235 set([('kidney|endocrine-related traits', '')])
# 17903292 rs7315682 set([('kidney|endocrine-related traits', '')])
# 17903292 rs2056694 set([('kidney|endocrine-related traits', '')])
# 17903292 rs33855 set([('kidney|endocrine-related traits', '')])
# 17903292 rs2480555 set([('kidney|endocrine-related traits', 'glomerular filtration rate')])
# 17903292 rs10501264 set([('kidney|endocrine-related traits', '')])
# 17903292 rs1223531 set([('kidney|endocrine-related traits', '')])
# 17903292 rs890945 set([('kidney|endocrine-related traits', '')])
# 17903292 rs10495487 set([('kidney|endocrine-related traits', 'Uric acid')])
# 17903292 rs10486365 set([('kidney|endocrine-related traits', '')])
# 17903292 rs701801 set([('kidney|endocrine-related traits', '')])
# 17903292 rs9305355 set([('kidney|endocrine-related traits', '')])
# 17903292 rs10486653 set([('kidney|endocrine-related traits', '')])
# 17903292 rs10483741 set([('kidney|endocrine-related traits', '')])
# 17903292 rs2761171 set([('kidney|endocrine-related traits', '')])
# 17903292 rs10486135 set([('kidney|endocrine-related traits', 'glomerular filtration rate')])
# 17903292 rs10519012 set([('kidney|endocrine-related traits', '')])
# 17903292 rs1543468 set([('kidney|endocrine-related traits', '')])
# 17903292 rs10484370 set([('kidney|endocrine-related traits', 'Serum Calcium')])
# 17903292 rs10489639 set([('kidney|endocrine-related traits', '')])
# 17903292 rs2113379 set([('kidney|endocrine-related traits', '')])
# 17903292 rs10512437 set([('kidney|endocrine-related traits', 'glomerular filtration rate')])
# 17903292 rs10489578 set([('kidney|endocrine-related traits', 'Serum creatinine (exam 6)'), ('kidney|endocrine-related traits', 'glomerular filtration rate (exam 6)')])
# 17903292 rs4128956 set([('kidney|endocrine-related traits', '')])
# 17903292 rs1931619 set([('kidney|endocrine-related traits', '')])
# 17903292 rs911122 set([('kidney|endocrine-related traits', 'cst3'), ('kidney|endocrine-related traits', 'urinary albumin excretion \xe2\x89\xa5 30*')])
# 17903292 rs837678 set([('kidney|endocrine-related traits', '')])
# 17903292 rs10496887 set([('kidney|endocrine-related traits', 'glomerular filtration rate')])
# 17903292 rs563754 set([('kidney|endocrine-related traits', '')])
# 17903292 rs10493147 set([('kidney|endocrine-related traits', '')])
# 17903292 rs10502192 set([('kidney|endocrine-related traits', '')])
# 17903292 rs10511176 set([('kidney|endocrine-related traits', 'glomerular filtration rate (exam 7)')])
# 17903292 rs3095160 set([('kidney|endocrine-related traits', '')])
# 17903292 rs1005066 set([('kidney|endocrine-related traits', 'glomerular filtration rate')])
# 17903292 rs10515134 set([('kidney|endocrine-related traits', 'Luteinizing Hormone')])
# 17903292 rs7865184 set([('kidney|endocrine-related traits', '')])
# 17903292 rs8113386 set([('kidney|endocrine-related traits', '')])
# 17903292 rs3760626 set([('kidney|endocrine-related traits', 'chronic kidney disease')])
# 17903292 rs10484587 set([('kidney|endocrine-related traits', '')])
# 17903292 rs2785980 set([('kidney|endocrine-related traits', '')])
# 17903292 rs3908399 set([('kidney|endocrine-related traits', '')])
# ---
# 17903293 rs1417352 gwas_central
# GWC: set([u'N-terminal pro-atrial natriuretic peptide'])
# US:  set([('biomarker traits|select', 'Atrial natriuretic peptide exam 6')])
#
# 17903293 rs1486139 gwas_central
# GWC: set([u'N-terminal pro-atrial natriuretic peptide'])
# US:  set([('biomarker traits|select', 'Atrial natriuretic peptide exam 6')])
#
# 17903293 rs1486140 gwas_central
# GWC: set([u'N-terminal pro-atrial natriuretic peptide'])
# US:  set([('biomarker traits|select', 'Atrial natriuretic peptide exam 6')])
#
# 17903293 rs1079596 gwas_central
# GWC: set([u'N-terminal pro-atrial natriuretic peptide'])
# US:  set([('biomarker traits|select', 'Atrial natriuretic peptide exam 6')])
#
# 17903293 rs1376544 gwas_central
# GWC: set([u'Vitamin D, Vitamin K phylloquinone, Vitamin K % undercaboxylated osteocalcin'])
# US:  set([('biomarker traits|select', 'Vitamin D, Vitamin K phylloquinone & Vitamin K % undercarboxylated osteocalcin')])
#
# 17903293 rs2494250 gwas_central
# GWC: set([u'Monocyte chemoattractant protein-1'])
# US:  set([('biomarker traits|select', 'Monocyte chemoattractant protein-1')])
#
# 17903293 rs4128725 gwas_central
# GWC: set([u'Monocyte chemoattractant protein-1'])
# US:  set([('biomarker traits|select', 'Monocyte chemoattractant protein-1')])
#
# 17903293 rs10489849 gwas_central
# GWC: set([u'Monocyte chemoattractant protein-1'])
# US:  set([('biomarker traits|select', 'Monocyte chemoattractant protein-1')])
#
# 17903293 rs1474747 gwas_central
# GWC: set([u'Monocyte chemoattractant protein-1'])
# US:  set([('biomarker traits|select', 'Monocyte chemoattractant protein-1')])
#
# 17903293 rs7778619 gwas_central
# GWC: set([u'Serum CD40 ligand'])
# US:  set([('biomarker traits|select', 'CD40 Ligand serum')])
#
# 17903293 rs8005745 gwas_central
# GWC: set([u'Serum CD40 ligand'])
# US:  set([('biomarker traits|select', 'CD40 Ligand serum')])
#
# 17903293 rs4664604 gwas_central
# GWC: set([u'Serum CD40 ligand'])
# US:  set([('biomarker traits|select', 'CD40 Ligand serum')])
#
# 17903293 rs9288125 gwas_central
# GWC: set([u'Serum CD40 ligand'])
# US:  set([('biomarker traits|select', 'CD40 Ligand serum')])
#
# 17903293 rs3849944 gwas_central
# GWC: set([u'Intracellular adhesion molecule-1'])
# US:  set([('biomarker traits|select', 'Intercellular adhesion molecule-1')])
#
# 17903293 rs2372184 gwas_central
# GWC: set([u'Plasma CD40 ligand'])
# US:  set([('biomarker traits|select', 'CD40 Ligand plasma')])
#
# 17903293 rs2387326 gwas_central
# GWC: set([u'Plasma vitamin K'])
# US:  set([('biomarker traits|select', 'Vitamin K plasma phylloquinone')])
#
# 17903293 rs7552393 gwas_central
# GWC: set([u'Tumor necrosis factor alpha'])
# US:  set([('biomarker traits|select', 'Tumor necrosis factor alpha')])
#
# 17903293 rs4911146 gwas_central
# GWC: set([u'Liver function test: alkaline phosphatase, AST, ALT, GGT'])
# US:  set([('biomarker traits|select', 'Liver function: Alkaline phosphatase; AST; ALT; gamma-glutamyl transferase')])
#
# 17903293 rs953402 gwas_central
# GWC: set([u'Liver function test: alkaline phosphatase, AST, ALT, GGT'])
# US:  set([('biomarker traits|select', 'Liver function: Alkaline phosphatase; AST; ALT; gamma-glutamyl transferase')])
#
# 17903293 rs1594468 gwas_central
# GWC: set([u'Bilirubin'])
# US:  None
#
# 17903293 rs496269 gwas_central
# GWC: set([u'Osteoprotegerin'])
# US:  set([('biomarker traits|select', 'Osteoprotegerin')])
#
# 17903293 rs1998303 gwas_central
# GWC: set([u'Alanine aminotransferase'])
# US:  set([('biomarker traits|select', 'Alanine aminotransferase')])
#
# 17903293 rs10492681 gwas_central
# GWC: set([u'Alanine aminotransferase'])
# US:  set([('biomarker traits|select', 'Alanine aminotransferase exam 2')])
#
# 17903293 rs2052028 gwas_central
# GWC: set([u'Vitamin K % undercarboxylated osteocalcin'])
# US:  set([('biomarker traits|select', 'Vitamin K % undercarboxylated osteocalcin')])
#
# 17903293 rs437021 gwas_central
# GWC: set([u'B-type natriuretic peptide'])
# US:  set([('biomarker traits|select', 'B-type natriuretic peptide')])
#
# 17903293 rs10518765 gwas_central
# GWC: set([u'Alkaline phosphatase'])
# US:  set([('biomarker traits|select', 'Alkaline phosphatase')])
#
# 17903293 rs2794520 gwas_central
# GWC: set([u'C-reactive protein'])
# US:  set([('biomarker traits|select', 'C-reactive protein exam 6'), ('biomarker traits|select', 'C-reactive protein average exams 2,6,7')])
#
# 17903293 rs2808629 gwas_central
# GWC: set([u'C-reactive protein'])
# US:  set([('biomarker traits|select', 'C-reactive protein exam 6'), ('biomarker traits|select', 'C-reactive protein average exams 2,6,7')])
#
# 17903293 rs746961 gwas_central
# GWC: set([u'C-reactive protein'])
# US:  set([('biomarker traits|select', 'C-reactive protein exam 6')])
#
# 17903293 rs465384 gwas_central
# GWC: set([u'C-reactive protein'])
# US:  None
#
# 17903293 rs583012 gwas_central
# GWC: set([u'C-reactive protein'])
# US:  set([('biomarker traits|select', 'C-reactive protein exam 2')])
#
# 17903293 rs1363258 gwas_central
# GWC: set([u'C-reactive protein'])
# US:  set([('biomarker traits|select', 'C-reactive protein exam 7')])
#
# 17903293 rs717145 gwas_central
# GWC: set([u'Urinary isoprostanes/creatinine'])
# US:  set([('biomarker traits|select', 'Urinary isoprostanes/creatinine')])
#
# 17903293 rs10485165 gwas_central
# GWC: set([u'Plasma vitamin D'])
# US:  set([('biomarker traits|select', 'Vitamin D plasma 25(OH)-D')])
#
# 17903293 rs10507577 gwas_central
# GWC: set([u'Plasma vitamin D'])
# US:  set([('biomarker traits|select', 'Vitamin D plasma 25(OH)-D')])
#
# 17903293 rs1417352 gwas_central
# GWC: set([u'N-terminal pro-atrial natriuretic peptide'])
# US:  set([('biomarker traits|select', 'Atrial natriuretic peptide exam 6')])
#
# 17903293 rs1486139 gwas_central
# GWC: set([u'N-terminal pro-atrial natriuretic peptide'])
# US:  set([('biomarker traits|select', 'Atrial natriuretic peptide exam 6')])
#
# 17903293 rs1486140 gwas_central
# GWC: set([u'N-terminal pro-atrial natriuretic peptide'])
# US:  set([('biomarker traits|select', 'Atrial natriuretic peptide exam 6')])
#
# 17903293 rs1079596 gwas_central
# GWC: set([u'N-terminal pro-atrial natriuretic peptide'])
# US:  set([('biomarker traits|select', 'Atrial natriuretic peptide exam 6')])
#
# 17903293 rs1376544 gwas_central
# GWC: set([u'Vitamin D, Vitamin K phylloquinone, Vitamin K % undercaboxylated osteocalcin'])
# US:  set([('biomarker traits|select', 'Vitamin D, Vitamin K phylloquinone & Vitamin K % undercarboxylated osteocalcin')])
#
# 17903293 rs2494250 gwas_central
# GWC: set([u'Monocyte chemoattractant protein-1'])
# US:  set([('biomarker traits|select', 'Monocyte chemoattractant protein-1')])
#
# 17903293 rs4128725 gwas_central
# GWC: set([u'Monocyte chemoattractant protein-1'])
# US:  set([('biomarker traits|select', 'Monocyte chemoattractant protein-1')])
#
# 17903293 rs10489849 gwas_central
# GWC: set([u'Monocyte chemoattractant protein-1'])
# US:  set([('biomarker traits|select', 'Monocyte chemoattractant protein-1')])
#
# 17903293 rs1474747 gwas_central
# GWC: set([u'Monocyte chemoattractant protein-1'])
# US:  set([('biomarker traits|select', 'Monocyte chemoattractant protein-1')])
#
# 17903293 rs7778619 gwas_central
# GWC: set([u'Serum CD40 ligand'])
# US:  set([('biomarker traits|select', 'CD40 Ligand serum')])
#
# 17903293 rs8005745 gwas_central
# GWC: set([u'Serum CD40 ligand'])
# US:  set([('biomarker traits|select', 'CD40 Ligand serum')])
#
# 17903293 rs4664604 gwas_central
# GWC: set([u'Serum CD40 ligand'])
# US:  set([('biomarker traits|select', 'CD40 Ligand serum')])
#
# 17903293 rs9288125 gwas_central
# GWC: set([u'Serum CD40 ligand'])
# US:  set([('biomarker traits|select', 'CD40 Ligand serum')])
#
# 17903293 rs3849944 gwas_central
# GWC: set([u'Intracellular adhesion molecule-1'])
# US:  set([('biomarker traits|select', 'Intercellular adhesion molecule-1')])
#
# 17903293 rs2372184 gwas_central
# GWC: set([u'Plasma CD40 ligand'])
# US:  set([('biomarker traits|select', 'CD40 Ligand plasma')])
#
# 17903293 rs2387326 gwas_central
# GWC: set([u'Plasma vitamin K'])
# US:  set([('biomarker traits|select', 'Vitamin K plasma phylloquinone')])
#
# 17903293 rs7552393 gwas_central
# GWC: set([u'Tumor necrosis factor alpha'])
# US:  set([('biomarker traits|select', 'Tumor necrosis factor alpha')])
#
# 17903293 rs4911146 gwas_central
# GWC: set([u'Liver function test: alkaline phosphatase, AST, ALT, GGT'])
# US:  set([('biomarker traits|select', 'Liver function: Alkaline phosphatase; AST; ALT; gamma-glutamyl transferase')])
#
# 17903293 rs953402 gwas_central
# GWC: set([u'Liver function test: alkaline phosphatase, AST, ALT, GGT'])
# US:  set([('biomarker traits|select', 'Liver function: Alkaline phosphatase; AST; ALT; gamma-glutamyl transferase')])
#
# 17903293 rs1594468 gwas_central
# GWC: set([u'Bilirubin'])
# US:  None
#
# 17903293 rs496269 gwas_central
# GWC: set([u'Osteoprotegerin'])
# US:  set([('biomarker traits|select', 'Osteoprotegerin')])
#
# 17903293 rs1998303 gwas_central
# GWC: set([u'Alanine aminotransferase'])
# US:  set([('biomarker traits|select', 'Alanine aminotransferase')])
#
# 17903293 rs10492681 gwas_central
# GWC: set([u'Alanine aminotransferase'])
# US:  set([('biomarker traits|select', 'Alanine aminotransferase exam 2')])
#
# 17903293 rs2052028 gwas_central
# GWC: set([u'Vitamin K % undercarboxylated osteocalcin'])
# US:  set([('biomarker traits|select', 'Vitamin K % undercarboxylated osteocalcin')])
#
# 17903293 rs437021 gwas_central
# GWC: set([u'B-type natriuretic peptide'])
# US:  set([('biomarker traits|select', 'B-type natriuretic peptide')])
#
# 17903293 rs10518765 gwas_central
# GWC: set([u'Alkaline phosphatase'])
# US:  set([('biomarker traits|select', 'Alkaline phosphatase')])
#
# 17903293 rs2794520 gwas_central
# GWC: set([u'C-reactive protein'])
# US:  set([('biomarker traits|select', 'C-reactive protein exam 6'), ('biomarker traits|select', 'C-reactive protein average exams 2,6,7')])
#
# 17903293 rs2808629 gwas_central
# GWC: set([u'C-reactive protein'])
# US:  set([('biomarker traits|select', 'C-reactive protein exam 6'), ('biomarker traits|select', 'C-reactive protein average exams 2,6,7')])
#
# 17903293 rs746961 gwas_central
# GWC: set([u'C-reactive protein'])
# US:  set([('biomarker traits|select', 'C-reactive protein exam 6')])
#
# 17903293 rs465384 gwas_central
# GWC: set([u'C-reactive protein'])
# US:  None
#
# 17903293 rs583012 gwas_central
# GWC: set([u'C-reactive protein'])
# US:  set([('biomarker traits|select', 'C-reactive protein exam 2')])
#
# 17903293 rs1363258 gwas_central
# GWC: set([u'C-reactive protein'])
# US:  set([('biomarker traits|select', 'C-reactive protein exam 7')])
#
# 17903293 rs717145 gwas_central
# GWC: set([u'Urinary isoprostanes/creatinine'])
# US:  set([('biomarker traits|select', 'Urinary isoprostanes/creatinine')])
#
# 17903293 rs10485165 gwas_central
# GWC: set([u'Plasma vitamin D'])
# US:  set([('biomarker traits|select', 'Vitamin D plasma 25(OH)-D')])
#
# 17903293 rs10507577 gwas_central
# GWC: set([u'Plasma vitamin D'])
# US:  set([('biomarker traits|select', 'Vitamin D plasma 25(OH)-D')])
#
# 17903293 rs4899940 set([('biomarker traits|select', 'Interleukin-6, C-reactive protein and Fibrinogen')])
# 17903293 rs1205 set([('biomarker traits|select', '')])
# 17903293 rs1887027 set([('biomarker traits|select', '')])
# 17903293 rs2831618 set([('biomarker traits|select', '')])
# 17903293 rs1080327 set([('biomarker traits|select', '')])
# 17903293 rs3116653 set([('biomarker traits|select', '')])
# 17903293 rs1860181 set([('biomarker traits|select', '')])
# 17903293 rs642245 set([('biomarker traits|select', '')])
# 17903293 rs4131568 set([('biomarker traits|select', '')])
# 17903293 rs1860182 set([('biomarker traits|select', '')])
# 17903293 rs1986743 set([('biomarker traits|select', '')])
# 17903293 rs910232 set([('biomarker traits|select', 'C-reactive protein: exams 2, 5, 6, 7')])
# 17903293 rs2390582 set([('biomarker traits|select', '')])
# 17903293 rs7969455 set([('biomarker traits|select', 'Interleukin-6, C-reactive protein and Fibrinogen')])
# 17903293 rs2353803 set([('biomarker traits|select', '')])
# 17903293 rs10503717 set([('biomarker traits|select', 'Interleukin-6, C-reactive protein and Fibrinogen')])
# 17903293 rs3110134 set([('biomarker traits|select', 'Interleukin-6, C-reactive protein and Fibrinogen')])
# 17903293 rs1119582 set([('biomarker traits|select', 'C-reactive protein average exams 2,6,7')])
# 17903293 rs744511 set([('biomarker traits|select', '')])
# 17903293 rs1461549 set([('biomarker traits|select', '')])
# 17903293 rs303939 set([('biomarker traits|select', '')])
# 17903293 rs3815341 set([('biomarker traits|select', '')])
# 17903293 rs11626844 set([('biomarker traits|select', '')])
# 17903293 rs9319160 set([('biomarker traits|select', 'C-reactive protein: exams 2, 5, 6, 7')])
# 17903293 rs1457590 set([('biomarker traits|select', 'Interleukin-6, C-reactive protein and Fibrinogen')])
# 17903293 rs2359763 set([('biomarker traits|select', 'Interleukin-6, C-reactive protein and Fibrinogen')])
# 17903293 rs2016740 set([('biomarker traits|select', 'Interleukin-6, C-reactive protein and Fibrinogen')])
# 17903293 rs1891187 set([('biomarker traits|select', '')])
# 17903293 rs1800795 set([('biomarker traits|select', '')])
# 17903293 rs698270 set([('biomarker traits|select', 'Interleukin-6, C-reactive protein and Fibrinogen')])
# 17903293 rs17532515 set([('biomarker traits|select', 'Bilirubin')])
# 17903293 rs10511884 set([('biomarker traits|select', '')])
# 17903293 rs10491109 set([('biomarker traits|select', '')])
# 17903293 rs248328 set([('biomarker traits|select', '')])
# 17903293 rs2044401 set([('biomarker traits|select', '')])
# 17903293 rs3093077 set([('biomarker traits|select', '')])
# 17903293 rs877936 set([('biomarker traits|select', 'Interleukin-6, C-reactive protein and Fibrinogen')])
# 17903293 rs1024611 set([('biomarker traits|select', '')])
# 17903293 rs10501981 set([('biomarker traits|select', '')])
# 17903293 rs1446959 set([('biomarker traits|select', '')])
# 17903293 rs6848323 set([('biomarker traits|select', 'Interleukin-6, C-reactive protein and Fibrinogen')])
# 17903293 rs719006 set([('biomarker traits|select', 'Interleukin-6, C-reactive protein and Fibrinogen')])
# 17903293 rs1436336 set([('biomarker traits|select', 'Interleukin-6, C-reactive protein and Fibrinogen')])
# 17903293 rs847428 set([('biomarker traits|select', 'Interleukin-6, C-reactive protein and Fibrinogen')])
# 17903293 rs1436136 set([('biomarker traits|select', 'Interleukin-6, C-reactive protein and Fibrinogen')])
# 17903293 rs962976 set([('biomarker traits|select', '')])
# 17903293 rs1417938 set([('biomarker traits|select', '')])
# 17903293 rs9352609 set([('biomarker traits|select', '')])
# 17903293 rs2421608 set([('biomarker traits|select', '')])
# 17903293 rs6563212 set([('biomarker traits|select', '')])
# 17903293 rs2831620 set([('biomarker traits|select', '')])
# 17903293 rs2831617 set([('biomarker traits|select', '')])
# 17903293 rs6461667 set([('biomarker traits|select', '')])
# ---
# 17903294 rs7159841 gwas_central
# GWC: set([u'Viscosity'])
# US:  set([('hematological phenotypes', 'Viscosity')])
#
# 17903294 rs1397048 gwas_central
# GWC: set([u'Mean corpuscular hemoglobin'])
# US:  set([('hematological phenotypes', 'mean corpuscular hemoglobin')])
#
# 17903294 rs2412522 gwas_central
# GWC: set([u'Mean corpuscular hemoglobin'])
# US:  set([('hematological phenotypes', 'hemoglobin')])
#
# 17903294 rs1829883 gwas_central
# GWC: set([u'Mean corpuscular hemoglobin'])
# US:  set([('hematological phenotypes', 'mean corpuscular hemoglobin')])
#
# 17903294 rs1200821 gwas_central
# GWC: set([u'Mean corpuscular hemoglobin'])
# US:  set([('hematological phenotypes', 'mean corpuscular hemoglobin')])
#
# 17903294 rs9253 gwas_central
# GWC: set([u'Red blood cell count'])
# US:  set([('hematological phenotypes', 'red blood cell count')])
#
# 17903294 rs10489087 gwas_central
# GWC: set([u'Red blood cell count'])
# US:  set([('hematological phenotypes', 'red blood cell count')])
#
# 17903294 rs6108011 gwas_central
# GWC: set([u'Red blood cell count'])
# US:  set([('hematological phenotypes', 'red blood cell count')])
#
# 17903294 rs636864 gwas_central
# GWC: set([u'Red blood cell count'])
# US:  set([('hematological phenotypes', 'red blood cell count')])
#
# 17903294 rs727979 gwas_central
# GWC: set([u'Red blood cell count'])
# US:  set([('hematological phenotypes', 'red blood cell count')])
#
# 17903294 rs6046 gwas_central
# GWC: set([u'Factor VII'])
# US:  None
#
# 17903294 rs561241 gwas_central
# GWC: set([u'Factor VII'])
# US:  set([('hematological phenotypes', 'FVII, exam 5'), ('hematological phenotypes', 'factor vii')])
#
# 17903294 rs10488360 gwas_central
# GWC: set([u'Factor VII'])
# US:  set([('hematological phenotypes', 'factor vii')])
#
# 17903294 rs966321 gwas_central
# GWC: set([u'Factor VII'])
# US:  set([('hematological phenotypes', 'factor vii')])
#
# 17903294 rs727435 gwas_central
# GWC: set([u'Factor VII'])
# US:  None
#
# 17903294 rs565229 gwas_central
# GWC: set([u'Collagen-induced platelet aggregation'])
# US:  set([('hematological phenotypes', 'platelet aggregation (collagen-induced)')])
#
# 17903294 rs10506458 gwas_central
# GWC: set([u'Collagen-induced platelet aggregation'])
# US:  set([('hematological phenotypes', 'platelet aggregation (collagen-induced)')])
#
# 17903294 rs10493485 gwas_central
# GWC: set([u'Tissue plasminogen activator'])
# US:  set([('hematological phenotypes', 'tissue plasminogen activator')])
#
# 17903294 rs10484128 gwas_central
# GWC: set([u'ADP-induced platelet aggregation'])
# US:  set([('hematological phenotypes', 'platelet aggregation (ADP-induced)')])
#
# 17903294 rs1160297 gwas_central
# GWC: set([u'Hemoglobin'])
# US:  set([('hematological phenotypes', 'hemoglobin')])
#
# 17903294 rs7844723 gwas_central
# GWC: set([u'Hemoglobin'])
# US:  set([('hematological phenotypes', 'hemoglobin')])
#
# 17903294 rs7159841 gwas_central
# GWC: set([u'Viscosity'])
# US:  set([('hematological phenotypes', 'Viscosity')])
#
# 17903294 rs1397048 gwas_central
# GWC: set([u'Mean corpuscular hemoglobin'])
# US:  set([('hematological phenotypes', 'mean corpuscular hemoglobin')])
#
# 17903294 rs2412522 gwas_central
# GWC: set([u'Mean corpuscular hemoglobin'])
# US:  set([('hematological phenotypes', 'hemoglobin')])
#
# 17903294 rs1829883 gwas_central
# GWC: set([u'Mean corpuscular hemoglobin'])
# US:  set([('hematological phenotypes', 'mean corpuscular hemoglobin')])
#
# 17903294 rs1200821 gwas_central
# GWC: set([u'Mean corpuscular hemoglobin'])
# US:  set([('hematological phenotypes', 'mean corpuscular hemoglobin')])
#
# 17903294 rs9253 gwas_central
# GWC: set([u'Red blood cell count'])
# US:  set([('hematological phenotypes', 'red blood cell count')])
#
# 17903294 rs10489087 gwas_central
# GWC: set([u'Red blood cell count'])
# US:  set([('hematological phenotypes', 'red blood cell count')])
#
# 17903294 rs6108011 gwas_central
# GWC: set([u'Red blood cell count'])
# US:  set([('hematological phenotypes', 'red blood cell count')])
#
# 17903294 rs636864 gwas_central
# GWC: set([u'Red blood cell count'])
# US:  set([('hematological phenotypes', 'red blood cell count')])
#
# 17903294 rs727979 gwas_central
# GWC: set([u'Red blood cell count'])
# US:  set([('hematological phenotypes', 'red blood cell count')])
#
# 17903294 rs6046 gwas_central
# GWC: set([u'Factor VII'])
# US:  None
#
# 17903294 rs561241 gwas_central
# GWC: set([u'Factor VII'])
# US:  set([('hematological phenotypes', 'FVII, exam 5'), ('hematological phenotypes', 'factor vii')])
#
# 17903294 rs10488360 gwas_central
# GWC: set([u'Factor VII'])
# US:  set([('hematological phenotypes', 'factor vii')])
#
# 17903294 rs966321 gwas_central
# GWC: set([u'Factor VII'])
# US:  set([('hematological phenotypes', 'factor vii')])
#
# 17903294 rs727435 gwas_central
# GWC: set([u'Factor VII'])
# US:  None
#
# 17903294 rs565229 gwas_central
# GWC: set([u'Collagen-induced platelet aggregation'])
# US:  set([('hematological phenotypes', 'platelet aggregation (collagen-induced)')])
#
# 17903294 rs10506458 gwas_central
# GWC: set([u'Collagen-induced platelet aggregation'])
# US:  set([('hematological phenotypes', 'platelet aggregation (collagen-induced)')])
#
# 17903294 rs10493485 gwas_central
# GWC: set([u'Tissue plasminogen activator'])
# US:  set([('hematological phenotypes', 'tissue plasminogen activator')])
#
# 17903294 rs10484128 gwas_central
# GWC: set([u'ADP-induced platelet aggregation'])
# US:  set([('hematological phenotypes', 'platelet aggregation (ADP-induced)')])
#
# 17903294 rs1160297 gwas_central
# GWC: set([u'Hemoglobin'])
# US:  set([('hematological phenotypes', 'hemoglobin')])
#
# 17903294 rs7844723 gwas_central
# GWC: set([u'Hemoglobin'])
# US:  set([('hematological phenotypes', 'hemoglobin')])
#
# 17903294 rs2178692 set([('hematological phenotypes', 'red blood cell count')])
# 17903294 rs9323656 set([('hematological phenotypes', '')])
# 17903294 rs953377 set([('hematological phenotypes', '')])
# 17903294 rs10488676 set([('hematological phenotypes', '')])
# 17903294 rs1273819 set([('hematological phenotypes', 'Fibrinogen')])
# 17903294 rs1001254 set([('hematological phenotypes', '')])
# 17903294 rs4525555 set([('hematological phenotypes', 'Platelet Aggregation, ADP, exam 5'), ('hematological phenotypes', 'Platelet Aggregation, Collagen, exam 5'), ('hematological phenotypes', 'Platelet Aggregation, epinephrine, exam 5')])
# 17903294 rs2066864 set([('hematological phenotypes', 'Fibrinogen, average'), ('hematological phenotypes', 'Fibrinogen, exam 7'), ('hematological phenotypes', 'Fibrinogen, exam 5'), ('hematological phenotypes', 'Fibrinogen, exam 6')])
# 17903294 rs10497881 set([('hematological phenotypes', '')])
# 17903294 rs2175271 set([('hematological phenotypes', '')])
# 17903294 rs4148751 set([('hematological phenotypes', 'platelet aggregation (ADP-induced)')])
# 17903294 rs917858 set([('hematological phenotypes', 'wVW, exam 5')])
# 17903294 rs10506540 set([('hematological phenotypes', '')])
# 17903294 rs1869733 set([('hematological phenotypes', '')])
# 17903294 rs10488675 set([('hematological phenotypes', '')])
# 17903294 rs7761311 set([('hematological phenotypes', '')])
# 17903294 rs4897472 set([('hematological phenotypes', '')])
# 17903294 rs4128714 set([('hematological phenotypes', '')])
# 17903294 rs10514670 set([('hematological phenotypes', 'von willebrand factor')])
# 17903294 rs1958208 set([('hematological phenotypes', '')])
# 17903294 rs4133289 set([('hematological phenotypes', 'hemoglobin')])
# 17903294 rs917859 set([('hematological phenotypes', 'wVW, exam 5')])
# 17903294 rs17310225 set([('hematological phenotypes', 'platelet aggregation (collagen-induced)')])
# 17903294 rs6938586 set([('hematological phenotypes', '')])
# 17903294 rs10490733 set([('hematological phenotypes', '')])
# 17903294 rs708356 set([('hematological phenotypes', '')])
# 17903294 rs9285468 set([('hematological phenotypes', '')])
# 17903294 rs2362932 set([('hematological phenotypes', '')])
# 17903294 rs10499199 set([('hematological phenotypes', '')])
# 17903294 rs7748468 set([('hematological phenotypes', '')])
# 17903294 rs10499201 set([('hematological phenotypes', '')])
# 17903294 rs4591494 set([('hematological phenotypes', 'factor vii')])
# 17903294 rs2015729 set([('hematological phenotypes', 'Platelet Aggregation, ADP, exam 5'), ('hematological phenotypes', 'Platelet Aggregation, Collagen, exam 5'), ('hematological phenotypes', 'Platelet Aggregation, epinephrine, exam 5')])
# 17903294 rs20037 set([('hematological phenotypes', 'red blood cell count')])
# 17903294 rs968856 set([('hematological phenotypes', '')])
# 17903294 rs9295740 set([('hematological phenotypes', '')])
# 17903294 rs10499200 set([('hematological phenotypes', '')])
# 17903294 rs10490258 set([('hematological phenotypes', '')])
# 17903294 rs2271090 set([('hematological phenotypes', 'red blood cell count')])
# 17903294 rs6902919 set([('hematological phenotypes', '')])
# 17903294 rs974673 set([('hematological phenotypes', '')])
# 17903294 rs2357013 set([('hematological phenotypes', 'hemoglobin')])
# 17903294 rs7938734 set([('hematological phenotypes', '')])
# 17903294 rs9317390 set([('hematological phenotypes', '')])
# 17903294 rs4861952 set([('hematological phenotypes', '')])
# 17903294 rs9321263 set([('hematological phenotypes', '')])
# 17903294 rs4897475 set([('hematological phenotypes', '')])
# 17903294 rs10502583 set([('hematological phenotypes', '')])
# 17903294 rs2029637 set([('hematological phenotypes', '')])
# 17903294 rs2023048 set([('hematological phenotypes', 'red blood cell count')])
# 17903294 rs2400107 set([('hematological phenotypes', 'factor vii')])
# 17903294 rs1542535 set([('hematological phenotypes', 'factor vii')])
# 17903294 rs3898916 set([('hematological phenotypes', '')])
# 17903294 rs2105819 set([('hematological phenotypes', '')])
# 17903294 rs216901 set([('hematological phenotypes', 'wVW, exam 5')])
# 17903294 rs2105250 set([('hematological phenotypes', '')])
# 17903294 rs848523 set([('hematological phenotypes', '')])
# 17903294 rs6956010 set([('hematological phenotypes', 'PAI1, average'), ('hematological phenotypes', 'PAI1, exam 5'), ('hematological phenotypes', 'PAI1, exam 6')])
# 17903294 rs1074801 set([('hematological phenotypes', 'Fibrinogen, average'), ('hematological phenotypes', 'Fibrinogen, exam 7'), ('hematological phenotypes', 'Fibrinogen, exam 5'), ('hematological phenotypes', 'Fibrinogen, exam 6')])
# 17903294 rs10500770 set([('hematological phenotypes', 'red blood cell count')])
# 17903294 rs486633 set([('hematological phenotypes', 'red blood cell count')])
# 17903294 rs10500769 set([('hematological phenotypes', 'red blood cell count')])
# 17903294 rs216903 set([('hematological phenotypes', 'wVW, exam 5')])
# 17903294 rs915171 set([('hematological phenotypes', '')])
# 17903294 rs1561478 set([('hematological phenotypes', '')])
# 17903294 rs10485968 set([('hematological phenotypes', '')])
# 17903294 rs1334689 set([('hematological phenotypes', '')])
# 17903294 rs216904 set([('hematological phenotypes', 'wVW, exam 5')])
# 17903294 rs9321265 set([('hematological phenotypes', '')])
# 17903294 rs38993 set([('hematological phenotypes', 'MCVavg12')])
# 17903294 rs10514838 set([('hematological phenotypes', 'hemoglobin')])
# 17903294 rs4075265 set([('hematological phenotypes', '')])
# 17903294 rs1413754 set([('hematological phenotypes', '')])
# 17903294 rs9299952 set([('hematological phenotypes', 'MCVavg12')])
# 17903294 rs6811964 set([('hematological phenotypes', '')])
# 17903294 rs3777442 set([('hematological phenotypes', '')])
# 17903294 rs10514919 set([('hematological phenotypes', 'Platelet Aggregation, ADP, exam 5'), ('hematological phenotypes', 'Platelet Aggregation, Collagen, exam 5'), ('hematological phenotypes', 'Platelet Aggregation, epinephrine, exam 5')])
# 17903294 rs6907809 set([('hematological phenotypes', '')])
# 17903294 rs1423741 set([('hematological phenotypes', '')])
# 17903294 rs7741731 set([('hematological phenotypes', '')])
# 17903294 rs6683832 set([('hematological phenotypes', '')])
# 17903294 rs4460176 set([('hematological phenotypes', 'PAI1')])
# 17903294 rs10494076 set([('hematological phenotypes', '')])
# 17903294 rs6950982 set([('hematological phenotypes', 'PAI1, average'), ('hematological phenotypes', 'PAI1, exam 5'), ('hematological phenotypes', 'PAI1, exam 6')])
# 17903294 rs956275 set([('hematological phenotypes', 'red blood cell count')])
# 17903294 rs1413753 set([('hematological phenotypes', '')])
# 17903294 rs2239138 set([('hematological phenotypes', 'wVW, exam 5')])
# 17903294 rs10522006 set([('hematological phenotypes', 'MCVavg12')])
# 17903294 rs1582055 set([('hematological phenotypes', '')])
# 17903294 rs10496112 set([('hematological phenotypes', '')])
# 17903294 rs202906 set([('hematological phenotypes', '')])
# 17903294 rs7319671 set([('hematological phenotypes', '')])
# 17903294 rs10493895 set([('hematological phenotypes', '')])
# 17903294 rs1359339 set([('hematological phenotypes', '')])
# 17903294 rs1412540 set([('hematological phenotypes', '')])
# 17903294 rs951251 set([('hematological phenotypes', '')])
# 17903294 rs277330 set([('hematological phenotypes', '')])
# 17903294 rs1811949 set([('hematological phenotypes', '')])
# 17903294 rs6926204 set([('hematological phenotypes', '')])
# 17903294 rs1649053 set([('hematological phenotypes', '')])
# 17903294 rs10498633 set([('hematological phenotypes', 'red blood cell count')])
# 17903294 rs1245072 set([('hematological phenotypes', '')])
# ---
# 17903295 rs10496265 gwas_central
# GWC: set([u'Age at natural menopause'])
# US:  set([('longevity|selected', 'Age at natural menopause\xe2\x80\xa1')])
#
# 17903295 rs10496262 gwas_central
# GWC: set([u'Age at natural menopause'])
# US:  set([('longevity|selected', 'Age at natural menopause\xe2\x80\xa1')])
#
# 17903295 rs958672 gwas_central
# GWC: set([u'Age at natural menopause'])
# US:  set([('longevity|selected', 'Age at natural menopause\xe2\x80\xa1')])
#
# 17903295 rs291353 gwas_central
# GWC: set([u'Age at natural menopause'])
# US:  set([('longevity|selected', 'Age at natural menopause\xe2\x80\xa1')])
#
# 17903295 rs1412337 gwas_central
# GWC: set([u'Morbidity-free survival at age 65'])
# US:  set([('longevity|selected', 'Morbidity-free survival at age 65')])
#
# 17903295 rs32566 gwas_central
# GWC: set([u'Morbidity-free survival at age 65'])
# US:  set([('longevity|selected', 'Morbidity-free survival at age 65')])
#
# 17903295 rs10484246 gwas_central
# GWC: set([u'Morbidity-free survival at age 65'])
# US:  set([('longevity|selected', 'Morbidity-free survival at age 65')])
#
# 17903295 rs4831837 gwas_central
# GWC: set([u'Morbidity-free survival at age 65'])
# US:  set([('longevity|selected', 'Morbidity-free survival at age 65')])
#
# 17903295 rs2639889 gwas_central
# GWC: set([u'Morbidity-free survival at age 65'])
# US:  set([('longevity|selected', 'Morbidity-free survival at age 65')])
#
# 17903295 rs1463605 gwas_central
# GWC: set([u'Biologic age by osseographic scoring system'])
# US:  set([('longevity|selected', 'Biologic age by osseographic scoring system')])
#
# 17903295 rs7176093 gwas_central
# GWC: set([u'Biologic age by osseographic scoring system'])
# US:  set([('longevity|selected', 'Biologic age by osseographic scoring system')])
#
# 17903295 rs3772255 gwas_central
# GWC: set([u'Biologic age by osseographic scoring system'])
# US:  set([('longevity|selected', 'Biologic age by osseographic scoring system')])
#
# 17903295 rs1528753 gwas_central
# GWC: set([u'Age at death'])
# US:  set([('longevity|selected', 'Age at death')])
#
# 17903295 rs10493513 gwas_central
# GWC: set([u'Age at death'])
# US:  set([('longevity|selected', 'Age at death')])
#
# 17903295 rs2371208 gwas_central
# GWC: set([u'Age at death'])
# US:  set([('longevity|selected', 'Age at death')])
#
# 17903295 rs10493514 gwas_central
# GWC: set([u'Age at death'])
# US:  set([('longevity|selected', 'Age at death')])
#
# 17903295 rs2543600 gwas_central
# GWC: set([u'Age at death'])
# US:  set([('longevity|selected', 'Age at death')])
#
# 17903295 rs7137869 gwas_central
# GWC: set([u'Walking speed at advanced age'])
# US:  set([('longevity|selected', 'Walking speed exam 7')])
#
# 17903295 rs4471448 gwas_central
# GWC: set([u'Walking speed at advanced age'])
# US:  set([('longevity|selected', 'Walking speed exam 7')])
#
# 17903295 rs10496265 gwas_central
# GWC: set([u'Age at natural menopause'])
# US:  set([('longevity|selected', 'Age at natural menopause\xe2\x80\xa1')])
#
# 17903295 rs10496262 gwas_central
# GWC: set([u'Age at natural menopause'])
# US:  set([('longevity|selected', 'Age at natural menopause\xe2\x80\xa1')])
#
# 17903295 rs958672 gwas_central
# GWC: set([u'Age at natural menopause'])
# US:  set([('longevity|selected', 'Age at natural menopause\xe2\x80\xa1')])
#
# 17903295 rs291353 gwas_central
# GWC: set([u'Age at natural menopause'])
# US:  set([('longevity|selected', 'Age at natural menopause\xe2\x80\xa1')])
#
# 17903295 rs1412337 gwas_central
# GWC: set([u'Morbidity-free survival at age 65'])
# US:  set([('longevity|selected', 'Morbidity-free survival at age 65')])
#
# 17903295 rs32566 gwas_central
# GWC: set([u'Morbidity-free survival at age 65'])
# US:  set([('longevity|selected', 'Morbidity-free survival at age 65')])
#
# 17903295 rs10484246 gwas_central
# GWC: set([u'Morbidity-free survival at age 65'])
# US:  set([('longevity|selected', 'Morbidity-free survival at age 65')])
#
# 17903295 rs4831837 gwas_central
# GWC: set([u'Morbidity-free survival at age 65'])
# US:  set([('longevity|selected', 'Morbidity-free survival at age 65')])
#
# 17903295 rs2639889 gwas_central
# GWC: set([u'Morbidity-free survival at age 65'])
# US:  set([('longevity|selected', 'Morbidity-free survival at age 65')])
#
# 17903295 rs1463605 gwas_central
# GWC: set([u'Biologic age by osseographic scoring system'])
# US:  set([('longevity|selected', 'Biologic age by osseographic scoring system')])
#
# 17903295 rs7176093 gwas_central
# GWC: set([u'Biologic age by osseographic scoring system'])
# US:  set([('longevity|selected', 'Biologic age by osseographic scoring system')])
#
# 17903295 rs3772255 gwas_central
# GWC: set([u'Biologic age by osseographic scoring system'])
# US:  set([('longevity|selected', 'Biologic age by osseographic scoring system')])
#
# 17903295 rs1528753 gwas_central
# GWC: set([u'Age at death'])
# US:  set([('longevity|selected', 'Age at death')])
#
# 17903295 rs10493513 gwas_central
# GWC: set([u'Age at death'])
# US:  set([('longevity|selected', 'Age at death')])
#
# 17903295 rs2371208 gwas_central
# GWC: set([u'Age at death'])
# US:  set([('longevity|selected', 'Age at death')])
#
# 17903295 rs10493514 gwas_central
# GWC: set([u'Age at death'])
# US:  set([('longevity|selected', 'Age at death')])
#
# 17903295 rs2543600 gwas_central
# GWC: set([u'Age at death'])
# US:  set([('longevity|selected', 'Age at death')])
#
# 17903295 rs7137869 gwas_central
# GWC: set([u'Walking speed at advanced age'])
# US:  set([('longevity|selected', 'Walking speed exam 7')])
#
# 17903295 rs4471448 gwas_central
# GWC: set([u'Walking speed at advanced age'])
# US:  set([('longevity|selected', 'Walking speed exam 7')])
#
# 17903295 rs10515522 set([('longevity|selected', 'Walking speed')])
# 17903295 rs10501636 set([('longevity|selected', '')])
# 17903295 rs1994854 set([('longevity|selected', '')])
# 17903295 rs10492036 set([('longevity|selected', 'Biologic age'), ('longevity|selected', 'Walking speed')])
# 17903295 rs310575 set([('longevity|selected', 'Biologic Age'), ('longevity|selected', 'Walking speed')])
# 17903295 rs10231641 set([('longevity|selected', 'Biologic Age'), ('longevity|selected', 'Walking speed')])
# 17903295 rs2725369 set([('longevity|selected', 'Morbidity-free survival at age 65')])
# 17903295 rs6700734 set([('longevity|selected', 'Walking speed')])
# 17903295 rs7844834 set([('longevity|selected', 'Biologic age'), ('longevity|selected', 'Walking speed')])
# 17903295 rs6657082 set([('longevity|selected', '')])
# 17903295 rs604578 set([('longevity|selected', '')])
# 17903295 rs10509200 set([('longevity|selected', '')])
# 17903295 rs10490518 set([('longevity|selected', 'Morbidity-free at 65'), ('longevity|selected', 'Age at Death')])
# 17903295 rs10500784 set([('longevity|selected', 'Morbidity-free survival at age 65')])
# 17903295 rs2769261 set([('longevity|selected', 'Walking speed, exam 7')])
# 17903295 rs687045 set([('longevity|selected', 'Age at death')])
# 17903295 rs1475398 set([('longevity|selected', 'Age at death')])
# 17903295 rs2340392 set([('longevity|selected', '')])
# 17903295 rs10507486 set([('longevity|selected', 'Age at death')])
# 17903295 rs9322361 set([('longevity|selected', 'Walking speed')])
# 17903295 rs353810 set([('longevity|selected', 'Biologic age by osseographic scoring system')])
# 17903295 rs2602044 set([('longevity|selected', 'Walking speed, exam 7')])
# 17903295 rs6433083 set([('longevity|selected', 'Walking speed')])
# 17903295 rs1923249 set([('longevity|selected', 'Biologic Age by OSS')])
# 17903295 rs959702 set([('longevity|selected', '')])
# 17903295 rs7862683 set([('longevity|selected', '')])
# 17903295 rs10488907 set([('longevity|selected', 'Morbidity-free at 65'), ('longevity|selected', 'Age at Death')])
# ...
# US:  None
#
# 20858683 rs1408272 gwas_central
# GWC: set([u'Glycated hemoglobin levels'])
# US:  None
#
# 20858683 rs1402837 gwas_central
# GWC: set([u'Glycated hemoglobin levels'])
# US:  None
#
# 20858683 rs17342717 gwas_central
# GWC: set([u'Glycated hemoglobin levels'])
# US:  None
#
# 20858683 rs4737009 gwas_central
# GWC: set([u'Glycated hemoglobin levels'])
# US:  set([('Hemoglobin A', '')])
#
# 20858683 rs2413450 gwas_central
# GWC: set([u'Glycated hemoglobin levels'])
# US:  None
#
# ---
# 20861866 rs1329428 gwas_central
# GWC: set([u'Age-related macular degeneration'])
# US:  set([('age-related macular degeneration', '')])
#
# 20861866 rs10490924 gwas_central
# GWC: set([u'Age-related macular degeneration'])
# US:  set([('age-related macular degeneration', '')])
#
# 20861866 rs429608 gwas_central
# GWC: set([u'Age-related macular degeneration'])
# US:  set([('age-related macular degeneration', '')])
#
# 20861866 rs2230199 gwas_central
# GWC: set([u'Age-related macular degeneration'])
# US:  set([('age-related macular degeneration', '')])
#
# 20861866 rs641153 set([('age-related macular degeneration', '')])
# 20861866 rs3793917 set([('age-related macular degeneration', '')])
# 20861866 rs11129874 set([('age-related macular degeneration', '')])
# 20861866 rs1061170 set([('age-related macular degeneration', '')])
# 20861866 rs2679798 set([('age-related macular degeneration', '')])
# 20861866 rs3750848 set([('age-related macular degeneration', '')])
# 20861866 rs1344189 set([('age-related macular degeneration', '')])
# ---
# 20862305 rs1359790 gwas_central
# GWC: set([u'Type II diabetes'])
# US:  None
#
# 20862305 rs10906115 gwas_central
# GWC: set([u'Type II diabetes'])
# US:  None
#
# 20862305 rs1436955 gwas_central
# GWC: set([u'Type II diabetes'])
# US:  None
#
# 20862305 rs5015480 gwas_central
# GWC: set([u'Type II diabetes'])
# US:  set([('Type 2 Diabetes', '')])
#
# 20862305 rs10923931 set([('Type 2 Diabetes', '')])
# 20862305 rs391300 set([('Type 2 Diabetes', '')])
# 20862305 rs10811661 set([('Type 2 Diabetes', '')])
# 20862305 rs7593730 set([('Type 2 Diabetes', '')])
# 20862305 rs1495377 set([('Type 2 Diabetes', '')])
# 20862305 rs5215 set([('Type 2 Diabetes', '')])
# 20862305 rs2943641 set([('Type 2 Diabetes', '')])
# 20862305 rs8050136 set([('Type 2 Diabetes', '')])
# 20862305 rs2283228 set([('Type 2 Diabetes', '')])
# 20862305 rs13266634 set([('Type 2 Diabetes', '')])
# 20862305 rs17584499 set([('Type 2 Diabetes', '')])
# 20862305 rs12779790 set([('Type 2 Diabetes', '')])
# 20862305 rs7901695 set([('Type 2 Diabetes', '')])
# 20862305 rs10946398 set([('Type 2 Diabetes', '')])
# 20862305 rs4402960 set([('Type 2 Diabetes', '')])
# 20862305 rs4607103 set([('Type 2 Diabetes', '')])
# 20862305 rs10010131 set([('Type 2 Diabetes', '')])
# 20862305 rs864745 set([('Type 2 Diabetes', '')])
# 20862305 rs564398 set([('Type 2 Diabetes', '')])
# 20862305 rs7961581 set([('Type 2 Diabetes', '')])
# 20862305 rs1801282 set([('Type 2 Diabetes', '')])
# ---
# 20881960 rs2284746 gwas_central
# GWC: set([u'Height'])
# US:  None
#
# 20881960 rs6470764 gwas_central
# GWC: set([u'Height'])
# US:  None
#
# 20881960 rs788867 gwas_central
# GWC: set([u'Height'])
# US:  None
#
# 20881960 rs2665838 gwas_central
# GWC: set([u'Height'])
# US:  set([('height|affect', '')])
#
# 20881960 rs7274811 gwas_central
# GWC: set([u'Height'])
# US:  None
#
# 20881960 rs2580816 gwas_central
# GWC: set([u'Height'])
# US:  None
#
# 20881960 rs6569648 gwas_central
# GWC: set([u'Height'])
# US:  None
#
# 20881960 rs2871865 gwas_central
# GWC: set([u'Height'])
# US:  None
#
# 20881960 rs10748128 gwas_central
# GWC: set([u'Height'])
# US:  None
#
# 20881960 rs1950500 gwas_central
# GWC: set([u'Height'])
# US:  None
#
# 20881960 rs10037512 gwas_central
# GWC: set([u'Height'])
# US:  None
#
# 20881960 rs17511102 gwas_central
# GWC: set([u'Height'])
# US:  None
#
# 20881960 rs572169 gwas_central
# GWC: set([u'Height'])
# US:  set([('height|affect', '')])
#
# 20881960 rs10770705 gwas_central
# GWC: set([u'Height'])
# US:  None
#
# 20881960 rs543650 gwas_central
# GWC: set([u'Height'])
# US:  None
#
# 20881960 rs3129109 gwas_central
# GWC: set([u'Height'])
# US:  None
#
# 20881960 rs7466269 gwas_central
# GWC: set([u'Height'])
# US:  None
#
# 20881960 rs2093210 gwas_central
# GWC: set([u'Height'])
# US:  None
#
# 20881960 rs2638953 gwas_central
# GWC: set([u'Height'])
# US:  None
#
# 20881960 rs9969804 gwas_central
# GWC: set([u'Height'])
# US:  None
#
# 20881960 rs26868 gwas_central
# GWC: set([u'Height'])
# US:  None
#
# 20881960 rs4986172 gwas_central
# GWC: set([u'Height'])
# US:  None
#
# 20881960 rs7507204 gwas_central
# GWC: set([u'Height'])
# US:  None
#
# 20881960 rs17318596 gwas_central
# GWC: set([u'Height'])
# US:  None
#
# 20881960 rs274546 gwas_central
# GWC: set([u'Height'])
# US:  None
#
# 20881960 rs4665736 gwas_central
# GWC: set([u'Height'])
# US:  None
#
# 20881960 rs4282339 gwas_central
# GWC: set([u'Height'])
# US:  None
#
# 20881960 rs889014 gwas_central
# GWC: set([u'Height'])
# US:  None
#
# 20881960 rs11830103 gwas_central
# GWC: set([u'Height'])
# US:  None
#
# 20881960 rs2856321 gwas_central
# GWC: set([u'Height'])
# US:  None
#
# 20881960 rs6439167 gwas_central
# GWC: set([u'Height'])
# US:  None
#
# 20881960 rs12534093 gwas_central
# GWC: set([u'Height'])
# US:  None
#
# 20881960 rs1351164 gwas_central
# GWC: set([u'Height'])
# US:  None
#
# 20881960 rs720390 gwas_central
# GWC: set([u'Height'])
# US:  None
#
# 20881960 rs12680655 gwas_central
# GWC: set([u'Height'])
# US:  None
#
# 20881960 rs7697556 gwas_central
# GWC: set([u'Height'])
# US:  None
#
# 20881960 rs7849585 gwas_central
# GWC: set([u'Height'])
# US:  None
#
# 20881960 rs862034 gwas_central
# GWC: set([u'Height'])
# US:  None
#
# 20881960 rs7971536 gwas_central
# GWC: set([u'Height'])
# US:  None
#
# 20881960 rs11684404 gwas_central
# GWC: set([u'Height'])
# US:  None
#
# 20881960 rs634552 gwas_central
# GWC: set([u'Height'])
# US:  None
#
# 20881960 rs3782089 gwas_central
# GWC: set([u'Height'])
# US:  None
#
# 20881960 rs4072910 gwas_central
# GWC: set([u'Height'])
# US:  None
#
# 20881960 rs2145998 gwas_central
# GWC: set([u'Height'])
# US:  set([('height|affect', '')])
#
# 20881960 rs9863706 gwas_central
# GWC: set([u'Height'])
# US:  None
#
# 20881960 rs9835332 gwas_central
# GWC: set([u'Height'])
# US:  None
#
# 20881960 rs2778031 gwas_central
# GWC: set([u'Height'])
# US:  None
#
# 20881960 rs2336725 gwas_central
# GWC: set([u'Height'])
# US:  None
#
# 20881960 rs5742915 gwas_central
# GWC: set([u'Height'])
# US:  set([('height|affect', '')])
#
# 20881960 rs724016 gwas_central
# GWC: set([u'Height'])
# US:  None
#
# 20881960 rs2871960 gwas_central
# GWC: set([u'Height'])
# US:  None
#
# 20881960 rs1991431 gwas_central
# GWC: set([u'Height'])
# US:  None
#
# 20881960 rs7632381 gwas_central
# GWC: set([u'Height'])
# US:  None
#
# 20881960 rs1582874 gwas_central
# GWC: set([u'Height'])
# US:  None
#
# 20881960 rs6808936 gwas_central
# GWC: set([u'Height'])
# US:  None
#
# 20881960 rs6763927 gwas_central
# GWC: set([u'Height'])
# US:  None
#
# 20881960 rs1344674 gwas_central
# GWC: set([u'Height'])
# US:  None
#
# 20881960 rs9846396 gwas_central
# GWC: set([u'Height'])
# US:  None
#
# 20881960 rs6764769 gwas_central
# GWC: set([u'Height'])
# US:  None
#
# 20881960 rs6763931 gwas_central
# GWC: set([u'Height'])
# US:  None
#
# 20881960 rs1344672 gwas_central
# GWC: set([u'Height'])
# US:  None
#
# 20881960 rs6440006 gwas_central
# GWC: set([u'Height'])
# US:  None
#
# 20881960 rs6440003 gwas_central
# GWC: set([u'Height'])
# US:  None
#
# 20881960 rs7624084 gwas_central
# GWC: set([u'Height'])
# US:  None
#
# 20881960 rs143384 gwas_central
# GWC: set([u'Height'])
# US:  None
#
# 20881960 rs6088820 gwas_central
# GWC: set([u'Height'])
# US:  None
#
# 20881960 rs6087704 gwas_central
# GWC: set([u'Height'])
# US:  None
#
# 20881960 rs1570004 gwas_central
# GWC: set([u'Height'])
# US:  None
#
# 20881960 rs6579234 gwas_central
# GWC: set([u'Height'])
# US:  None
#
# 20881960 rs6142379 gwas_central
# GWC: set([u'Height'])
# US:  None
#
# 20881960 rs1886691 gwas_central
# GWC: set([u'Height'])
# US:  None
#
# 20881960 rs224329 gwas_central
# GWC: set([u'Height'])
# US:  None
#
# 20881960 rs224333 gwas_central
# GWC: set([u'Height'])
# US:  None
#
# 20881960 rs725908 gwas_central
# GWC: set([u'Height'])
# US:  None
#
# 20881960 rs6142376 gwas_central
# GWC: set([u'Height'])
# US:  None
#
# 20881960 rs6142374 gwas_central
# GWC: set([u'Height'])
# US:  None
#
# 20881960 rs6141548 gwas_central
# GWC: set([u'Height'])
# US:  None
#
# 20881960 rs6088823 gwas_central
# GWC: set([u'Height'])
# US:  None
#
# 20881960 rs6088813 gwas_central
# GWC: set([u'Height'])
# US:  None
#
# 20881960 rs4911494 gwas_central
# GWC: set([u'Height'])
# US:  None
#
# 20881960 rs4911492 gwas_central
# GWC: set([u'Height'])
# US:  None
#
# 20881960 rs4911180 gwas_central
# GWC: set([u'Height'])
# US:  None
#
# 20881960 rs4911179 gwas_central
# GWC: set([u'Height'])
# US:  None
#
# 20881960 rs6785073 gwas_central
# GWC: set([u'Height'])
# US:  None
#
# 20881960 rs13091182 gwas_central
# GWC: set([u'Height'])
# US:  None
#
# 20881960 rs6142373 gwas_central
# GWC: set([u'Height'])
# US:  None
#
# 20881960 rs6088815 gwas_central
# GWC: set([u'Height'])
# US:  None
#
# 20881960 rs4911491 gwas_central
# GWC: set([u'Height'])
# US:  None
#
# 20881960 rs4911178 gwas_central
# GWC: set([u'Height'])
# US:  None
#
# 20881960 rs6767899 gwas_central
# GWC: set([u'Height'])
# US:  None
#
# 20881960 rs2011092 gwas_central
# GWC: set([u'Height'])
# US:  None
#
# 20881960 rs13099193 gwas_central
# GWC: set([u'Height'])
# US:  None
#
# 20881960 rs13066993 gwas_central
# GWC: set([u'Height'])
# US:  None
#
# 20881960 rs745931 gwas_central
# GWC: set([u'Height'])
# US:  None
#
# 20881960 rs2248393 gwas_central
# GWC: set([u'Height'])
# US:  None
#
# 20881960 rs6142358 gwas_central
# GWC: set([u'Height'])
# US:  None
#
# 20881960 rs4911496 gwas_central
# GWC: set([u'Height'])
# US:  None
#
# 20881960 rs1540927 gwas_central
# GWC: set([u'Height'])
# US:  None
#
# 20881960 rs9821337 gwas_central
# GWC: set([u'Height'])
# US:  None
#
# 20881960 rs11107116 set([('height|affect', '')])
# 20881960 rs2421992 set([('height|affect', '')])
# 20881960 rs225694 set([('height|affect', '')])
# 20881960 rs10958476 set([('height|affect', '')])
# 20881960 rs2070776 set([('height|affect', '')])
# 20881960 rs6892884 set([('height|affect', '')])
# 20881960 rs7763064 set([('height|affect', '')])
# 20881960 rs1173727 set([('height|affect', '')])
# 20881960 rs227724 set([('height|affect', '')])
# 20881960 rs1401796 set([('height|affect', '')])
# 20881960 rs6449353 set([('height|affect', '')])
# 20881960 rs7460090 set([('height|affect', '')])
# 20881960 rs7652177 set([('height|affect', '')])
# 20881960 rs879882 set([('height|affect', '')])
# 20881960 rs3791675 set([('height|affect', '')])
# 20881960 rs12153391 set([('height|affect', '')])
# 20881960 rs3792752 set([('height|affect', '')])
# 20881960 rs17346452 set([('height|affect', '')])
# 20881960 rs6938239 set([('height|affect', '')])
# 20881960 rs1367226 set([('height|affect', '')])
# 20881960 rs2780226 set([('height|affect', '')])
# 20881960 rs10187066 set([('height|affect', '')])
# 20881960 rs7916441 set([('height|affect', '')])
# 20881960 rs2280470 set([('height|affect', '')])
# 20881960 rs12470505 set([('height|affect', '')])
# 20881960 rs2724475 set([('height|affect', '')])
# 20881960 rs7689420 set([('height|affect', '')])
# 20881960 rs2353398 set([('height|affect', '')])
# 20881960 rs2256183 set([('height|affect', '')])
# 20881960 rs10859563 set([('height|affect', '')])
# 20881960 rs4711336 set([('height|affect', '')])
# 20881960 rs16942341 set([('height|affect', '')])
# 20881960 rs750460 set([('height|affect', '')])
# ---
# 20885792 rs2075650 gwas_central
# GWC: set([u"Late onset Alzheimer's disease"])
# US:  set([('Late-Onset Alzheimer Disease|Chromosome', '')])
#
# 20885792 rs11754661 gwas_central
# GWC: set([u"Late onset Alzheimer's disease"])
# US:  set([('Late-Onset Alzheimer Disease|Chromosome', '')])
#
# 20885792 rs4676049 gwas_central
# GWC: set([u"Late onset Alzheimer's disease"])
# US:  None
#
# 20885792 rs6859 gwas_central
# GWC: set([u"Late onset Alzheimer's disease"])
# US:  set([('Late-Onset Alzheimer Disease|Chromosome', '')])
#
# 20885792 rs405509 set([('Late-Onset Alzheimer Disease|Chromosome', '')])
# 20885792 rs10402271 set([('Late-Onset Alzheimer Disease|Chromosome', '')])
# 20885792 rs439401 set([('Late-Onset Alzheimer Disease|Chromosome', '')])
# 20885792 rs6509916 set([('Late-Onset Alzheimer Disease|Chromosome', '')])
# 20885792 rs157580 set([('Late-Onset Alzheimer Disease|Chromosome', '')])
# 20885792 rs509512 set([('Late-Onset Alzheimer Disease|Chromosome', '')])
# 20885792 rs8106922 set([('Late-Onset Alzheimer Disease|Chromosome', '')])
# 20885792 rs679670 set([('Late-Onset Alzheimer Disease|Chromosome', '')])
# ---
# 20921969 rs4959235 gwas_central
# GWC: set([u'Antipsychotic-induced QTc interval prolongation, quetiapine'])
# US:  set([('antipsychotic', 'quetiapine/QTc')])
#
# 20921969 rs10458561 gwas_central
# GWC: set([u'Antipsychotic-induced QTc interval prolongation, risperidone'])
# US:  set([('antipsychotic', 'risperidone/QTc')])
#
# 20921969 rs6468544 gwas_central
# GWC: set([u'Antipsychotic-induced QTc interval prolongation, risperidone'])
# US:  set([('antipsychotic', 'risperidone/QTc')])
#
# 20921969 rs16895513 set([('antipsychotic', 'risperidone/QTc')])
# ---
# 20927387 rs7775698 gwas_central
# GWC: set([u'Mean corpuscular hemoglobin', u'Red blood cell count'])
# US:  set([('Red Blood Cell|Medical', 'MCV'), ('Red Blood Cell|Medical', 'RBC count'), ('Red Blood Cell|Medical', 'MCH')])
#
# 20927387 rs855791 gwas_central
# GWC: set([u'Mean corpuscular hemoglobin', u'Mean corpuscular volume'])
# US:  set([('Red Blood Cell|Medical', 'MCV'), ('Red Blood Cell|Medical', 'MCHC'), ('Red Blood Cell|Medical', 'MCH')])
#
# 20927387 rs1800562 gwas_central
# GWC: set([u'Mean corpuscular hemoglobin', u'Mean corpuscular volume'])
# US:  set([('Red Blood Cell|Medical', 'MCV'), ('Red Blood Cell|Medical', 'MCH')])
#
# 20927387 rs6569992 gwas_central
# GWC: set([u'Mean corpuscular hemoglobin', u'Red blood cell count', u'Mean corpuscular volume'])
# US:  set([('Red Blood Cell|Medical', 'MCV'), ('Red Blood Cell|Medical', 'RBC count'), ('Red Blood Cell|Medical', 'MCH')])
#
# 20927387 rs17342717 gwas_central
# GWC: set([u'Mean corpuscular hemoglobin'])
# US:  set([('Red Blood Cell|Medical', 'MCH')])
#
# 20927387 rs7775698 gwas_central
# GWC: set([u'Mean corpuscular hemoglobin', u'Red blood cell count'])
# US:  set([('Red Blood Cell|Medical', 'MCV'), ('Red Blood Cell|Medical', 'RBC count'), ('Red Blood Cell|Medical', 'MCH')])
#
# 20927387 rs6569992 gwas_central
# GWC: set([u'Mean corpuscular hemoglobin', u'Red blood cell count', u'Mean corpuscular volume'])
# US:  set([('Red Blood Cell|Medical', 'MCV'), ('Red Blood Cell|Medical', 'RBC count'), ('Red Blood Cell|Medical', 'MCH')])
#
# 20927387 rs9494145 gwas_central
# GWC: set([u'Mean corpuscular volume'])
# US:  set([('Red Blood Cell|Medical', 'MCV'), ('Red Blood Cell|Medical', 'RBC count'), ('Red Blood Cell|Medical', 'MCH')])
#
# 20927387 rs855791 gwas_central
# GWC: set([u'Mean corpuscular hemoglobin', u'Mean corpuscular volume'])
# US:  set([('Red Blood Cell|Medical', 'MCV'), ('Red Blood Cell|Medical', 'MCHC'), ('Red Blood Cell|Medical', 'MCH')])
#
# 20927387 rs6569992 gwas_central
# GWC: set([u'Mean corpuscular hemoglobin', u'Red blood cell count', u'Mean corpuscular volume'])
# US:  set([('Red Blood Cell|Medical', 'MCV'), ('Red Blood Cell|Medical', 'RBC count'), ('Red Blood Cell|Medical', 'MCH')])
#
# 20927387 rs1800562 gwas_central
# GWC: set([u'Mean corpuscular hemoglobin', u'Mean corpuscular volume'])
# US:  set([('Red Blood Cell|Medical', 'MCV'), ('Red Blood Cell|Medical', 'MCH')])
#
# 20927387 rs4820268 gwas_central
# GWC: set([u'Mean corpuscular hemoglobin concentration'])
# US:  set([('Red Blood Cell|Medical', 'MCHC'), ('Red Blood Cell|Medical', 'MCH')])
#
# 20927387 rs9376092 set([('Red Blood Cell|Medical', 'MCV'), ('Red Blood Cell|Medical', 'RBC count'), ('Red Blood Cell|Medical', 'MCH')])
# 20927387 rs9402686 set([('Red Blood Cell|Medical', 'MCV')])
# 20927387 rs198846 set([('Red Blood Cell|Medical', 'MCV'), ('Red Blood Cell|Medical', 'MCH')])
# 20927387 rs17064262 set([('Red Blood Cell|Medical', 'MCV'), ('Red Blood Cell|Medical', 'MCH')])
# 20927387 rs2413450 set([('Red Blood Cell|Medical', 'MCV')])
# 20927387 rs4895441 set([('Red Blood Cell|Medical', 'MCV'), ('Red Blood Cell|Medical', 'RBC count'), ('Red Blood Cell|Medical', 'MCH')])
# 20927387 rs9483788 set([('Red Blood Cell|Medical', 'RBC count')])
# 20927387 rs5756506 set([('Red Blood Cell|Medical', 'MCH')])
# 20927387 rs5756504 set([('Red Blood Cell|Medical', 'MCH')])
# ---
# 20932310 rs12643654 gwas_central
# GWC: set([u"P-tau181p, Alzheimer's disease"])

# %%
BLACKLIST=['19043545', '18464913', '17997608', '17447842', '19936222', '19503597', '20041166']

# %% [markdown]
# #### Error analysis over top 15 documents

# %% [markdown]
# Crohns disease (1st paper): Table is really messed up, but could solve it with a specialized extractor that looks at induced cells.
#
# Weight/bmi: The table is only a screenshot
#
# Acronyms at the end: The acronym explanations are in the caption of the table
#
# Some acroynms aren't resolved because an extra letter is added to them e.g. AXYZ instead of XYZ

# %% [markdown]
# ### Set up map of GWC to GWASDB phenotypes

# %%
out_set = set()
for a in assocs:
    s1 = gold_rel_dict[(a.paper.pubmed_id, a.snp.rs_id)]
    s2 = rel_dict.get((str(a.paper.pubmed_id), a.snp.rs_id), None)
    if s1 and s2:
        for name1 in s1:
            for name2a, name2b in s2:
                name1 = str(name1)
                score = phen_scores.get((name1.lower(), name2a.lower(), name2b.lower()), '')
                out_set.add('%s\t%s\t%s\t%s\n' % (name1, name2a, name2b, score))

with open('phenotype.mapping.tsv', 'w') as f:                    
    for out_str in out_set:
        f.write(out_str)

# %% [markdown]
# Dictionary legend in 0: wrong, 1: acronym, 2: imprecise, 3: correct

# %%
phen_map = dict()
phen_scores = dict()
with open('phenotype.mapping.annotated.txt') as f:                    
    lines = f.read().split('\r')
    for line in lines:
        fields = line.strip().split('\t')
        if fields[0] == 'Thiazide-induced':
            print fields
        fields = [re.sub('"', '', f) for f in fields]
        try:
            orig_name, glob_name, loc_name, score = fields
        except ValueError:
            if len(fields) == 2:
                orig_name, glob_name = fields
                loc_name = ''
            else:
                orig_name, glob_name, loc_name = fields
            score = 3
        phen_scores[(orig_name.lower(), glob_name.lower(), loc_name.lower())] = score
        if score in ('2', '3'):
            key = (glob_name, loc_name)
            if key not in phen_map: phen_map[key] = set()
            phen_map[key].add(orig_name)

# %% [markdown]
# ### Look at results!

# %%
import re

def paper_contains(pmid, quote):
    with open('../data/db/papers/%d.xml' % pmid) as f:
        txt = f.read()
        return True if re.search(quote, txt) else False

# %%
# display directly the results we found
n_correct = 0
n_imprecise = 0
n_missing = 0
n_wrong = 0
n_total = 0
n_new = 0
invalid_per_paper = { a.paper.pubmed_id : 0 for a in assocs }
seen = set()
for a in assocs:
#     if str(a.paper.pubmed_id) in BLACKLIST: continue
    if (a.paper.pubmed_id, a.snp.rs_id) in seen: continue
    seen.add((a.paper.pubmed_id, a.snp.rs_id))
    gold_phen_set = gold_rel_dict[(a.paper.pubmed_id, a.snp.rs_id)]
    pred_phen_set = rel_dict.get((str(a.paper.pubmed_id), a.snp.rs_id), {})
    tmp = list(pred_phen_set)
    if tmp and tmp[0][1].startswith('Age at'):
        n_correct += 1
        continue
    pred_phen_set2 = {m for p in pred_phen_set for m in phen_map.get(p, {})}
    if gold_phen_set & pred_phen_set2: 
        n_correct += 1
        n_total += 1
    else:
#         if True:
        if paper_contains(a.paper.pubmed_id, a.snp.rs_id):
            if a.paper.pubmed_id == 20195266:
                print a.snp.rs_id, gold_phen_set, pred_phen_set, pred_phen_set2
            if pred_phen_set2:
                n_wrong += 1
            else:
                n_missing += 1
            n_total += 1
            invalid_per_paper[a.paper.pubmed_id] += 1
#         print gold_phen_set
#         print pred_phen_set
#         print pred_phen_set2        
#         print

print n_correct, n_wrong, n_missing, n_total

print 'Biggest omissions:', sorted(invalid_per_paper.items(), key=lambda x: x[1], reverse=True)[:15]
# Out:
# 2530 33 395 2954
# Biggest omissions: [(23400010, 14), (19197348, 12), (22747683, 9), (22675492, 8), (21533175, 8), (23202124, 7), (22493691, 7), (23903356, 7), (23583978, 7), (23563607, 7), (22216198, 7), (23381943, 7), (24068962, 6), (22961080, 6), (23300278, 5)]

# %% [markdown]
# #### Notes from all papers:
#
# 19197348: (Korsae islanders) No global phenotype, need to handle phenotype headers. Some not parsed because exact match not in dict, need to search for n-grams
# 23400010: All the SNPs are in text!!
# 19305408: Phenotype incorrect? QT Interval vs sudden cardian death. But QT interval is in abstract
# 22760553: citalopram in dict but connected to a dash in title. Add "side effects" to matched keywords?
# 22747683: They're in text
# 22675492: Estradiol gets pushed our because "testosterone," and "testostreone" both present
# 21533175: can't parse 'Serum dehydroepiandrosterone sulphate levels' (acronym in text)
# 23202124: It's all in text
# 22493691: pvalue/rel not parsed in table (WTF!)
# 23903356: all in text (not abstract)
# 23583978: in the text (some in abstract)
# 23563607: Phenotype headers not fully matched (e.g. Obesity type-2) and "trails" instead of traits
#
#
#
# Idea: Match spans if they contain the same words, but potentially in a different order

# %% [markdown]
# #### Notes from first 100:
#
# 470 fully correct
#
# 19197348: Phenotype headers
# 18159244: Completely messed-up way of writing down p-values
# 17903302: Acronyms
# 17903305: Phenotype headers, errors (prostate vs breast cancer)
# 19043545: Mentions in text
# 17447842: Mentions in text (also: Messed-up way of writing table (induced cells should help)
# 17658951: Extraction from text
# 17903296: e.g. Neck phenotype acronym has an undocumented male/female suffix
# 19557161: In text, and one table entry strangely doesn't seem have been found

# %%
paper_id = '19557161'
for a in assocs:
    if str(a.paper.pubmed_id) == paper_id and paper_contains(a.paper.pubmed_id, a.snp.rs_id):
        print a.phenotype.name, a.snp.rs_id, rel_dict.get((paper_id, a.snp.rs_id), None)
# Out:
# Waist-hip ratio rs2605100 None
# Waist circumference rs987237 None
# Waist circumference rs545854 None
# Waist circumference rs6429082 None

# %%
with open('associations.tsv', 'w') as f:
    for (pmid, rsid, (glob_phen, loc_phen)) in associations:
        pvals = pval_dict.get(pmid, None)
        pval = min(pvals.get(rsid, [-1])) if pvals else -1
        loc_phen = '-' if not loc_phen else loc_phen

        f.write('%s\t%s\t%s\t%s\t%f\n' % (pmid, rsid, glob_phen, loc_phen, pval))
