# %% [markdown]
# # Evaluation notebook

# %% [markdown]
# Here, we will evaluate the relations extracted in all the other notebooks

# %%
# %load_ext autoreload
# %autoreload 2

import sys
import cPickle
import numpy as np

# import snorkel and gwasdb
sys.path.append('../snorkel')
sys.path.append('../src')
sys.path.append('../src/crawler')

# set up paths
abstract_dir = '../data/db/papers'

# %%
from snorkel.parser import XMLDocParser, HTMLParser, CorpusParser
from extractor.parser import UnicodeXMLTableDocParser, UnicodeTableParser

xml_parser = UnicodeXMLTableDocParser(
    path=abstract_dir,
    doc='./*',
    text='.//table',
    id='.//article-id[@pub-id-type="pmid"]/text()',
    keep_xml_tree=True)

table_parser = UnicodeTableParser()
html_parser = HTMLParser(path='../data/db/papers/')
cp = CorpusParser(xml_parser, table_parser)
# %time corpus = cp.parse_corpus(name='GWAS Corpus')
# Out:
# CPU times: user 14min 49s, sys: 47.4 s, total: 15min 37s
# Wall time: 23min 30s

# %% [markdown]
# ## Loading results from other notebooks

# %% [markdown]
# #### Phenotype/rsid relations from tables

# %%
phen_table_associations = dict()
with open('phen-rsid.table.rel.all.tsv') as f:
    for line in f:
        fields = line.strip().split('\t')
        pmid, rsid, phen, pval, _, table_id, row_id, col_id = fields
        # note that we assume that an rsid at a givel location will correspond to 1 phenotype
        phen_table_associations[pmid, table_id, row_id, col_id] = (rsid, phen)
        
print len(phen_table_associations), 'loaded, e.g.:'
print phen_table_associations.items()[:5]
# Out:
# 2130 loaded, e.g.:
# [(('21347282', '1', '3', '1'), ('rs937254', 'HDL-C')), (('23836780', '0', '3', '1'), ('rs3213787', 'Glaucoma')), (('17903302', '4', '31', '2'), ('rs9307847', 'CB-PWV')), (('17903307', '3', '2', '2'), ('rs9325117', 'longitudinal slope of fef mean fev')), (('17903298', '3', '12', '3'), ('rs10510418', 'Fasting insulin'))]

# %% [markdown]
# #### PMID/Phenotype relations extracted from titles/abstracts

# %%
phen_text_associations = dict()
with open('phenotypes.extracted.tsv') as f:
    for line in f:
        pmid, phen = line.strip().split('\t')
        phen_text_associations[pmid] = phen
        
print len(phen_text_associations), 'loaded, e.g.:'
print phen_text_associations.items()[:5]
# Out:
# 589 loaded, e.g.:
# [('23738518', 'reading|language'), ('19056611', 'Type 2 Diabetes'), ('21298047', 'European-Origin|Substance Dependence'), ('23104006', 'endometriosis'), ('20072603', 'Osteoporosis')]

# %% [markdown]
# #### RSID/Pvalue relations extracted from tables

# %%
pval_table_associations = dict()
with open('pval-rsid.raw.tsv') as f:
    for line in f:
        pmid, rsid, table_id, row_id, col_id, pval = line.strip().split('\t')
        pval, table_id, row_id, col_id = float(pval), int(table_id), int(row_id), int(col_id)
        
        key = pmid, table_id, row_id, col_id, rsid
        if key not in pval_table_associations: pval_table_associations[key] = set()
        pval_table_associations[key].add(pval)

print len(pval_table_associations), 'loaded, e.g.:'
print pval_table_associations.items()[:5]
# Out:
# 10681 loaded, e.g.:
# [(('22504420', 0, 33, 0, 'rs4790881'), set([0.0, 0.0006, 2e-06])), (('22396660', 1, 6, 1, 'rs11746443'), set([0.98])), (('17903302', 1, 21, 2, 'rs1408263'), set([2.4e-05])), (('17903294', 2, 20, 1, 'rs727979'), set([2.6e-05, 7e-06])), (('17903307', 1, 47, 1, 'rs1409149'), set([9e-06]))]

# %% [markdown]
# #### Singleton RSids

# %%
singleton_associations = dict()
with open('rsids.singletons.all.tsv') as f:
    for line in f:
        pmid, table_id, row_num, col_num, rsid = line.strip().split()
        singleton_associations[pmid, table_id, row_num, col_num] = rsid

print len(singleton_associations), 'loaded, e.g.:'
print singleton_associations.items()[:5]
# Out:
# 12309 loaded, e.g.:
# [(('17903303', '2', '9', '2'), 'rs28207'), (('25742292', '1', '13', '5'), 'rs7919841'), (('17903302', '4', '31', '2'), 'rs9307847'), (('25129146', '0', '2', '0'), 'rs7447927'), (('19096518', '0', '3', '0'), 'rs563694')]

# %% [markdown]
# ## Construct a list valid relations

# %%
# TODO: load pvalues properly, use them to filter stuff downstream, do acroynm resolution here

# %%
import re

def clean(phen):
    phen = re.sub('[)():.]+', '', phen)
    phen = re.sub('^or ', '', phen)
    phen = phen.strip()
    return phen

associations = []

# record table associations wth pval < 1e-5 or no pval reported
chosen_rsids = set()
tables_with_pvals = { table_id for 
                      (pmid, table_id, row_id, col_id), (rsid, loc_phen) in phen_table_associations.items() 
                      if (pmid, table_id, row_id, col_id, rsid) in pval_table_associations }
for (pmid, table_id, row_id, col_id), (rsid, loc_phen) in phen_table_associations.items():
    pvals = pval_table_associations.get((pmid, table_id, row_id, col_id, rsid), [-1])
    glob_phen = clean(phen_text_associations[pmid])
    if min(pvals) < 1e-5:
        associations.append((pmid, rsid, (glob_phen, loc_phen)))
        chosen_rsids.add((pmid, table_id, row_id, col_id, rsid))


# record associations with no local phenotype
for (pmid, table_id, row_id, col_id, rsid), pvals in pval_table_associations.items():
    # skip low-pvalue snps and snps that we already added
    if pvals and min(pvals) > 1e-5: continue
    if (pmid, table_id, row_id, col_id, rsid) in chosen_rsids: continue
    
    # append with global phenotype
    phen = clean(phen_text_associations[pmid])
    associations.append((pmid, rsid, (phen, '')))    
    chosen_rsids.add((pmid, table_id, row_id, col_id, rsid))

# # record singletons
# tables_found = {table_id for _, table_id, _, _, _ in pval_table_associations}
# for (pmid, table_id, row_id, col_id), rsid in singleton_associations.items():
#     if (pmid, table_id, row_id, col_id, rsid) in chosen_rsids: continue
#     if table_id in tables_found: continue
#     phen = clean(phen_text_associations[pmid])
#     associations.append((pmid, rsid, (phen, ''))) 

print len(associations), 'associations, e.g.:'
print associations[:5]
# Out:
# 9240 associations, e.g.:
# [('21347282', 'rs937254', ('Coronary Heart Disease', 'HDL-C')), ('23836780', 'rs3213787', ('intraocular pressure|glaucoma', 'Glaucoma')), ('17903302', 'rs9307847', ('arterial stiffness|blood pressure', 'CB-PWV')), ('17903307', 'rs9325117', ('pulmonary function', 'longitudinal slope of fef mean fev')), ('17903298', 'rs10510418', ('diabetes-related traits', 'Fasting insulin'))]

# %% [markdown]
# ## Comparing to GWAS central

# %%
from db.kb import KnowledgeBase

kb = KnowledgeBase()
assocs = [assoc for doc in corpus.documents for assoc in kb.assoc_by_pmid(doc.name) if assoc.source == 'gwas_central' and assoc.pvalue < 1e-5]

print '%d documents, %d associations' % (len(corpus.documents), len(assocs))
# Out:
# 589 documents, 7629 associations

# %%
rel_dict = { (pmid, rsid) : set() for (pmid, rsid, phen) in associations }
for (pmid, rsid, phen) in associations:
    rel_dict[(pmid, rsid)].add(phen)

gold_rel_dict = { (a.paper.pubmed_id, a.snp.rs_id) : set() for a in assocs }
for a in assocs:
    gold_rel_dict[(a.paper.pubmed_id, a.snp.rs_id)].add(a.phenotype.name)

# %%
# display directly the results we found
for doc in corpus.documents:
#     continue
    rsids_seen = set()
    for a in assocs:
        if str(a.paper.pubmed_id) != doc.name: continue
        rsids_seen.add(a.snp.rs_id)
        
#         # print old snps
#         print a.paper.pubmed_id, a.snp.rs_id, a.source
#         print 'GWC:', gold_rel_dict[(a.paper.pubmed_id, a.snp.rs_id)]
#         print 'US: ', rel_dict.get((str(a.paper.pubmed_id), a.snp.rs_id), None)
#         print
    
    # print new snps
    for (pmid, rsid), phens in rel_dict.items():
        if pmid != doc.name: continue
        if rsid in rsids_seen: continue
        print pmid, rsid, phens
    print '---'
# Out:
# ---
# ---
# ---
# 17903292 rs10502302 set([('endocrine-related traits|kidney', 'Serum creatinine (exam 5)')])
# 17903292 rs723464 set([('endocrine-related traits|kidney', ''), ('endocrine-related traits|kidney', 'urinary albumin excretion')])
# 17903292 rs754958 set([('endocrine-related traits|kidney', 'Serum Phosphorous')])
# 17903292 rs727087 set([('endocrine-related traits|kidney', 'glomerular filtration rate')])
# 17903292 rs2885618 set([('endocrine-related traits|kidney', 'glomerular filtration rate')])
# 17903292 rs10495487 set([('endocrine-related traits|kidney', 'Uric acid')])
# 17903292 rs10486135 set([('endocrine-related traits|kidney', 'glomerular filtration rate')])
# 17903292 rs10484370 set([('endocrine-related traits|kidney', 'Serum Calcium')])
# 17903292 rs10512437 set([('endocrine-related traits|kidney', 'glomerular filtration rate')])
# 17903292 rs10489578 set([('endocrine-related traits|kidney', 'Serum creatinine (exam 6)'), ('endocrine-related traits|kidney', 'glomerular filtration rate (exam 6)')])
# 17903292 rs911122 set([('endocrine-related traits|kidney', 'urinary albumin excretion \xe2\x89\xa5 30*'), ('endocrine-related traits|kidney', 'cst3')])
# 17903292 rs2480555 set([('endocrine-related traits|kidney', 'glomerular filtration rate')])
# 17903292 rs10496887 set([('endocrine-related traits|kidney', 'glomerular filtration rate')])
# 17903292 rs10511176 set([('endocrine-related traits|kidney', 'glomerular filtration rate (exam 7)')])
# 17903292 rs1005066 set([('endocrine-related traits|kidney', 'glomerular filtration rate')])
# 17903292 rs10485409 set([('endocrine-related traits|kidney', ''), ('endocrine-related traits|kidney', 'urinary albumin excretion')])
# 17903292 rs10515134 set([('endocrine-related traits|kidney', 'Luteinizing Hormone')])
# 17903292 rs2145231 set([('endocrine-related traits|kidney', 'cst3')])
# 17903292 rs3760626 set([('endocrine-related traits|kidney', 'chronic kidney disease')])
# ---
# 17903293 rs4899940 set([('biomarker traits', 'Interleukin-6, C-reactive protein and Fibrinogen')])
# 17903293 rs910232 set([('biomarker traits', 'C-reactive protein: exams 2, 5, 6, 7')])
# 17903293 rs7969455 set([('biomarker traits', 'Interleukin-6, C-reactive protein and Fibrinogen')])
# 17903293 rs10503717 set([('biomarker traits', 'Interleukin-6, C-reactive protein and Fibrinogen')])
# 17903293 rs3110134 set([('biomarker traits', 'Interleukin-6, C-reactive protein and Fibrinogen')])
# 17903293 rs1119582 set([('biomarker traits', ''), ('biomarker traits', 'C-reactive protein average exams 2,6,7')])
# 17903293 rs9319160 set([('biomarker traits', 'C-reactive protein: exams 2, 5, 6, 7')])
# 17903293 rs1457590 set([('biomarker traits', 'Interleukin-6, C-reactive protein and Fibrinogen')])
# 17903293 rs2359763 set([('biomarker traits', 'Interleukin-6, C-reactive protein and Fibrinogen')])
# 17903293 rs2016740 set([('biomarker traits', 'Interleukin-6, C-reactive protein and Fibrinogen')])
# 17903293 rs698270 set([('biomarker traits', 'Interleukin-6, C-reactive protein and Fibrinogen')])
# 17903293 rs17532515 set([('biomarker traits', ''), ('biomarker traits', 'Bilirubin')])
# 17903293 rs877936 set([('biomarker traits', 'Interleukin-6, C-reactive protein and Fibrinogen')])
# 17903293 rs6848323 set([('biomarker traits', 'Interleukin-6, C-reactive protein and Fibrinogen')])
# 17903293 rs719006 set([('biomarker traits', 'Interleukin-6, C-reactive protein and Fibrinogen')])
# 17903293 rs1436336 set([('biomarker traits', 'Interleukin-6, C-reactive protein and Fibrinogen')])
# 17903293 rs847428 set([('biomarker traits', 'Interleukin-6, C-reactive protein and Fibrinogen')])
# 17903293 rs1436136 set([('biomarker traits', 'Interleukin-6, C-reactive protein and Fibrinogen')])
# ---
# 17903294 rs2178692 set([('hematological phenotypes', 'red blood cell count')])
# 17903294 rs2239138 set([('hematological phenotypes', 'wVW, exam 5')])
# 17903294 rs1273819 set([('hematological phenotypes', 'Fibrinogen')])
# 17903294 rs4525555 set([('hematological phenotypes', 'Platelet Aggregation, ADP, exam 5'), ('hematological phenotypes', 'Platelet Aggregation, Collagen, exam 5'), ('hematological phenotypes', 'Platelet Aggregation, epinephrine, exam 5')])
# 17903294 rs2066864 set([('hematological phenotypes', 'Fibrinogen, average'), ('hematological phenotypes', 'Fibrinogen, exam 7'), ('hematological phenotypes', 'Fibrinogen, exam 5'), ('hematological phenotypes', 'Fibrinogen, exam 6')])
# 17903294 rs4148751 set([('hematological phenotypes', 'platelet aggregation (ADP-induced)')])
# 17903294 rs917858 set([('hematological phenotypes', 'wVW, exam 5')])
# 17903294 rs10514670 set([('hematological phenotypes', 'von willebrand factor')])
# 17903294 rs4133289 set([('hematological phenotypes', ''), ('hematological phenotypes', 'hemoglobin')])
# 17903294 rs917859 set([('hematological phenotypes', 'wVW, exam 5')])
# 17903294 rs10514838 set([('hematological phenotypes', 'hemoglobin')])
# 17903294 rs17310225 set([('hematological phenotypes', 'platelet aggregation (collagen-induced)')])
# 17903294 rs4591494 set([('hematological phenotypes', 'factor vii'), ('hematological phenotypes', '')])
# 17903294 rs2015729 set([('hematological phenotypes', 'Platelet Aggregation, ADP, exam 5'), ('hematological phenotypes', 'Platelet Aggregation, Collagen, exam 5'), ('hematological phenotypes', 'Platelet Aggregation, epinephrine, exam 5')])
# 17903294 rs20037 set([('hematological phenotypes', 'red blood cell count')])
# 17903294 rs2357013 set([('hematological phenotypes', ''), ('hematological phenotypes', 'hemoglobin')])
# 17903294 rs2271090 set([('hematological phenotypes', 'red blood cell count')])
# 17903294 rs2023048 set([('hematological phenotypes', 'red blood cell count')])
# 17903294 rs2400107 set([('hematological phenotypes', 'factor vii')])
# 17903294 rs1542535 set([('hematological phenotypes', 'factor vii')])
# 17903294 rs216901 set([('hematological phenotypes', 'wVW, exam 5')])
# 17903294 rs1510107 set([('hematological phenotypes', ''), ('hematological phenotypes', 'hemoglobin')])
# 17903294 rs6956010 set([('hematological phenotypes', 'PAI1, average'), ('hematological phenotypes', 'PAI1, exam 5'), ('hematological phenotypes', 'PAI1, exam 6')])
# 17903294 rs1074801 set([('hematological phenotypes', 'Fibrinogen, average'), ('hematological phenotypes', 'Fibrinogen, exam 7'), ('hematological phenotypes', 'Fibrinogen, exam 5'), ('hematological phenotypes', 'Fibrinogen, exam 6')])
# 17903294 rs10500770 set([('hematological phenotypes', 'red blood cell count')])
# 17903294 rs486633 set([('hematological phenotypes', 'red blood cell count')])
# 17903294 rs10500769 set([('hematological phenotypes', 'red blood cell count')])
# 17903294 rs216903 set([('hematological phenotypes', 'wVW, exam 5')])
# 17903294 rs216904 set([('hematological phenotypes', 'wVW, exam 5')])
# 17903294 rs38993 set([('hematological phenotypes', 'MCVavg12')])
# 17903294 rs9299952 set([('hematological phenotypes', 'MCVavg12')])
# 17903294 rs10514919 set([('hematological phenotypes', 'Platelet Aggregation, ADP, exam 5'), ('hematological phenotypes', 'Platelet Aggregation, Collagen, exam 5'), ('hematological phenotypes', 'Platelet Aggregation, epinephrine, exam 5')])
# 17903294 rs4460176 set([('hematological phenotypes', 'PAI1'), ('hematological phenotypes', '')])
# 17903294 rs6950982 set([('hematological phenotypes', 'PAI1, average'), ('hematological phenotypes', 'PAI1, exam 5'), ('hematological phenotypes', 'PAI1, exam 6')])
# 17903294 rs956275 set([('hematological phenotypes', 'red blood cell count')])
# 17903294 rs10522006 set([('hematological phenotypes', 'MCVavg12')])
# 17903294 rs1954971 set([('hematological phenotypes', 'von willebrand factor'), ('hematological phenotypes', '')])
# 17903294 rs10498633 set([('hematological phenotypes', 'red blood cell count')])
# ---
# 17903295 rs10515522 set([('longevity|age-related phenotypes', 'Walking speed')])
# 17903295 rs10492036 set([('longevity|age-related phenotypes', 'Walking speed')])
# 17903295 rs310575 set([('longevity|age-related phenotypes', 'Walking speed')])
# 17903295 rs1371217 set([('longevity|age-related phenotypes', 'Age at natural menopause')])
# 17903295 rs10231641 set([('longevity|age-related phenotypes', 'Walking speed')])
# 17903295 rs2725369 set([('longevity|age-related phenotypes', 'Morbidity-free survival at age 65')])
# 17903295 rs6700734 set([('longevity|age-related phenotypes', 'Walking speed')])
# 17903295 rs7844834 set([('longevity|age-related phenotypes', 'Walking speed')])
# 17903295 rs10490518 set([('longevity|age-related phenotypes', 'Morbidity-free at 65')])
# 17903295 rs10500784 set([('longevity|age-related phenotypes', 'Morbidity-free survival at age 65')])
# 17903295 rs2769261 set([('longevity|age-related phenotypes', 'Walking speed, exam 7')])
# 17903295 rs687045 set([('longevity|age-related phenotypes', 'Age at death')])
# 17903295 rs1475398 set([('longevity|age-related phenotypes', 'Age at death')])
# 17903295 rs10507486 set([('longevity|age-related phenotypes', 'Age at death')])
# 17903295 rs9322361 set([('longevity|age-related phenotypes', 'Walking speed')])
# 17903295 rs353810 set([('longevity|age-related phenotypes', 'Biologic age by osseographic scoring system')])
# 17903295 rs2602044 set([('longevity|age-related phenotypes', 'Walking speed, exam 7')])
# 17903295 rs6433083 set([('longevity|age-related phenotypes', 'Walking speed')])
# 17903295 rs1923249 set([('longevity|age-related phenotypes', 'Biologic Age by OSS')])
# 17903295 rs10488907 set([('longevity|age-related phenotypes', 'Morbidity-free at 65')])
# 17903295 rs9308261 set([('longevity|age-related phenotypes', 'Morbidity-free at 65')])
# 17903295 rs2165723 set([('longevity|age-related phenotypes', 'Walking speed')])
# 17903295 rs728546 set([('longevity|age-related phenotypes', 'Walking speed')])
# 17903295 rs1620210 set([('longevity|age-related phenotypes', 'Morbidity-free at 65')])
# 17903295 rs362356 set([('longevity|age-related phenotypes', 'Age at death')])
# 17903295 rs9301112 set([('longevity|age-related phenotypes', 'Walking speed')])
# 17903295 rs2833485 set([('longevity|age-related phenotypes', 'Walking speed')])
# 17903295 rs683907 set([('longevity|age-related phenotypes', 'Age at death')])
# 17903295 rs1203981 set([('longevity|age-related phenotypes', 'Biologic age by osseographic scoring system')])
# 17903295 rs6669117 set([('longevity|age-related phenotypes', 'Age at death')])
# 17903295 rs8011773 set([('longevity|age-related phenotypes', 'Walking speed, exam 7')])
# 17903295 rs2248383 set([('longevity|age-related phenotypes', 'Biologic age by osseographic scoring system')])
# 17903295 rs2918418 set([('longevity|age-related phenotypes', 'Walking speed')])
# 17903295 rs1343981 set([('longevity|age-related phenotypes', 'Age at death')])
# 17903295 rs1171278 set([('longevity|age-related phenotypes', 'Morbidity-free survival at age 65')])
# 17903295 rs873348 set([('longevity|age-related phenotypes', 'Walking speed')])
# 17903295 rs2374983 set([('longevity|age-related phenotypes', 'Age at death'), ('longevity|age-related phenotypes', 'Morbidity-free at 65'), ('longevity|age-related phenotypes', 'Morbidity-free survival at age 65')])
# 17903295 rs1002666 set([('longevity|age-related phenotypes', 'Biologic Age by OSS')])
# 17903295 rs719756 set([('longevity|age-related phenotypes', 'Morbidity-free survival at age 65')])
# 17903295 rs10509024 set([('longevity|age-related phenotypes', 'Age at natural menopause')])
# 17903295 rs31564 set([('longevity|age-related phenotypes', 'Walking speed')])
# 17903295 rs4752977 set([('longevity|age-related phenotypes', 'Morbidity-free at 65')])
# 17903295 rs2215921 set([('longevity|age-related phenotypes', 'Walking speed')])
# 17903295 rs1474827 set([('longevity|age-related phenotypes', 'Walking speed')])
# 17903295 rs2154380 set([('longevity|age-related phenotypes', 'Age at death')])
# 17903295 rs10493379 set([('longevity|age-related phenotypes', 'Age at death')])
# 17903295 rs952658 set([('longevity|age-related phenotypes', 'Walking speed')])
# 17903295 rs7135493 set([('longevity|age-related phenotypes', 'Walking speed')])
# 17903295 rs1368850 set([('longevity|age-related phenotypes', 'Morbidity-free at 65')])
# 17903295 rs1383636 set([('longevity|age-related phenotypes', 'Morbidity-free survival at age 65')])
# 17903295 rs911847 set([('longevity|age-related phenotypes', 'Biologic Age by OSS'), ('longevity|age-related phenotypes', 'Age at death')])
# 17903295 rs2254191 set([('longevity|age-related phenotypes', 'Morbidity-free at 65')])
# 17903295 rs10506274 set([('longevity|age-related phenotypes', 'Morbidity-free at 65')])
# 17903295 rs921055 set([('longevity|age-related phenotypes', 'Walking speed, exam 7')])
# 17903295 rs4943794 set([('longevity|age-related phenotypes', 'Age at death'), ('longevity|age-related phenotypes', 'Biologic Age by OSS')])
# 17903295 rs6682403 set([('longevity|age-related phenotypes', 'Morbidity-free at 65')])
# 17903295 rs256014 set([('longevity|age-related phenotypes', 'Biologic Age by OSS')])
# 17903295 rs10520603 set([('longevity|age-related phenotypes', 'Walking speed')])
# 17903295 rs4793513 set([('longevity|age-related phenotypes', 'Age at natural menopause')])
# 17903295 rs1978945 set([('longevity|age-related phenotypes', 'Walking speed')])
# 17903295 rs2831154 set([('longevity|age-related phenotypes', 'Morbidity-free at 65')])
# 17903295 rs6487366 set([('longevity|age-related phenotypes', 'Walking speed')])
# 17903295 rs4943116 set([('longevity|age-related phenotypes', 'Morbidity-free at 65')])
# 17903295 rs17190837 set([('longevity|age-related phenotypes', 'Morbidity-free at 65')])
# 17903295 rs7166323 set([('longevity|age-related phenotypes', 'Walking speed')])
# 17903295 rs2823322 set([('longevity|age-related phenotypes', 'Morbidity-free at 65')])
# 17903295 rs854523 set([('longevity|age-related phenotypes', 'Morbidity-free survival at age 65')])
# 17903295 rs1927914 set([('longevity|age-related phenotypes', 'Biologic Age by OSS')])
# 17903295 rs10492651 set([('longevity|age-related phenotypes', 'Walking speed')])
# 17903295 rs1362626 set([('longevity|age-related phenotypes', 'Walking speed, exam 7')])
# 17903295 rs655883 set([('longevity|age-related phenotypes', 'Morbidity-free at 65')])
# 17903295 rs10520361 set([('longevity|age-related phenotypes', 'Walking speed')])
# 17903295 rs243725 set([('longevity|age-related phenotypes', 'Morbidity-free at 65')])
# 17903295 rs3790426 set([('longevity|age-related phenotypes', 'Morbidity-free survival at age 65')])
# 17903295 rs4764600 set([('longevity|age-related phenotypes', 'Age at death')])
# 17903295 rs1862345 set([('longevity|age-related phenotypes', 'Walking speed')])
# ---
# 17903296 rs2008691 set([('association bone', 'nsa1')])
# 17903296 rs4988321 set([('association bone', 'femoral bmd**')])
# 17903296 rs1884052 set([('association bone', 'shaftz1r')])
# 17903296 rs10492922 set([('association bone', 'fnbmd')])
# 17903296 rs3866461 set([('association bone', 'femoral neck length**')])
# 17903296 rs7975232 set([('association bone', 'neckz1rm')])
# 17903296 rs3778099 set([('association bone', 'femoral bmd**')])
# 17903296 rs2189480 set([('association bone', 'neckz1rm')])
# 17903296 rs1304771 set([('association bone', 'nsa1')])
# 17903296 rs8081154 set([('association bone', 'fnbmd')])
# 17903296 rs2075555 set([('association bone', 'neckw1rf')])
# 17903296 rs1386389 set([('association bone', 'NeckZ1')])
# 17903296 rs6502901 set([('association bone', 'NeckZ1')])
# 17903296 rs11568820 set([('association bone', 'neckz1rm')])
# 17903296 rs4775936 set([('association bone', 'nsa1')])
# 17903296 rs1801133 set([('association bone', 'nsa1')])
# 17903296 rs2234693 set([('association bone', 'femoral neck length**')])
# 17903296 rs4988300 set([('association bone', 'femoral bmd**')])
# 17903296 rs10519297 set([('association bone', 'nsa1')])
# 17903296 rs7290139 set([('association bone', 'ShaftZ1')])
# 17903296 rs11327935 set([('association bone', 'neckw1rf')])
# 17903296 rs3736228 set([('association bone', 'femoral bmd**')])
# 17903296 rs1759687 set([('association bone', 'femoral neck length**')])
# 17903296 rs842288 set([('association bone', 'fnbmd')])
# 17903296 rs1800012 set([('association bone', 'neckw1rf')])
# 17903296 rs1107946 set([('association bone', 'neckw1rf')])
# 17903296 rs2094541 set([('association bone', 'NeckW1')])
# 17903296 rs10046 set([('association bone', 'nsa1')])
# 17903296 rs700518 set([('association bone', 'nsa1')])
# 17903296 rs10492028 set([('association bone', 'neckz1rm')])
# 17903296 rs10735810 set([('association bone', 'neckz1rm')])
# 17903296 rs1544410 set([('association bone', 'neckz1rm')])
# 17903296 rs10518923 set([('association bone', 'ShaftZ1')])
# 17903296 rs627174 set([('association bone', 'femoral bmd**')])
# 17903296 rs731236 set([('association bone', 'neckz1rm')])
# 17903296 rs750160 set([('association bone', 'NeckW1')])
# 17903296 rs9340799 set([('association bone', 'femoral bmd**')])
# 17903296 rs2320625 set([('association bone', 'shaft width**')])
# 17903296 rs11575899 set([('association bone', 'nsa1')])
# ---
# 17903297 rs10518241 set([('brain|cognitive test', 'wide-range achievement test')])
# 17903297 rs1846090 set([('brain|cognitive test', 'wide-range achievement test')])
# 17903297 rs2029395 set([('brain|cognitive test', 'factor 2:visual memory and organization'), ('brain|cognitive test', '')])
# 17903297 rs1328822 set([('brain|cognitive test', 'wide-range achievement test')])
# 17903297 rs236535 set([('brain|cognitive test', 'BMRIZLWMHVMV')])
# 17903297 rs1433527 set([('brain|cognitive test', 'temporal brain volume'), ('brain|cognitive test', '')])
# 17903297 rs2326510 set([('brain|cognitive test', 'parietal brain volume')])
# 17903297 rs10502991 set([('brain|cognitive test', 'wide-range achievement test'), ('brain|cognitive test', '')])
# 17903297 rs293966 set([('brain|cognitive test', 'boston naming test')])
# 17903297 rs10512187 set([('brain|cognitive test', 'wide-range achievement test')])
# 17903297 rs2975420 set([('brain|cognitive test', 'f3')])
# 17903297 rs4426714 set([('brain|cognitive test', 'BMRIZLWMHVMV')])
# 17903297 rs2765241 set([('brain|cognitive test', 'boston naming test')])
# 17903297 rs1547275 set([('brain|cognitive test', 'temporal brain volume')])
# ---
# 17903298 rs2938392 set([('diabetes-related traits', 'Fasting insulin')])
# 17903298 rs2444962 set([('diabetes-related traits', '28 yr time averaged fpg')])
# 17903298 rs290483 set([('diabetes-related traits', '28 yr time averaged fpg')])
# 17903298 rs10500300 set([('diabetes-related traits', 'homeostasis model insulin resistance')])
# 17903298 rs10513860 set([('diabetes-related traits', 'Fasting insulin')])
# 17903298 rs7903146 set([('diabetes-related traits', '28 yr time averaged fpg')])
# 17903298 rs876362 set([('diabetes-related traits', '28 yr time averaged fpg')])
# 17903298 rs10513843 set([('diabetes-related traits', 'homeostasis model insulin resistance')])
# 17903298 rs10512296 set([('diabetes-related traits', 'fasting plasma glucose')])
# 17903298 rs10509970 set([('diabetes-related traits', '28 yr time averaged fpg')])
# 17903298 rs10510634 set([('diabetes-related traits', ''), ('diabetes-related traits', '28 yr time averaged fpg')])
# 17903298 rs2877832 set([('diabetes-related traits', ''), ('diabetes-related traits', 'homeostasis model insulin resistance'), ('diabetes-related traits', 'Fasting Insulin')])
# 17903298 rs2837076 set([('diabetes-related traits', '28 yr time averaged fpg')])
# 17903298 rs878208 set([('diabetes-related traits', 'Fasting insulin')])
# 17903298 rs757110 set([('diabetes-related traits', 'Fasting insulin')])
# 17903298 rs722341 set([('diabetes-related traits', 'hemoglobin a1c')])
# 17903298 rs1489092 set([('diabetes-related traits', 'Incident DM')])
# 17903298 rs1890843 set([('diabetes-related traits', 'fasting plasma glucose')])
# 17903298 rs12255372 set([('diabetes-related traits', 'hemoglobin a1c')])
# 17903298 rs10510418 set([('diabetes-related traits', 'Fasting insulin')])
# 17903298 rs10510421 set([('diabetes-related traits', '28 yr time averaged fpg')])
# 17903298 rs2292101 set([('diabetes-related traits', 'Fasting insulin')])
# 17903298 rs10494382 set([('diabetes-related traits', 'hemoglobin a1c')])
# 17903298 rs1801282 set([('diabetes-related traits', '28 yr time averaged fpg'), ('diabetes-related traits', 'hemoglobin a1c')])
# 17903298 rs10509966 set([('diabetes-related traits', 'hemoglobin a1c')])
# 17903298 rs10510422 set([('diabetes-related traits', '28 yr time averaged fpg')])
# 17903298 rs1463697 set([('diabetes-related traits', 'hemoglobin a1c')])
# 17903298 rs1882347 set([('diabetes-related traits', 'fasting plasma glucose')])
# 17903298 rs7917983 set([('diabetes-related traits', 'hemoglobin a1c')])
# 17903298 rs10509967 set([('diabetes-related traits', 'hemoglobin a1c')])
# 17903298 rs2299641 set([('diabetes-related traits', 'Fasting insulin')])
# 17903298 rs1899951 set([('diabetes-related traits', 'hemoglobin a1c')])
# 17903298 rs10510410 set([('diabetes-related traits', 'Fasting insulin')])
# 17903298 rs916829 set([('diabetes-related traits', 'Fasting insulin')])
# 17903298 rs10510419 set([('diabetes-related traits', '28 yr time averaged fpg')])
# 17903298 rs10510411 set([('diabetes-related traits', 'Fasting insulin')])
# 17903298 rs10497392 set([('diabetes-related traits', 'hemoglobin a1c')])
# 17903298 rs10509969 set([('diabetes-related traits', 'fasting plasma glucose')])
# 17903298 rs10510412 set([('diabetes-related traits', 'Fasting insulin')])
# 17903298 rs4135268 set([('diabetes-related traits', '28 yr time averaged fpg')])
# 17903298 rs2190454 set([('diabetes-related traits', 'Fasting insulin')])
# 17903298 rs2722425 set([('diabetes-related traits', ''), ('diabetes-related traits', '28 yr time averaged fpg'), ('diabetes-related traits', 'fasting plasma glucose')])
# 17903298 rs10510060 set([('diabetes-related traits', 'hemoglobin a1c')])
# 17903298 rs3856808 set([('diabetes-related traits', '28 yr time averaged fpg')])
# 17903298 rs7100927 set([('diabetes-related traits', '28 yr time averaged fpg')])
# 17903298 rs4803953 set([('diabetes-related traits', 'Fasting insulin')])
# 17903298 rs10497721 set([('diabetes-related traits', ''), ('diabetes-related traits', 'Incident DM')])
# ---
# 17903300 rs10518418 set([('waist circumference|body mass index', 'Mean body mass index')])
# 17903300 rs9309153 set([('waist circumference|body mass index', 'Mean body mass index')])
# 17903300 rs1992901 set([('waist circumference|body mass index', 'Mean waist circumference')])
# ---
# 17903301 rs1949350 set([('exercise responses|artery', 'Stage 2 Exercise heart rate')])
# 17903301 rs10510001 set([('exercise responses|artery', 'left ventricular diastolic dimension'), ('exercise responses|artery', 'brachial artery hyperemic flow velocity'), ('exercise responses|artery', 'left ventricular mass'), ('exercise responses|artery', 'left ventricular systolic dimension'), ('exercise responses|artery', 'left ventricular fractional shortening')])
# 17903301 rs1202524 set([('exercise responses|artery', 'left ventricular diastolic dimension')])
# 17903301 rs729761 set([('exercise responses|artery', 'Left atrial diameter'), ('exercise responses|artery', 'left ventricular systolic dimension'), ('exercise responses|artery', 'Stage 2 Exercise heart rate'), ('exercise responses|artery', 'left ventricular fractional shortening')])
# 17903301 rs2900208 set([('exercise responses|artery', 'left ventricular diastolic dimension')])
# 17903301 rs26438 set([('exercise responses|artery', 'Aortic root diameter')])
# 17903301 rs4345919 set([('exercise responses|artery', 'Post-exercise 3 minute recovery heart rate')])
# 17903301 rs731824 set([('exercise responses|artery', 'Left atrial diameter')])
# 17903301 rs10498756 set([('exercise responses|artery', 'brachial artery hyperemic flow velocity')])
# 17903301 rs275678 set([('exercise responses|artery', 'Post-exercise 3 minute recovery systolic blood pressure')])
# 17903301 rs1989051 set([('exercise responses|artery', 'left ventricular mass')])
# 17903301 rs2912991 set([('exercise responses|artery', 'Across phenotypes')])
# 17903301 rs667269 set([('exercise responses|artery', 'Across left ventricular phenotypes')])
# 17903301 rs2419857 set([('exercise responses|artery', 'Stage 2 Exercise heart rate')])
# 17903301 rs525960 set([('exercise responses|artery', 'Across left ventricular phenotypes')])
# 17903301 rs10513333 set([('exercise responses|artery', 'Left atrial diameter')])
# 17903301 rs1425727 set([('exercise responses|artery', 'Baseline brachial artery flow velocity')])
# 17903301 rs2180478 set([('exercise responses|artery', 'left ventricular diastolic dimension')])
# 17903301 rs10515509 set([('exercise responses|artery', 'left ventricular mass')])
# 17903301 rs6585258 set([('exercise responses|artery', 'left ventricular mass')])
# 17903301 rs1395204 set([('exercise responses|artery', 'Aortic root diameter')])
# 17903301 rs1432214 set([('exercise responses|artery', 'Across phenotypes')])
# 17903301 rs1752189 set([('exercise responses|artery', 'Post-exercise 3 minute recovery systolic blood pressure')])
# 17903301 rs2478516 set([('exercise responses|artery', 'Stage 2 Exercise systolic blood pressure')])
# 17903301 rs833048 set([('exercise responses|artery', 'brachial artery hyperemic flow velocity')])
# 17903301 rs2478518 set([('exercise responses|artery', 'left ventricular systolic dimension'), ('exercise responses|artery', 'left ventricular fractional shortening')])
# 17903301 rs1954627 set([('exercise responses|artery', 'Across phenotypes')])
# 17903301 rs10488825 set([('exercise responses|artery', 'Aortic root diameter')])
# 17903301 rs1560916 set([('exercise responses|artery', 'Across phenotypes')])
# 17903301 rs2396083 set([('exercise responses|artery', 'left ventricular systolic dimension'), ('exercise responses|artery', 'Left atrial diameter'), ('exercise responses|artery', 'left ventricular fractional shortening')])
# 17903301 rs2438085 set([('exercise responses|artery', 'left ventricular wall thickness')])
# 17903301 rs1357424 set([('exercise responses|artery', 'left ventricular systolic dimension'), ('exercise responses|artery', 'left ventricular fractional shortening')])
# 17903301 rs180934 set([('exercise responses|artery', 'left ventricular wall thickness'), ('exercise responses|artery', 'brachial artery hyperemic flow velocity'), ('exercise responses|artery', 'left ventricular mass')])
# 17903301 rs1059502 set([('exercise responses|artery', 'left ventricular diastolic dimension'), ('exercise responses|artery', 'Aortic root diameter')])
# 17903301 rs180935 set([('exercise responses|artery', 'left ventricular wall thickness'), ('exercise responses|artery', 'brachial artery hyperemic flow velocity'), ('exercise responses|artery', 'left ventricular mass')])
# 17903301 rs473664 set([('exercise responses|artery', 'Across left ventricular phenotypes'), ('exercise responses|artery', 'left ventricular mass')])
# 17903301 rs1202585 set([('exercise responses|artery', 'left ventricular mass'), ('exercise responses|artery', 'brachial artery hyperemic flow velocity'), ('exercise responses|artery', 'left ventricular wall thickness'), ('exercise responses|artery', 'Baseline brachial artery diameter')])
# 17903301 rs10493052 set([('exercise responses|artery', 'Across phenotypes')])
# 17903301 rs10501940 set([('exercise responses|artery', 'left ventricular systolic dimension')])
# 17903301 rs427832 set([('exercise responses|artery', 'Post-exercise 3 minute recovery systolic blood pressure'), ('exercise responses|artery', 'Baseline brachial artery flow velocity')])
# 17903301 rs10491168 set([('exercise responses|artery', 'Stage 2 Exercise systolic blood pressure')])
# 17903301 rs10489725 set([('exercise responses|artery', 'left ventricular mass')])
# 17903301 rs3007456 set([('exercise responses|artery', 'Baseline brachial artery flow velocity')])
# 17903301 rs3766377 set([('exercise responses|artery', 'Across left ventricular phenotypes')])
# 17903301 rs10495298 set([('exercise responses|artery', 'Stage 2 Exercise systolic blood pressure')])
# 17903301 rs3813713 set([('exercise responses|artery', 'left ventricular wall thickness')])
# 17903301 rs2215564 set([('exercise responses|artery', 'brachial artery hyperemic flow velocity')])
# 17903301 rs10483844 set([('exercise responses|artery', 'Stage 2 Exercise heart rate')])
# 17903301 rs1959290 set([('exercise responses|artery', 'Across left ventricular phenotypes')])
# 17903301 rs190982 set([('exercise responses|artery', 'Stage 2 Exercise heart rate')])
# 17903301 rs721575 set([('exercise responses|artery', 'Post-exercise 3 minute recovery heart rate')])
# 17903301 rs758216 set([('exercise responses|artery', 'Post-exercise 3 minute recovery systolic blood pressure'), ('exercise responses|artery', 'Baseline brachial artery flow velocity'), ('exercise responses|artery', 'Aortic root diameter')])
# 17903301 rs10485104 set([('exercise responses|artery', 'Across left ventricular phenotypes')])
# 17903301 rs998334 set([('exercise responses|artery', 'left ventricular diastolic dimension'), ('exercise responses|artery', 'left ventricular systolic dimension')])
# 17903301 rs1492090 set([('exercise responses|artery', 'brachial artery hyperemic flow velocity')])
# 17903301 rs7286558 set([('exercise responses|artery', 'Stage 2 Exercise heart rate')])
# 17903301 rs10510677 set([('exercise responses|artery', 'Across phenotypes')])
# 17903301 rs7327514 set([('exercise responses|artery', 'Left atrial diameter')])
# 17903301 rs2331406 set([('exercise responses|artery', 'Aortic root diameter')])
# 17903301 rs10509999 set([('exercise responses|artery', 'left ventricular diastolic dimension'), ('exercise responses|artery', 'left ventricular systolic dimension'), ('exercise responses|artery', 'brachial artery hyperemic flow velocity')])
# 17903301 rs1006581 set([('exercise responses|artery', 'Baseline brachial artery diameter')])
# 17903301 rs10513442 set([('exercise responses|artery', 'Aortic root diameter')])
# 17903301 rs861857 set([('exercise responses|artery', 'Across left ventricular phenotypes'), ('exercise responses|artery', 'left ventricular mass')])
# 17903301 rs1959289 set([('exercise responses|artery', 'Across left ventricular phenotypes')])
# 17903301 rs10495300 set([('exercise responses|artery', 'Left atrial diameter')])
# 17903301 rs10518462 set([('exercise responses|artery', 'Across left ventricular phenotypes')])
# 17903301 rs6560812 set([('exercise responses|artery', 'Across phenotypes')])
# 17903301 rs2303928 set([('exercise responses|artery', 'Stage 2 Exercise heart rate')])
# 17903301 rs10512056 set([('exercise responses|artery', 'Across phenotypes')])
# 17903301 rs707025 set([('exercise responses|artery', 'Across left ventricular phenotypes'), ('exercise responses|artery', 'left ventricular systolic dimension')])
# 17903301 rs10514431 set([('exercise responses|artery', 'left ventricular diastolic dimension')])
# 17903301 rs7155941 set([('exercise responses|artery', 'Across phenotypes')])
# 17903301 rs180940 set([('exercise responses|artery', 'left ventricular mass'), ('exercise responses|artery', 'brachial artery hyperemic flow velocity'), ('exercise responses|artery', 'left ventricular wall thickness')])
# 17903301 rs10505599 set([('exercise responses|artery', 'left ventricular diastolic dimension')])
# 17903301 rs10511550 set([('exercise responses|artery', 'left ventricular wall thickness')])
# 17903301 rs741067 set([('exercise responses|artery', 'Baseline brachial artery diameter')])
# 17903301 rs1959291 set([('exercise responses|artery', 'Across left ventricular phenotypes')])
# 17903301 rs10513272 set([('exercise responses|artery', 'left ventricular diastolic dimension')])
# 17903301 rs10491574 set([('exercise responses|artery', 'Across left ventricular phenotypes')])
# 17903301 rs7902873 set([('exercise responses|artery', 'left ventricular diastolic dimension'), ('exercise responses|artery', 'left ventricular systolic dimension'), ('exercise responses|artery', 'left ventricular mass')])
# 17903301 rs10491167 set([('exercise responses|artery', 'Stage 2 Exercise systolic blood pressure')])
# 17903301 rs10519181 set([('exercise responses|artery', ''), ('exercise responses|artery', 'left ventricular wall thickness')])
# 17903301 rs10510000 set([('exercise responses|artery', 'left ventricular diastolic dimension'), ('exercise responses|artery', 'left ventricular systolic dimension'), ('exercise responses|artery', 'left ventricular mass'), ('exercise responses|artery', 'brachial artery hyperemic flow velocity'), ('exercise responses|artery', 'left ventricular fractional shortening')])
# 17903301 rs1719 set([('exercise responses|artery', 'left ventricular wall thickness')])
# ---
# 17903302 rs1721359 set([('arterial stiffness|blood pressure', 'blood-pressure'), ('arterial stiffness|blood pressure', '')])
# 17903302 rs3846317 set([('arterial stiffness|blood pressure', 'RW')])
# 17903302 rs2717594 set([('arterial stiffness|blood pressure', 'CF-PWV')])
# 17903302 rs427832 set([('arterial stiffness|blood pressure', 'FW')])
# 17903302 rs3910046 set([('arterial stiffness|blood pressure', 'CB-PWV'), ('arterial stiffness|blood pressure', 'CF-PWV')])
# 17903302 rs2478516 set([('arterial stiffness|blood pressure', 'FW'), ('arterial stiffness|blood pressure', 'RW')])
# 17903302 rs731824 set([('arterial stiffness|blood pressure', 'MAP')])
# 17903302 rs6492654 set([('arterial stiffness|blood pressure', ''), ('arterial stiffness|blood pressure', 'RW')])
# 17903302 rs16776 set([('arterial stiffness|blood pressure', 'FW')])
# 17903302 rs1059502 set([('arterial stiffness|blood pressure', 'MAP')])
# 17903302 rs3846318 set([('arterial stiffness|blood pressure', 'RW')])
# 17903302 rs3911890 set([('arterial stiffness|blood pressure', 'FW')])
# 17903302 rs2478518 set([('arterial stiffness|blood pressure', 'FW')])
# 17903302 rs4835136 set([('arterial stiffness|blood pressure', 'CB-PWV')])
# 17903302 rs10519958 set([('arterial stiffness|blood pressure', 'RW')])
# 17903302 rs10519959 set([('arterial stiffness|blood pressure', 'CB-PWV')])
# 17903302 rs9307847 set([('arterial stiffness|blood pressure', 'CB-PWV')])
# ---
# 17903303 rs1180937 set([('atherosclerosis', 'Internal carotid artery intimal medial thickness')])
# 17903303 rs10832008 set([('atherosclerosis', 'Internal carotid artery intimal medial thickness')])
# 17903303 rs714647 set([('atherosclerosis', 'Internal carotid artery intimal medial thickness')])
# 17903303 rs2813563 set([('atherosclerosis', 'Abdominal aortic calcification')])
# 17903303 rs3762823 set([('atherosclerosis', 'Common carotid artery intimal medial thickness')])
# 17903303 rs17030524 set([('atherosclerosis', 'Abdominal aortic calcification')])
# 17903303 rs1948685 set([('atherosclerosis', 'Internal carotid artery intimal medial thickness')])
# 17903303 rs394884 set([('atherosclerosis', 'Ankle brachial index')])
# 17903303 rs1106679 set([('atherosclerosis', 'Coronary artery calcification')])
# 17903303 rs3853250 set([('atherosclerosis', 'Ankle brachial index')])
# 17903303 rs959987 set([('atherosclerosis', 'Internal carotid artery intimal medial thickness')])
# 17903303 rs3853251 set([('atherosclerosis', 'Ankle brachial index')])
# 17903303 rs10505346 set([('atherosclerosis', 'Ankle brachial index')])
# 17903303 rs10240716 set([('atherosclerosis', 'Ankle brachial index')])
# 17903303 rs300574 set([('atherosclerosis', 'Internal carotid artery intimal medial thickness')])
# 17903303 rs725467 set([('atherosclerosis', 'Abdominal aortic calcification')])
# 17903303 rs7000744 set([('atherosclerosis', 'Coronary artery calcification')])
# 17903303 rs4444073 set([('atherosclerosis', 'Ankle brachial index')])
# 17903303 rs1467558 set([('atherosclerosis', 'Coronary artery calcification')])
# 17903303 rs6832344 set([('atherosclerosis', ''), ('atherosclerosis', 'Ankle brachial index')])
# 17903303 rs1454183 set([('atherosclerosis', 'Abdominal aortic calcification')])
# 17903303 rs10483084 set([('atherosclerosis', 'Ankle brachial index')])
# ---
# 17903304 rs10519186 set([('cardiovascular disease', 'Major coronary heart disease')])
# 17903304 rs3951042 set([('cardiovascular disease', 'Major coronary heart disease')])
# 17903304 rs2317948 set([('cardiovascular disease', 'Major cardiovascular disease'), ('cardiovascular disease', 'Major coronary heart disease')])
# 17903304 rs7983138 set([('cardiovascular disease', 'Major coronary heart disease')])
# 17903304 rs2985183 set([('cardiovascular disease', 'Major coronary heart disease')])
# 17903304 rs724868 set([('cardiovascular disease', 'Major coronary heart disease')])
# 17903304 rs566125 set([('cardiovascular disease', 'Major cardiovascular disease')])
# 17903304 rs2863274 set([('cardiovascular disease', 'Major cardiovascular disease'), ('cardiovascular disease', 'Major coronary heart disease')])
# 17903304 rs1133415 set([('cardiovascular disease', 'Major coronary heart disease')])
# 17903304 rs4603405 set([('cardiovascular disease', 'Major coronary heart disease')])
# 17903304 rs10512574 set([('cardiovascular disease', 'Major coronary heart disease')])
# 17903304 rs185021 set([('cardiovascular disease', 'Major coronary heart disease')])
# 17903304 rs832177 set([('cardiovascular disease', 'Major coronary heart disease')])
# 17903304 rs10484286 set([('cardiovascular disease', 'Major coronary heart disease')])
# 17903304 rs768586 set([('cardiovascular disease', 'Major coronary heart disease')])
# 17903304 rs6686484 set([('cardiovascular disease', 'Major coronary heart disease')])
# 17903304 rs10507391 set([('cardiovascular disease', 'Major cardiovascular disease'), ('cardiovascular disease', 'Major coronary heart disease')])
# 17903304 rs752876 set([('cardiovascular disease', 'Major coronary heart disease')])
# 17903304 rs7984952 set([('cardiovascular disease', 'Major coronary heart disease')])
# 17903304 rs7995384 set([('cardiovascular disease', 'Major coronary heart disease')])
# 17903304 rs10497521 set([('cardiovascular disease', 'Major coronary heart disease')])
# 17903304 rs2093185 set([('cardiovascular disease', 'Major cardiovascular disease')])
# 17903304 rs10489656 set([('cardiovascular disease', 'Major cardiovascular disease'), ('cardiovascular disease', 'Major coronary heart disease')])
# 17903304 rs9320660 set([('cardiovascular disease', 'Major coronary heart disease')])
# 17903304 rs7277304 set([('cardiovascular disease', 'Major coronary heart disease')])
# 17903304 rs2033546 set([('cardiovascular disease', 'Major cardiovascular disease'), ('cardiovascular disease', 'Major coronary heart disease')])
# 17903304 rs9305551 set([('cardiovascular disease', 'Major coronary heart disease')])
# 17903304 rs40949 set([('cardiovascular disease', 'Major coronary heart disease')])
# 17903304 rs902027 set([('cardiovascular disease', 'Major coronary heart disease')])
# 17903304 rs2096767 set([('cardiovascular disease', 'Major cardiovascular disease'), ('cardiovascular disease', 'Major coronary heart disease')])
# 17903304 rs911839 set([('cardiovascular disease', 'Major cardiovascular disease'), ('cardiovascular disease', 'Major coronary heart disease')])
# 17903304 rs10493062 set([('cardiovascular disease', 'Major coronary heart disease')])
# 17903304 rs10488674 set([('cardiovascular disease', 'Major coronary heart disease')])
# 17903304 rs618675 set([('cardiovascular disease', 'Major cardiovascular disease'), ('cardiovascular disease', 'Major coronary heart disease')])
# 17903304 rs10489658 set([('cardiovascular disease', 'Major cardiovascular disease'), ('cardiovascular disease', 'Major coronary heart disease')])
# 17903304 rs117395 set([('cardiovascular disease', 'Major coronary heart disease')])
# 17903304 rs2114580 set([('cardiovascular disease', 'Major cardiovascular disease'), ('cardiovascular disease', 'Major coronary heart disease')])
# 17903304 rs10492225 set([('cardiovascular disease', 'Major coronary heart disease')])
# 17903304 rs758216 set([('cardiovascular disease', 'Major coronary heart disease')])
# 17903304 rs2317951 set([('cardiovascular disease', 'Major cardiovascular disease'), ('cardiovascular disease', 'Major coronary heart disease')])
# 17903304 rs10484326 set([('cardiovascular disease', 'Major coronary heart disease')])
# 17903304 rs264986 set([('cardiovascular disease', 'Major coronary heart disease')])
# ---
# 17903305 rs7329659 set([('prostate cancer|breast', '')])
# 17903305 rs7564590 set([('prostate cancer|breast', 'Breast cancer')])
# 17903305 rs2410373 set([('prostate cancer|breast', 'Prostate cancer')])
# 17903305 rs7610584 set([('prostate cancer|breast', '')])
# 17903305 rs208354 set([('prostate cancer|breast', '')])
# 17903305 rs7558615 set([('prostate cancer|breast', 'Breast cancer')])
# ---
# 17903306 rs10503790 set([('heart rate|variability traits', 'SDNN')])
# 17903306 rs10503797 set([('heart rate|variability traits', 'RR')])
# 17903306 rs7000280 set([('heart rate|variability traits', 'SDNN')])
# 17903306 rs10503794 set([('heart rate|variability traits', 'SDNN')])
# 17903306 rs10503788 set([('heart rate|variability traits', 'SDNN')])
# 17903306 rs10503789 set([('heart rate|variability traits', 'SDNN')])
# 17903306 rs164462 set([('heart rate|variability traits', 'QT')])
# 17903306 rs1011725 set([('heart rate|variability traits', 'PR')])
# 17903306 rs520180 set([('heart rate|variability traits', 'PR')])
# 17903306 rs10500600 set([('heart rate|variability traits', 'TP')])
# 17903306 rs10512617 set([('heart rate|variability traits', 'QT')])
# 17903306 rs9325124 set([('heart rate|variability traits', 'TP')])
# 17903306 rs10494365 set([('heart rate|variability traits', 'QT')])
# 17903306 rs10519165 set([('heart rate|variability traits', 'LF/HF')])
# 17903306 rs10515621 set([('heart rate|variability traits', 'RR')])
# 17903306 rs2195926 set([('heart rate|variability traits', 'SDNN'), ('heart rate|variability traits', 'TP')])
# 17903306 rs347311 set([('heart rate|variability traits', 'QT')])
# 17903306 rs10503791 set([('heart rate|variability traits', 'SDNN')])
# ---
# 17903307 rs688878 set([('pulmonary function', 'percent predicted fef percent predicted fvc for latest exam')])
# 17903307 rs842873 set([('pulmonary function', 'percent predicted fef percent predicted fef')])
# 17903307 rs3745295 set([('pulmonary function', 'longitudinal slope of fev for latest exam')])
# 17903307 rs542338 set([('pulmonary function', 'mean fev longitudinal slope of fev')])
# 17903307 rs753765 set([('pulmonary function', 'for latest exam')])
# 17903307 rs3738051 set([('pulmonary function', 'longitudinal slope of fef percent predicted fef')])
# 17903307 rs564425 set([('pulmonary function', ''), ('pulmonary function', 'percent predicted fef')])
# 17903307 rs726289 set([('pulmonary function', 'longitudinal slope of fef')])
# 17903307 rs10497042 set([('pulmonary function', 'percent predicted fev')])
# 17903307 rs10489542 set([('pulmonary function', 'percent predicted fvc for latest exam')])
# 17903307 rs9325117 set([('pulmonary function', 'longitudinal slope of fef mean fev')])
# 17903307 rs10487367 set([('pulmonary function', 'mean fvc from two exams percent predicted fev')])
# 17903307 rs10489030 set([('pulmonary function', 'for latest exam percent predicted fvc for latest exam')])
# 17903307 rs140289 set([('pulmonary function', 'percent predicted fvc for latest exam for latest exam')])
# 17903307 rs2903908 set([('pulmonary function', 'percent predicted fef')])
# 17903307 rs10518032 set([('pulmonary function', 'for latest exam')])
# 17903307 rs10518669 set([('pulmonary function', 'mean fev')])
# 17903307 rs2300081 set([('pulmonary function', 'mean fev')])
# 17903307 rs5909594 set([('pulmonary function', 'longitudinal slope of fef')])
# 17903307 rs2889529 set([('pulmonary function', 'for latest exam mean fev')])
# 17903307 rs10494879 set([('pulmonary function', 'longitudinal slope of fef longitudinal slope of fev')])
# 17903307 rs495366 set([('pulmonary function', 'longitudinal slope of fef for latest exam')])
# 17903307 rs10517825 set([('pulmonary function', 'percent predicted fvc for latest exam')])
# 17903307 rs717610 set([('pulmonary function', 'mean fvc from two exams mean fev')])
# 17903307 rs10484047 set([('pulmonary function', 'percent predicted fvc for latest exam longitudinal slope of fev')])
# 17903307 rs10483190 set([('pulmonary function', 'longitudinal slope of fev mean fev')])
# 17903307 rs2974490 set([('pulmonary function', 'for latest exam')])
# 17903307 rs10484042 set([('pulmonary function', 'percent predicted fvc for latest exam longitudinal slope of fev')])
# 17903307 rs7577293 set([('pulmonary function', 'mean fev')])
# 17903307 rs4918762 set([('pulmonary function', 'mean fev')])
# 17903307 rs721411 set([('pulmonary function', 'for latest exam')])
# 17903307 rs10488908 set([('pulmonary function', 'mean fvc from two exams')])
# ---
# 17903308 rs2256551 set([('circadian phenotypes|sleep', 'Sleep duration')])
# 17903308 rs2525724 set([('circadian phenotypes|sleep', 'Bedtime')])
# 17903308 rs2189829 set([('circadian phenotypes|sleep', 'Sleepiness')])
# 17903308 rs10520010 set([('circadian phenotypes|sleep', 'Sleepiness')])
# 17903308 rs2359894 set([('circadian phenotypes|sleep', 'Sleep duration')])
# 17903308 rs9298693 set([('circadian phenotypes|sleep', 'Sleepiness')])
# 17903308 rs10503857 set([('circadian phenotypes|sleep', 'Bedtime')])
# 17903308 rs324981 set([('circadian phenotypes|sleep', 'Bedtime')])
# 17903308 rs10498313 set([('circadian phenotypes|sleep', 'Bedtime')])
# 17903308 rs10483871 set([('circadian phenotypes|sleep', 'Bedtime')])
# 17903308 rs2061579 set([('circadian phenotypes|sleep', 'Sleep duration')])
# 17903308 rs481233 set([('circadian phenotypes|sleep', 'Sleep duration')])
# 17903308 rs2985334 set([('circadian phenotypes|sleep', 'Bedtime')])
# 17903308 rs10507551 set([('circadian phenotypes|sleep', 'Bedtime')])
# 17903308 rs10489832 set([('circadian phenotypes|sleep', 'Sleep duration')])
# 17903308 rs2165207 set([('circadian phenotypes|sleep', 'Sleep duration')])
# 17903308 rs28168 set([('circadian phenotypes|sleep', 'Bedtime')])
# 17903308 rs7073579 set([('circadian phenotypes|sleep', 'Sleepiness')])
# 17903308 rs10510835 set([('circadian phenotypes|sleep', 'Sleepiness')])
# 17903308 rs6974138 set([('circadian phenotypes|sleep', 'Sleep duration')])
# 17903308 rs10492507 set([('circadian phenotypes|sleep', 'Sleep duration')])
# 17903308 rs2247614 set([('circadian phenotypes|sleep', 'Sleepiness')])
# 17903308 rs2288292 set([('circadian phenotypes|sleep', 'Bedtime')])
# 17903308 rs932650 set([('circadian phenotypes|sleep', 'Bedtime')])
# 17903308 rs434052 set([('circadian phenotypes|sleep', 'Sleepiness')])
# 17903308 rs4896580 set([('circadian phenotypes|sleep', 'Sleepiness')])
# 17903308 rs10512058 set([('circadian phenotypes|sleep', 'Bedtime')])
# 17903308 rs1725021 set([('circadian phenotypes|sleep', 'Bedtime')])
# ---
# ---
# ---
# ---
# ---
# 18369459 rs3812888 set([('Psoriasis|Psoriatic Arthritis', '')])
# ---
# ---
# ---
# 18483556 rs7495174 set([('Hair Color|Skin Pigmentation', '')])
# 18483556 rs4904866 set([('Hair Color|Skin Pigmentation', '')])
# 18483556 rs8039195 set([('Hair Color|Skin Pigmentation', '')])
# 18483556 rs8049897 set([('Hair Color|Skin Pigmentation', '')])
# 18483556 rs2241039 set([('Hair Color|Skin Pigmentation', '')])
# 18483556 rs9806558 set([('Hair Color|Skin Pigmentation', '')])
# 18483556 rs7204478 set([('Hair Color|Skin Pigmentation', '')])
# 18483556 rs1540771 set([('Hair Color|Skin Pigmentation', '')])
# 18483556 rs4408545 set([('Hair Color|Skin Pigmentation', '')])
# 18483556 rs4785763 set([('Hair Color|Skin Pigmentation', '')])
# 18483556 rs2493040 set([('Hair Color|Skin Pigmentation', '')])
# 18483556 rs8007923 set([('Hair Color|Skin Pigmentation', '')])
# 18483556 rs8028689 set([('Hair Color|Skin Pigmentation', '')])
# 18483556 rs6497268 set([('Hair Color|Skin Pigmentation', '')])
# 18483556 rs7183877 set([('Hair Color|Skin Pigmentation', '')])
# 18483556 rs4238833 set([('Hair Color|Skin Pigmentation', '')])
# 18483556 rs7195066 set([('Hair Color|Skin Pigmentation', '')])
# 18483556 rs35391 set([('Hair Color|Skin Pigmentation', '')])
# 18483556 rs16950987 set([('Hair Color|Skin Pigmentation', '')])
# 18483556 rs9392056 set([('Hair Color|Skin Pigmentation', '')])
# 18483556 rs916977 set([('Hair Color|Skin Pigmentation', '')])
# 18483556 rs11636232 set([('Hair Color|Skin Pigmentation', '')])
# 18483556 rs7196459 set([('Hair Color|Skin Pigmentation', '')])
# 18483556 rs7188458 set([('Hair Color|Skin Pigmentation', '')])
# 18483556 rs12142165 set([('Hair Color|Skin Pigmentation', '')])
# 18483556 rs11855019 set([('Hair Color|Skin Pigmentation', '')])
# 18483556 rs164741 set([('Hair Color|Skin Pigmentation', '')])
# 18483556 rs7174027 set([('Hair Color|Skin Pigmentation', '')])
# ...
# ---
# 24324648 rs3106598 set([('Serum IgE', '')])
# 24324648 rs7939777 set([('Serum IgE', '')])
# 24324648 rs9264567 set([('Serum IgE', '')])
# 24324648 rs9271682 set([('Serum IgE', '')])
# 24324648 rs1399315 set([('Serum IgE', '')])
# 24324648 rs943474 set([('Serum IgE', '')])
# 24324648 rs3130941 set([('Serum IgE', '')])
# 24324648 rs2078158 set([('Serum IgE', '')])
# 24324648 rs12173787 set([('Serum IgE', '')])
# ---
# 24347629 rs8094794 set([('Periodontal', '')])
# 24347629 rs10457526 set([('Periodontal', '')])
# 24347629 rs12630931 set([('Periodontal', 'PD2'), ('Periodontal', '')])
# 24347629 rs3870371 set([('Periodontal', '')])
# 24347629 rs10457525 set([('Periodontal', '')])
# 24347629 rs3783412 set([('Periodontal', '')])
# 24347629 rs7749983 set([('Periodontal', '')])
# 24347629 rs11659841 set([('Periodontal', '')])
# 24347629 rs7816221 set([('Periodontal', '')])
# 24347629 rs920455 set([('Periodontal', '')])
# 24347629 rs11713199 set([('Periodontal', 'PD2'), ('Periodontal', '')])
# 24347629 rs733048 set([('Periodontal', 'PD1'), ('Periodontal', '')])
# 24347629 rs12589327 set([('Periodontal', '')])
# 24347629 rs2297778 set([('Periodontal', '')])
# 24347629 rs12799172 set([('Periodontal', '')])
# 24347629 rs12630254 set([('Periodontal', 'PD2'), ('Periodontal', '')])
# ---
# 24348519 rs17817449 set([('body mass index', '')])
# 24348519 rs1421085 set([('body mass index', '')])
# 24348519 rs8192472 set([('body mass index', '')])
# 24348519 rs8050136 set([('body mass index', '')])
# 24348519 rs9939609 set([('body mass index', '')])
# 24348519 rs12964056 set([('body mass index', '')])
# ---
# 24376456 rs10770612 set([('blood pressure', ''), ('blood pressure', 'Aortic root size')])
# 24376456 rs2275588 set([('blood pressure', ''), ('blood pressure', 'Blood pressure')])
# 24376456 rs10518590 set([('blood pressure', ''), ('blood pressure', 'Blood pressure')])
# 24376456 rs10826334 set([('blood pressure', ''), ('blood pressure', 'Blood pressure'), ('blood pressure', 'MAP')])
# 24376456 rs9874923 set([('blood pressure', ''), ('blood pressure', 'MAP')])
# 24376456 rs7902871 set([('blood pressure', 'Total cysteine'), ('blood pressure', ''), ('blood pressure', 'DBP')])
# 24376456 rs10509096 set([('blood pressure', ''), ('blood pressure', 'Blood pressure')])
# 24376456 rs16849553 set([('blood pressure', ''), ('blood pressure', 'MAP')])
# 24376456 rs10777317 set([('blood pressure', 'Sudden cardiac arrest'), ('blood pressure', '')])
# 24376456 rs1348582 set([('blood pressure', ''), ('blood pressure', 'QT interval')])
# 24376456 rs2410182 set([('blood pressure', ''), ('blood pressure', 'Coronary heart disease'), ('blood pressure', 'SBP')])
# 24376456 rs4494364 set([('blood pressure', 'Sudden cardiac arrest'), ('blood pressure', ''), ('blood pressure', 'SBP')])
# 24376456 rs10841397 set([('blood pressure', ''), ('blood pressure', 'Baseline blood pressure')])
# 24376456 rs7116456 set([('blood pressure', ''), ('blood pressure', 'SBP')])
# 24376456 rs648425 set([('blood pressure', ''), ('blood pressure', 'Blood pressure'), ('blood pressure', 'SBP')])
# 24376456 rs4537030 set([('blood pressure', ''), ('blood pressure', 'MAP')])
# 24376456 rs4892138 set([('blood pressure', 'Hypertension'), ('blood pressure', '')])
# 24376456 rs12767760 set([('blood pressure', 'Total cysteine'), ('blood pressure', '')])
# 24376456 rs13008299 set([('blood pressure', ''), ('blood pressure', 'DBP')])
# 24376456 rs6479671 set([('blood pressure', 'Alcohol drinking')])
# 24376456 rs16963349 set([('blood pressure', ''), ('blood pressure', 'Blood pressure'), ('blood pressure', 'SBP')])
# 24376456 rs4888671 set([('blood pressure', ''), ('blood pressure', 'Folate')])
# 24376456 rs10500968 set([('blood pressure', ''), ('blood pressure', 'Echocardiography')])
# 24376456 rs991427 set([('blood pressure', 'Sudden cardiac arrest'), ('blood pressure', ''), ('blood pressure', 'SBP')])
# 24376456 rs2059238 set([('blood pressure', 'Cardiac structure and function'), ('blood pressure', '')])
# 24376456 rs11766519 set([('blood pressure', ''), ('blood pressure', 'PP')])
# 24376456 rs12757165 set([('blood pressure', 'Cardiac hypertrophy'), ('blood pressure', '')])
# 24376456 rs12356193 set([('blood pressure', ''), ('blood pressure', 'Uric acid levels')])
# 24376456 rs10841530 set([('blood pressure', ''), ('blood pressure', 'SBP'), ('blood pressure', 'Baseline blood pressure')])
# 24376456 rs1171614 set([('blood pressure', ''), ('blood pressure', 'Urate levels')])
# 24376456 rs1735151 set([('blood pressure', ''), ('blood pressure', 'Coronary heart disease')])
# 24376456 rs12773465 set([('blood pressure', ''), ('blood pressure', 'Cystathionine'), ('blood pressure', 'MAP')])
# 24376456 rs7791745 set([('blood pressure', ''), ('blood pressure', 'MAP')])
# 24376456 rs12292796 set([('blood pressure', ''), ('blood pressure', 'PP')])
# 24376456 rs2346177 set([('blood pressure', ''), ('blood pressure', 'Coronary heart disease')])
# 24376456 rs3824789 set([('blood pressure', ''), ('blood pressure', 'Cystathionine')])
# 24376456 rs2837253 set([('blood pressure', ''), ('blood pressure', 'SBP')])
# 24376456 rs2735413 set([('blood pressure', ''), ('blood pressure', 'Folate'), ('blood pressure', 'SBP')])
# 24376456 rs2937785 set([('blood pressure', 'Hypertension'), ('blood pressure', '')])
# 24376456 rs669733 set([('blood pressure', 'Blood pressure')])
# 24376456 rs7094971 set([('blood pressure', ''), ('blood pressure', 'Carnitine')])
# 24376456 rs2278075 set([('blood pressure', 'Cardiovascular disease'), ('blood pressure', '')])
# 24376456 rs1943940 set([('blood pressure', 'Hypertension'), ('blood pressure', ''), ('blood pressure', 'DBP')])
# 24376456 rs7728043 set([('blood pressure', ''), ('blood pressure', 'QT interval')])
# 24376456 rs3096277 set([('blood pressure', ''), ('blood pressure', 'Blood pressure')])
# 24376456 rs1523351 set([('blood pressure', 'Coronary artery disease'), ('blood pressure', '')])
# 24376456 rs9318552 set([('blood pressure', ''), ('blood pressure', 'DBP')])
# 24376456 rs4953404 set([('blood pressure', ''), ('blood pressure', 'Coronary heart disease'), ('blood pressure', 'PP')])
# 24376456 rs17669622 set([('blood pressure', 'Cardiac hypertrophy'), ('blood pressure', ''), ('blood pressure', 'MAP')])
# 24376456 rs3852160 set([('blood pressure', 'QT interval'), ('blood pressure', ''), ('blood pressure', 'MAP')])
# 24376456 rs10486744 set([('blood pressure', 'Blood pressure')])
# ---
# 24376798 rs9275572 set([('Chronic Hepatitis C', '')])
# 24376798 rs1130380 set([('Chronic Hepatitis C', '')])
# ---
# 24379826 rs6786174 set([('serum uric acid levels', '')])
# 24379826 rs13131257 set([('serum uric acid levels', '')])
# 24379826 rs6786387 set([('serum uric acid levels', '')])
# 24379826 rs6832439 set([('serum uric acid levels', ''), ('serum uric acid levels', 'Total antioxidant status')])
# 24379826 rs737267 set([('serum uric acid levels', ''), ('serum uric acid levels', 'Total antioxidant status')])
# 24379826 rs17586876 set([('serum uric acid levels', '')])
# 24379826 rs6449213 set([('serum uric acid levels', '')])
# 24379826 rs938553 set([('serum uric acid levels', ''), ('serum uric acid levels', 'Body weight')])
# 24379826 rs7652782 set([('serum uric acid levels', '')])
# ---
# 24386095 rs646776 set([('Lipid Levels', ''), ('Lipid Levels', 'LDL')])
# 24386095 rs12740374 set([('Lipid Levels', ''), ('Lipid Levels', 'LDL')])
# 24386095 rs651821 set([('Lipid Levels', ''), ('Lipid Levels', 'TG')])
# 24386095 rs10045497 set([('Lipid Levels', 'TC'), ('Lipid Levels', ''), ('Lipid Levels', 'LDL')])
# 24386095 rs599839 set([('Lipid Levels', ''), ('Lipid Levels', 'LDL')])
# 24386095 rs6754295 set([('Lipid Levels', ''), ('Lipid Levels', 'HDL')])
# 24386095 rs1160985 set([('Lipid Levels', ''), ('Lipid Levels', 'LDL')])
# 24386095 rs693 set([('Lipid Levels', ''), ('Lipid Levels', 'HDL')])
# 24386095 rs2043085 set([('Lipid Levels', ''), ('Lipid Levels', 'HDL')])
# 24386095 rs11207995 set([('Lipid Levels', 'TC'), ('Lipid Levels', '')])
# 24386095 rs328 set([('Lipid Levels', ''), ('Lipid Levels', 'HDL'), ('Lipid Levels', 'TG')])
# 24386095 rs673548 set([('Lipid Levels', ''), ('Lipid Levels', 'HDL')])
# 24386095 rs507666 set([('Lipid Levels', 'TC'), ('Lipid Levels', ''), ('Lipid Levels', 'LDL')])
# 24386095 rs3764261 set([('Lipid Levels', ''), ('Lipid Levels', 'HDL')])
# ---
# 24390342 rs72634030 set([('rheumatoid arthritis|biology', '')])
# 24390342 rs13142500 set([('rheumatoid arthritis|biology', '')])
# 24390342 rs2469434 set([('rheumatoid arthritis|biology', '')])
# 24390342 rs10175798 set([('rheumatoid arthritis|biology', '')])
# 24390342 rs10774624 set([('rheumatoid arthritis|biology', '')])
# 24390342 rs773125 set([('rheumatoid arthritis|biology', '')])
# 24390342 rs73194058 set([('rheumatoid arthritis|biology', '')])
# 24390342 rs909685 set([('rheumatoid arthritis|biology', '')])
# 24390342 rs6732565 set([('rheumatoid arthritis|biology', '')])
# 24390342 rs4409785 set([('rheumatoid arthritis|biology', '')])
# 24390342 rs9826828 set([('rheumatoid arthritis|biology', '')])
# 24390342 rs73013527 set([('rheumatoid arthritis|biology', '')])
# 24390342 rs11089637 set([('rheumatoid arthritis|biology', '')])
# 24390342 rs678347 set([('rheumatoid arthritis|biology', '')])
# 24390342 rs4452313 set([('rheumatoid arthritis|biology', '')])
# 24390342 rs1893592 set([('rheumatoid arthritis|biology', '')])
# 24390342 rs3783782 set([('rheumatoid arthritis|biology', '')])
# 24390342 rs28411352 set([('rheumatoid arthritis|biology', '')])
# 24390342 rs726288 set([('rheumatoid arthritis|biology', '')])
# 24390342 rs968567 set([('rheumatoid arthritis|biology', '')])
# 24390342 rs2105325 set([('rheumatoid arthritis|biology', '')])
# 24390342 rs9603616 set([('rheumatoid arthritis|biology', '')])
# 24390342 rs998731 set([('rheumatoid arthritis|biology', '')])
# 24390342 rs2664035 set([('rheumatoid arthritis|biology', '')])
# 24390342 rs1516971 set([('rheumatoid arthritis|biology', '')])
# 24390342 rs1950897 set([('rheumatoid arthritis|biology', '')])
# 24390342 rs4272 set([('rheumatoid arthritis|biology', '')])
# 24390342 rs12413578 set([('rheumatoid arthritis|biology', '')])
# 24390342 rs1877030 set([('rheumatoid arthritis|biology', '')])
# 24390342 rs2234067 set([('rheumatoid arthritis|biology', '')])
# 24390342 rs3806624 set([('rheumatoid arthritis|biology', '')])
# 24390342 rs6715284 set([('rheumatoid arthritis|biology', '')])
# 24390342 rs9373594 set([('rheumatoid arthritis|biology', '')])
# 24390342 rs2671692 set([('rheumatoid arthritis|biology', '')])
# 24390342 rs4780401 set([('rheumatoid arthritis|biology', '')])
# 24390342 rs227163 set([('rheumatoid arthritis|biology', '')])
# 24390342 rs67250450 set([('rheumatoid arthritis|biology', '')])
# 24390342 rs9378815 set([('rheumatoid arthritis|biology', '')])
# 24390342 rs793108 set([('rheumatoid arthritis|biology', '')])
# ---
# ---
# 24403052 rs214803 set([('basal cell carcinoma', '')])
# 24403052 rs59586681 set([('basal cell carcinoma', '')])
# 24403052 rs214782 set([('basal cell carcinoma', '')])
# 24403052 rs7006527 set([('basal cell carcinoma', '')])
# ---
# 24449572 rs6448432 set([('Rheumatoid Arthritis', '')])
# 24449572 rs6679677 set([('Rheumatoid Arthritis', '')])
# 24449572 rs11181399 set([('Rheumatoid Arthritis', '')])
# 24449572 rs1047022 set([('Rheumatoid Arthritis', '')])
# 24449572 rs7954523 set([('Rheumatoid Arthritis', '')])
# 24449572 rs3763309 set([('Rheumatoid Arthritis', '')])
# 24449572 rs6859219 set([('Rheumatoid Arthritis', '')])
# 24449572 rs6564350 set([('Rheumatoid Arthritis', '')])
# 24449572 rs6457617 set([('Rheumatoid Arthritis', '')])
# 24449572 rs7187962 set([('Rheumatoid Arthritis', '')])
# ---
# 24465431 rs16862964 set([('Diabetes,|Cardiovascular Disease', '')])
# 24465431 rs6595551 set([('Diabetes,|Cardiovascular Disease', '')])
# ---
# 24465473 rs17653722 set([('Telomere Length', '')])
# ---
# 24478790 rs10466239 set([('telomere length', '')])
# ---
# 24483146 rs2928445 set([('biomarkers', '')])
# 24483146 rs28668016 set([('biomarkers', '')])
# 24483146 rs316871 set([('biomarkers', '')])
# 24483146 rs427498 set([('biomarkers', '')])
# 24483146 rs9846155 set([('biomarkers', '')])
# 24483146 rs4392391 set([('biomarkers', '')])
# 24483146 rs12486452 set([('biomarkers', '')])
# 24483146 rs6441911 set([('biomarkers', '')])
# 24483146 rs11215416 set([('biomarkers', '')])
# 24483146 rs9816196 set([('biomarkers', '')])
# 24483146 rs9512755 set([('biomarkers', '')])
# 24483146 rs2857891 set([('biomarkers', '')])
# 24483146 rs10513968 set([('biomarkers', '')])
# 24483146 rs316823 set([('biomarkers', '')])
# 24483146 rs2290344 set([('biomarkers', '')])
# 24483146 rs7183960 set([('biomarkers', '')])
# 24483146 rs967285 set([('biomarkers', '')])
# 24483146 rs11636687 set([('biomarkers', '')])
# 24483146 rs8024695 set([('biomarkers', '')])
# 24483146 rs9878275 set([('biomarkers', '')])
# 24483146 rs1450679 set([('biomarkers', '')])
# 24483146 rs9850725 set([('biomarkers', '')])
# 24483146 rs12631341 set([('biomarkers', '')])
# 24483146 rs1565214 set([('biomarkers', '')])
# 24483146 rs12050587 set([('biomarkers', '')])
# 24483146 rs1565215 set([('biomarkers', '')])
# 24483146 rs7631790 set([('biomarkers', '')])
# 24483146 rs7719624 set([('biomarkers', '')])
# 24483146 rs3135351 set([('biomarkers', '')])
# 24483146 rs2414409 set([('biomarkers', '')])
# 24483146 rs10510741 set([('biomarkers', '')])
# 24483146 rs2274870 set([('biomarkers', '')])
# 24483146 rs12188464 set([('biomarkers', '')])
# 24483146 rs6808448 set([('biomarkers', '')])
# 24483146 rs4682949 set([('biomarkers', '')])
# 24483146 rs2172820 set([('biomarkers', '')])
# 24483146 rs9846284 set([('biomarkers', '')])
# 24483146 rs7174876 set([('biomarkers', '')])
# 24483146 rs10495285 set([('biomarkers', '')])
# 24483146 rs402098 set([('biomarkers', '')])
# 24483146 rs9821268 set([('biomarkers', '')])
# 24483146 rs17564430 set([('biomarkers', '')])
# 24483146 rs13171512 set([('biomarkers', '')])
# 24483146 rs9809107 set([('biomarkers', '')])
# 24483146 rs9861198 set([('biomarkers', '')])
# 24483146 rs888468 set([('biomarkers', '')])
# 24483146 rs9852733 set([('biomarkers', '')])
# 24483146 rs4774760 set([('biomarkers', '')])
# 24483146 rs7713001 set([('biomarkers', '')])
# 24483146 rs2653165 set([('biomarkers', '')])
# 24483146 rs11215406 set([('biomarkers', '')])
# 24483146 rs6128386 set([('biomarkers', '')])
# ---
# 24489884 rs4628571 set([('aggression', '')])
# 24489884 rs2045797 set([('aggression', '')])
# 24489884 rs7578047 set([('aggression', '')])
# 24489884 rs6834498 set([('aggression', '')])
# 24489884 rs670292 set([('aggression', '')])
# 24489884 rs1299926 set([('aggression', '')])
# 24489884 rs3752433 set([('aggression', '')])
# 24489884 rs6954895 set([('aggression', '')])
# 24489884 rs8102754 set([('aggression', '')])
# 24489884 rs6012564 set([('aggression', '')])
# 24489884 rs238215 set([('aggression', '')])
# 24489884 rs2844775 set([('aggression', '')])
# 24489884 rs16840114 set([('aggression', '')])
# 24489884 rs16924133 set([('aggression', '')])
# 24489884 rs17535407 set([('aggression', '')])
# 24489884 rs555017 set([('aggression', '')])
# 24489884 rs12249434 set([('aggression', '')])
# 24489884 rs2148710 set([('aggression', '')])
# ---
# 24509480 rs9505118 set([('type 2 diabetes', '')])
# 24509480 rs3130501 set([('type 2 diabetes', '')])
# 24509480 rs4275659 set([('type 2 diabetes', '')])
# 24509480 rs6808574 set([('type 2 diabetes', '')])
# 24509480 rs6813195 set([('type 2 diabetes', '')])
# 24509480 rs702634 set([('type 2 diabetes', '')])
# 24509480 rs17106184 set([('type 2 diabetes', '')])
# ---
# 24511991 rs356220 set([('Parkinson\xe2\x80\x99s disease', '')])
# 24511991 rs12681349 set([('Parkinson\xe2\x80\x99s disease', '')])
# 24511991 rs3129882 set([('Parkinson\xe2\x80\x99s disease', '')])
# 24511991 rs2338971 set([('Parkinson\xe2\x80\x99s disease', '')])
# 24511991 rs199498 set([('Parkinson\xe2\x80\x99s disease', '')])
# ---
# ---
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-242-2980cf4e4865> in <module>()
#      14
#      15     # print new snps
# ---> 16     for (pmid, rsid), phens in rel_dict.items():
#      17         if pmid != doc.name: continue
#      18         if rsid in rsids_seen: continue
#
# KeyboardInterrupt:

# %%
BLACKLIST=['19043545', '18464913', '17997608', '17447842', '19936222', '19503597', '20041166']

# %% [markdown]
# #### Error analysis over top 15 documents

# %% [markdown]
# Crohns disease (1st paper): Table is really messed up, but could solve it with a specialized extractor that looks at induced cells.
#
# Weight/bmi: The table is only a screenshot
#
# Acronyms at the end: The acronym explanations are in the caption of the table
#
# Some acroynms aren't resolved because an extra letter is added to them e.g. AXYZ instead of XYZ

# %% [markdown]
# ### Set up map of GWC to GWASDB phenotypes

# %%
out_set = set()
for a in assocs:
    s1 = gold_rel_dict[(a.paper.pubmed_id, a.snp.rs_id)]
    s2 = rel_dict.get((str(a.paper.pubmed_id), a.snp.rs_id), None)
    if s1 and s2:
        for name1 in s1:
            for name2a, name2b in s2:
                name1 = str(name1)
                score = phen_scores.get((name1.lower(), name2a.lower(), name2b.lower()), '')
                out_set.add('%s\t%s\t%s\t%s\n' % (name1, name2a, name2b, score))

with open('phenotype.mapping.tsv', 'w') as f:                    
    for out_str in out_set:
        f.write(out_str)

# %% [markdown]
# Dictionary legend in 0: wrong, 1: acronym, 2: imprecise, 3: correct

# %%
phen_map = dict()
phen_scores = dict()
with open('phenotype.mapping.annotated.txt') as f:                    
    lines = f.read().split('\r')
    for line in lines:
        fields = line.strip().split('\t')
        if fields[0] == 'Thiazide-induced':
            print fields
        fields = [re.sub('"', '', f) for f in fields]
        try:
            orig_name, glob_name, loc_name, score = fields
        except ValueError:
            if len(fields) == 2:
                orig_name, glob_name = fields
                loc_name = ''
            else:
                orig_name, glob_name, loc_name = fields
            score = 3
        phen_scores[(orig_name.lower(), glob_name.lower(), loc_name.lower())] = score
        if score in ('2', '3'):
            key = (glob_name, loc_name)
            if key not in phen_map: phen_map[key] = set()
            phen_map[key].add(orig_name)

# %% [markdown]
# ### Look at results!

# %%
import re

def paper_contains(pmid, quote):
    with open('../data/db/papers/%d.xml' % pmid) as f:
        txt = f.read()
        return True if re.search(quote, txt) else False

# %%
# display directly the results we found
n_correct = 0
n_imprecise = 0
n_missing = 0
n_wrong = 0
n_total = 0
n_new = 0
invalid_per_paper = { a.paper.pubmed_id : 0 for a in assocs }
seen = set()
for a in assocs:
#     if str(a.paper.pubmed_id) in BLACKLIST: continue
    if (a.paper.pubmed_id, a.snp.rs_id) in seen: continue
    seen.add((a.paper.pubmed_id, a.snp.rs_id))
    gold_phen_set = gold_rel_dict[(a.paper.pubmed_id, a.snp.rs_id)]
    pred_phen_set = rel_dict.get((str(a.paper.pubmed_id), a.snp.rs_id), {})
    tmp = list(pred_phen_set)
    if tmp and tmp[0][1].startswith('Age at'):
        n_correct += 1
        continue
    pred_phen_set2 = {m for p in pred_phen_set for m in phen_map.get(p, {})}
    if gold_phen_set & pred_phen_set2: 
        n_correct += 1
        n_total += 1
    else:
#         if True:
        if paper_contains(a.paper.pubmed_id, a.snp.rs_id):
            if a.paper.pubmed_id == 20195266:
                print a.snp.rs_id, gold_phen_set, pred_phen_set, pred_phen_set2
            if pred_phen_set2:
                n_wrong += 1
            else:
                n_missing += 1
            n_total += 1
            invalid_per_paper[a.paper.pubmed_id] += 1
#         print gold_phen_set
#         print pred_phen_set
#         print pred_phen_set2        
#         print

print n_correct, n_wrong, n_missing, n_total

print 'Biggest omissions:', sorted(invalid_per_paper.items(), key=lambda x: x[1], reverse=True)[:15]
# Out:
# 2530 33 395 2954
# Biggest omissions: [(23400010, 14), (19197348, 12), (22747683, 9), (22675492, 8), (21533175, 8), (23202124, 7), (22493691, 7), (23903356, 7), (23583978, 7), (23563607, 7), (22216198, 7), (23381943, 7), (24068962, 6), (22961080, 6), (23300278, 5)]

# %% [markdown]
# #### Notes from all papers:
#
# 19197348: (Korsae islanders) No global phenotype, need to handle phenotype headers. Some not parsed because exact match not in dict, need to search for n-grams
# 23400010: All the SNPs are in text!!
# 19305408: Phenotype incorrect? QT Interval vs sudden cardian death. But QT interval is in abstract
# 22760553: citalopram in dict but connected to a dash in title. Add "side effects" to matched keywords?
# 22747683: They're in text
# 22675492: Estradiol gets pushed our because "testosterone," and "testostreone" both present
# 21533175: can't parse 'Serum dehydroepiandrosterone sulphate levels' (acronym in text)
# 23202124: It's all in text
# 22493691: pvalue/rel not parsed in table (WTF!)
# 23903356: all in text (not abstract)
# 23583978: in the text (some in abstract)
# 23563607: Phenotype headers not fully matched (e.g. Obesity type-2) and "trails" instead of traits
#
#
#
# Idea: Match spans if they contain the same words, but potentially in a different order

# %% [markdown]
# #### Notes from first 100:
#
# 470 fully correct
#
# 19197348: Phenotype headers
# 18159244: Completely messed-up way of writing down p-values
# 17903302: Acronyms
# 17903305: Phenotype headers, errors (prostate vs breast cancer)
# 19043545: Mentions in text
# 17447842: Mentions in text (also: Messed-up way of writing table (induced cells should help)
# 17658951: Extraction from text
# 17903296: e.g. Neck phenotype acronym has an undocumented male/female suffix
# 19557161: In text, and one table entry strangely doesn't seem have been found

# %%
paper_id = '19557161'
for a in assocs:
    if str(a.paper.pubmed_id) == paper_id and paper_contains(a.paper.pubmed_id, a.snp.rs_id):
        print a.phenotype.name, a.snp.rs_id, rel_dict.get((paper_id, a.snp.rs_id), None)
# Out:
# Waist-hip ratio rs2605100 None
# Waist circumference rs987237 None
# Waist circumference rs545854 None
# Waist circumference rs6429082 None

# %%
with open('associations.tsv', 'w') as f:
    for (pmid, rsid, (glob_phen, loc_phen)) in associations:
        pvals = pval_dict.get(pmid, None)
        pval = min(pvals.get(rsid, [-1])) if pvals else -1
        loc_phen = '-' if not loc_phen else loc_phen

        f.write('%s\t%s\t%s\t%s\t%f\n' % (pmid, rsid, glob_phen, loc_phen, pval))
