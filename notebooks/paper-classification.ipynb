# %% [markdown]
# # Paper Classification

# %% [markdown]
# Here, we will explain how to determine whether a paper is a GWAS or not. We classify papers using a text-based binary classifier, in addition to a couple hand-picked filters. First, let's see what happens when we run the classifier on the downloaded GWAS papers. We should expect almost all of them to be classified as GWAS.

# %%
from bs4 import BeautifulSoup
import glob
import numpy as np
import pickle
import re

# %% [markdown]
# First, we extract features from the paper. In particular, we extract text, which is comprised of the article title, abstract, table captions, and table headers. We also extract three filters based on the year the paper was published, the number of times an RSID appears in the paper's tables, and the number of times an RSID appears in the tables and extracted text.

# %%
def extract_features(paper):
    """
    input: name of paper
    output: [text, filters]
    """
    with open(paper) as f:
        soup = BeautifulSoup(f, 'xml')

        ### Text ###
        # Title and Abstract
        text = ""
        article_title = ""
        article_title_tag = soup.find('article-title')
        abstract_tag = soup.find('abstract')
        if article_title_tag is not None:
            text += article_title_tag.get_text().lower() + " "
            article_title = article_title_tag.get_text().lower() + " "
        if abstract_tag is not None:
            text += abstract_tag.get_text().lower()
        else:
            if soup.find('body') is not None:
                body = soup.find('body').get_text().lower()
                # get first 2000 characters from body
                limit = min(len(body), 2000)
                text += body[:limit]

        # Tables
        table_tags = soup.find_all('table-wrapper') + soup.find_all('table-wrap')
        table_titles = ""
        table_headers = ""
        table_data = ""
        for table_tag in table_tags:
            table_title_tag = table_tag.find('caption')
            if table_title_tag is not None:
                table_titles += table_title_tag.get_text().lower() + " "
            table_header = table_tag.find('thead')
            if table_header is not None:
                header_names = table_header.find_all('td')
                for name in header_names:
                    table_headers += name.get_text().lower() + " "
            table_body = table_tag.find('tbody')
            if table_body is not None:
                body_data = table_body.find_all('td')
                for data in body_data:
                    table_data += data.get_text().lower() + " "

        extracted_text = text + table_titles + table_headers

        ### Filters ###
        year = soup.find('pub-date').find('year')
        if year:
            year_filter = int(year.get_text()) >= 2006
        else:
            year_filter = 1
        
        rsid_regex = re.compile('rs[0-9]+?')
        table_rsid = re.findall(rsid_regex, table_data)
        all_rsid = re.findall(rsid_regex, extracted_text + ' ' + table_data)
        weak_rsid_filter = len(all_rsid) > 0
        strong_rsid_filter = len(table_rsid) > 0

        extracted_filters = [year_filter, weak_rsid_filter, strong_rsid_filter]

        return [extracted_text, extracted_filters]

# %%
X_text = []
X_filters = []

papers = glob.glob('../data/db/papers/*.xml')

for paper in papers:
    print paper
    features = extract_features(paper)
    X_text.append(features[0])
    X_filters.append(features[1])
# Out:
# ../data/db/papers/17447842.xml
# ../data/db/papers/17658951.xml
# ../data/db/papers/17684544.xml
# ../data/db/papers/17903292.xml
# ../data/db/papers/17903293.xml
# ../data/db/papers/17903294.xml
# ../data/db/papers/17903295.xml
# ../data/db/papers/17903296.xml
# ../data/db/papers/17903297.xml
# ../data/db/papers/17903298.xml
# ../data/db/papers/17903300.xml
# ../data/db/papers/17903301.xml
# ../data/db/papers/17903302.xml
# ../data/db/papers/17903303.xml
# ../data/db/papers/17903304.xml
# ../data/db/papers/17903305.xml
# ../data/db/papers/17903306.xml
# ../data/db/papers/17903307.xml
# ../data/db/papers/17903308.xml
# ../data/db/papers/17997608.xml
# ../data/db/papers/18159244.xml
# ../data/db/papers/18262040.xml
# ../data/db/papers/18282107.xml
# ../data/db/papers/18369459.xml
# ../data/db/papers/18455228.xml
# ../data/db/papers/18464913.xml
# ../data/db/papers/18483556.xml
# ../data/db/papers/18604267.xml
# ../data/db/papers/18776929.xml
# ../data/db/papers/18823527.xml
# ../data/db/papers/18840781.xml
# ../data/db/papers/18846228.xml
# ../data/db/papers/18941528.xml
# ../data/db/papers/19043545.xml
# ../data/db/papers/19056611.xml
# ../data/db/papers/19081515.xml
# ../data/db/papers/19096518.xml
# ../data/db/papers/19116933.xml
# ../data/db/papers/19122664.xml
# ../data/db/papers/19132087.xml
# ../data/db/papers/19169254.xml
# ../data/db/papers/19197348.xml
# ../data/db/papers/19219042.xml
# ../data/db/papers/19300482.xml
# ../data/db/papers/19300499.xml
# ../data/db/papers/19300500.xml
# ../data/db/papers/19304780.xml
# ../data/db/papers/19305408.xml
# ../data/db/papers/19343178.xml
# ../data/db/papers/19359265.xml
# ../data/db/papers/19401414.xml
# ../data/db/papers/19412175.xml
# ../data/db/papers/19412176.xml
# ../data/db/papers/19421330.xml
# ../data/db/papers/19430480.xml
# ../data/db/papers/19430483.xml
# ../data/db/papers/19448621.xml
# ../data/db/papers/19454037.xml
# ../data/db/papers/19503088.xml
# ../data/db/papers/19503597.xml
# ../data/db/papers/19557161.xml
# ../data/db/papers/19557197.xml
# ../data/db/papers/19570815.xml
# ../data/db/papers/19571809.xml
# ../data/db/papers/19578366.xml
# ../data/db/papers/19587794.xml
# ../data/db/papers/19597492.xml
# ../data/db/papers/19609347.xml
# ../data/db/papers/19651812.xml
# ../data/db/papers/19668339.xml
# ../data/db/papers/19684604.xml
# ../data/db/papers/19714205.xml
# ../data/db/papers/19714249.xml
# ../data/db/papers/19734902.xml
# ../data/db/papers/19779542.xml
# ../data/db/papers/19798445.xml
# ../data/db/papers/19801982.xml
# ../data/db/papers/19812673.xml
# ../data/db/papers/19820699.xml
# ../data/db/papers/19862010.xml
# ../data/db/papers/19874204.xml
# ../data/db/papers/19915575.xml
# ../data/db/papers/19961619.xml
# ../data/db/papers/19966805.xml
# ../data/db/papers/20011104.xml
# ../data/db/papers/20038947.xml
# ../data/db/papers/20041166.xml
# ../data/db/papers/20062060.xml
# ../data/db/papers/20066028.xml
# ../data/db/papers/20072603.xml
# ../data/db/papers/20081856.xml
# ../data/db/papers/20081858.xml
# ../data/db/papers/20169177.xml
# ../data/db/papers/20173747.xml
# ../data/db/papers/20173748.xml
# ../data/db/papers/20174558.xml
# ../data/db/papers/20190752.xml
# ../data/db/papers/20195266.xml
# ../data/db/papers/20200953.xml
# ../data/db/papers/20305777.xml
# ../data/db/papers/20339536.xml
# ../data/db/papers/20364137.xml
# ../data/db/papers/20372150.xml
# ../data/db/papers/20395239.xml
# ../data/db/papers/20418485.xml
# ../data/db/papers/20421936.xml
# ../data/db/papers/20436471.xml
# ../data/db/papers/20442857.xml
# ../data/db/papers/20463881.xml
# ../data/db/papers/20485516.xml
# ../data/db/papers/20522523.xml
# ../data/db/papers/20526338.xml
# ../data/db/papers/20548944.xml
# ../data/db/papers/20548946.xml
# ../data/db/papers/20585626.xml
# ../data/db/papers/20585627.xml
# ../data/db/papers/20622878.xml
# ../data/db/papers/20634892.xml
# ../data/db/papers/20639881.xml
# ../data/db/papers/20661308.xml
# ../data/db/papers/20663923.xml
# ../data/db/papers/20675712.xml
# ../data/db/papers/20686565.xml
# ../data/db/papers/20686608.xml
# ../data/db/papers/20686651.xml
# ../data/db/papers/20694014.xml
# ../data/db/papers/20694148.xml
# ../data/db/papers/20700438.xml
# ../data/db/papers/20700443.xml
# ../data/db/papers/20711177.xml
# ../data/db/papers/20729852.xml
# ../data/db/papers/20801717.xml
# ../data/db/papers/20802479.xml
# ../data/db/papers/20834067.xml
# ../data/db/papers/20838585.xml
# ../data/db/papers/20852633.xml
# ../data/db/papers/20858683.xml
# ../data/db/papers/20861866.xml
# ../data/db/papers/20862305.xml
# ../data/db/papers/20885792.xml
# ../data/db/papers/20921969.xml
# ../data/db/papers/20927387.xml
# ../data/db/papers/20932310.xml
# ../data/db/papers/20935630.xml
# ../data/db/papers/20953186.xml
# ../data/db/papers/20953189.xml
# ../data/db/papers/20972438.xml
# ../data/db/papers/20972440.xml
# ../data/db/papers/21037568.xml
# ../data/db/papers/21042317.xml
# ../data/db/papers/21044948.xml
# ../data/db/papers/21051773.xml
# ../data/db/papers/21060860.xml
# ../data/db/papers/21060863.xml
# ../data/db/papers/21076409.xml
# ../data/db/papers/21079607.xml
# ../data/db/papers/21082022.xml
# ../data/db/papers/21124946.xml
# ../data/db/papers/21124955.xml
# ../data/db/papers/21151130.xml
# ../data/db/papers/21186350.xml
# ../data/db/papers/21203500.xml
# ../data/db/papers/21223598.xml
# ../data/db/papers/21242260.xml
# ../data/db/papers/21244703.xml
# ../data/db/papers/21273288.xml
# ../data/db/papers/21278746.xml
# ../data/db/papers/21297633.xml
# ../data/db/papers/21298027.xml
# ../data/db/papers/21298047.xml
# ../data/db/papers/21326860.xml
# ../data/db/papers/21339755.xml
# ../data/db/papers/21347284.xml
# ../data/db/papers/21364930.xml
# ../data/db/papers/21379329.xml
# ../data/db/papers/21383967.xml
# ../data/db/papers/21386085.xml
# ../data/db/papers/21390209.xml
# ../data/db/papers/21399635.xml
# ../data/db/papers/21408207.xml
# ../data/db/papers/21418511.xml
# ../data/db/papers/21423239.xml
# ../data/db/papers/21423719.xml
# ../data/db/papers/21424380.xml
# ../data/db/papers/21437268.xml
# ../data/db/papers/21448238.xml
# ../data/db/papers/21460840.xml
# ../data/db/papers/21460841.xml
# ../data/db/papers/21483430.xml
# ../data/db/papers/21483845.xml
# ../data/db/papers/21490707.xml
# ../data/db/papers/21490949.xml
# ../data/db/papers/21502949.xml
# ../data/db/papers/21533022.xml
# ../data/db/papers/21533024.xml
# ../data/db/papers/21533074.xml
# ../data/db/papers/21533175.xml
# ../data/db/papers/21552555.xml
# ../data/db/papers/21573004.xml
# ../data/db/papers/21573128.xml
# ../data/db/papers/21602797.xml
# ../data/db/papers/21602798.xml
# ../data/db/papers/21627779.xml
# ../data/db/papers/21658281.xml
# ../data/db/papers/21665990.xml
# ../data/db/papers/21685912.xml
# ../data/db/papers/21700879.xml
# ../data/db/papers/21708048.xml
# ../data/db/papers/21729881.xml
# ../data/db/papers/21738478.xml
# ../data/db/papers/21738479.xml
# ../data/db/papers/21738484.xml
# ../data/db/papers/21738487.xml
# ../data/db/papers/21738491.xml
# ../data/db/papers/21750679.xml
# ../data/db/papers/21771975.xml
# ../data/db/papers/21779176.xml
# ../data/db/papers/21779181.xml
# ../data/db/papers/21779381.xml
# ../data/db/papers/21799836.xml
# ../data/db/papers/21801394.xml
# ../data/db/papers/21804547.xml
# ../data/db/papers/21804549.xml
# ../data/db/papers/21810271.xml
# ../data/db/papers/21812969.xml
# ../data/db/papers/21814517.xml
# ../data/db/papers/21827660.xml
# ../data/db/papers/21829377.xml
# ../data/db/papers/21829393.xml
# ../data/db/papers/21873549.xml
# ../data/db/papers/21876539.xml
# ../data/db/papers/21878437.xml
# ../data/db/papers/21901158.xml
# ../data/db/papers/21909108.xml
# ../data/db/papers/21909110.xml
# ../data/db/papers/21909115.xml
# ../data/db/papers/21931564.xml
# ../data/db/papers/21931568.xml
# ../data/db/papers/21935397.xml
# ../data/db/papers/21943158.xml
# ../data/db/papers/21946350.xml
# ../data/db/papers/21980299.xml
# ../data/db/papers/21980494.xml
# ../data/db/papers/21983785.xml
# ../data/db/papers/21983787.xml
# ../data/db/papers/21998595.xml
# ../data/db/papers/21998597.xml
# ../data/db/papers/22001756.xml
# ../data/db/papers/22028671.xml
# ../data/db/papers/22044751.xml
# ../data/db/papers/22085899.xml
# ../data/db/papers/22087292.xml
# ../data/db/papers/22116950.xml
# ../data/db/papers/22120009.xml
# ../data/db/papers/22144915.xml
# ../data/db/papers/22170493.xml
# ../data/db/papers/22174851.xml
# ../data/db/papers/22197932.xml
# ../data/db/papers/22205951.xml
# ../data/db/papers/22216198.xml
# ../data/db/papers/22233651.xml
# ../data/db/papers/22238593.xml
# ../data/db/papers/22247754.xml
# ../data/db/papers/22267201.xml
# ../data/db/papers/22286170.xml
# ../data/db/papers/22291604.xml
# ../data/db/papers/22291609.xml
# ../data/db/papers/22306652.xml
# ../data/db/papers/22344219.xml
# ../data/db/papers/22359512.xml
# ../data/db/papers/22368281.xml
# ../data/db/papers/22383897.xml
# ../data/db/papers/22384028.xml
# ../data/db/papers/22396660.xml
# ../data/db/papers/22403646.xml
# ../data/db/papers/22423221.xml
# ../data/db/papers/22428042.xml
# ../data/db/papers/22430674.xml
# ../data/db/papers/22438815.xml
# ../data/db/papers/22452962.xml
# ../data/db/papers/22470424.xml
# ../data/db/papers/22479191.xml
# ../data/db/papers/22479202.xml
# ../data/db/papers/22479309.xml
# ../data/db/papers/22479419.xml
# ../data/db/papers/22484627.xml
# ../data/db/papers/22493691.xml
# ../data/db/papers/22504421.xml
# ../data/db/papers/22509378.xml
# ../data/db/papers/22511988.xml
# ../data/db/papers/22544364.xml
# ../data/db/papers/22558069.xml
# ../data/db/papers/22558097.xml
# ../data/db/papers/22561518.xml
# ../data/db/papers/22570617.xml
# ../data/db/papers/22570627.xml
# ../data/db/papers/22570697.xml
# ../data/db/papers/22589738.xml
# ../data/db/papers/22589742.xml
# ../data/db/papers/22666496.xml
# ../data/db/papers/22675492.xml
# ../data/db/papers/22685421.xml
# ../data/db/papers/22693455.xml
# ../data/db/papers/22693459.xml
# ../data/db/papers/22719876.xml
# ../data/db/papers/22737229.xml
# ../data/db/papers/22745674.xml
# ../data/db/papers/22747683.xml
# ../data/db/papers/22760553.xml
# ../data/db/papers/22763110.xml
# ../data/db/papers/22792070.xml
# ../data/db/papers/22792071.xml
# ../data/db/papers/22792082.xml
# ../data/db/papers/22792221.xml
# ../data/db/papers/22807686.xml
# ../data/db/papers/22829776.xml
# ../data/db/papers/22832960.xml
# ../data/db/papers/22832961.xml
# ../data/db/papers/22832964.xml
# ../data/db/papers/22889924.xml

# %% [markdown]
# To predict whether a paper is GWAS or not, we use an SVM classifier that has been trained on the extracted text of papers using a bag-of-words model.

# %%
with open('../data/classifiers/classifier.pkl') as f:
    clf = pickle.load(f)
predicted = clf.predict(X_text)

# %% [markdown]
# Also, we filter out any paper published before 2006, because those papers are highly unlikely to be GWAS. (The first GWAS paper was published in 2005.)

# %%
filters = np.asarray(X_filters)
predicted = np.logical_and(predicted, filters[:,0])

# %% [markdown]
# Optionally, we can also filter out papers that do not have any extractable information. The weak filter excludes any papers that don't have an RSID in the extracted text or tables. The strong filter excludes any papers that don't have an RSID in the tables. We use the weak filter as default.

# %%
filter_type = 'weak'  # You can change this! The choices are None, 'weak', or 'strong'
if filter_type == 'weak':
    predicted = np.logical_and(predicted, filters[:,1])
elif filter_type == 'strong':
    predicted = np.logical_and(predicted, filters[:,2])

# %% [markdown]
# Write out the results.

# %%
def get_title(paper):
    with open(paper) as f:
        text = f.read()
        title_regex = re.compile('<article-title>.+?</article-title>')
        match = re.search(title_regex, text)
        if match is None:
            return ""
        title = match.group(0)[15:-16]
        title = title.replace('<italic>', '').replace('</italic>', '')
        return title

num_gwas_predicted = np.count_nonzero(predicted)
print "number GWAS predicted: {} out of {}".format(num_gwas_predicted, len(predicted))
for i, p in enumerate(predicted):
    if p == 1:
        print "{} - {}".format(papers[i], get_title(papers[i]))
# Out:
# number GWAS predicted: 297 out of 320
# ../data/db/papers/17658951.xml - Genome-Wide Association Scan Shows Genetic Variants in the FTO Gene Are Associated with Obesity-Related Traits
# ../data/db/papers/17684544.xml - Systematic Association Mapping Identifies NELL1 as a Novel IBD Disease Gene
# ../data/db/papers/17903292.xml - A genome-wide association for kidney function and endocrine-related traits in the NHLBI's Framingham Heart Study
# ../data/db/papers/17903293.xml - Genome-wide association with select biomarker traits in the Framingham Heart Study
# ../data/db/papers/17903294.xml - Genome-wide association and linkage analyses of hemostatic factors and hematological phenotypes in the Framingham Heart Study
# ../data/db/papers/17903295.xml - Genetic correlates of longevity and selected age-related phenotypes: a genome-wide association study in the Framingham Study
# ../data/db/papers/17903296.xml - Genome-wide association with bone mass and geometry in the Framingham Heart Study
# ../data/db/papers/17903297.xml - Genetic correlates of brain aging on MRI and cognitive test measures: a genome-wide association and linkage analysis in the Framingham study
# ../data/db/papers/17903298.xml - Genome-wide association with diabetes-related traits in the Framingham Heart Study
# ../data/db/papers/17903300.xml - Genome-wide association to body mass index and waist circumference: the Framingham Heart Study 100K project
# ../data/db/papers/17903301.xml - Genome-wide association of echocardiographic dimensions, brachial artery endothelial function and treadmill exercise responses in the Framingham Heart Study
# ../data/db/papers/17903302.xml - Framingham Heart Study 100K Project: genome-wide associations for blood pressure and arterial stiffness
# ../data/db/papers/17903303.xml - Genome-wide association study for subclinical atherosclerosis in major arterial territories in the NHLBI's Framingham Heart Study
# ../data/db/papers/17903304.xml - Framingham Heart Study 100K project: genome-wide associations for cardiovascular disease outcomes
# ../data/db/papers/17903305.xml - A genome-wide association study of breast and prostate cancer in the NHLBI's Framingham Heart Study
# ../data/db/papers/17903306.xml - Genome-wide association study of electrocardiographic and heart rate variability traits: the Framingham Heart Study
# ../data/db/papers/17903307.xml - Framingham Heart Study genome-wide association: results for pulmonary function measures
# ../data/db/papers/17997608.xml - The GLUT9 Gene Is Associated with Serum Uric Acid Levels in Sardinia and Chianti Cohorts
# ../data/db/papers/18159244.xml - Genome Wide Association (GWA) Study for Early Onset Extreme Obesity Supports the Role of Fat Mass and Obesity Associated Gene (FTO) Variants
# ../data/db/papers/18262040.xml - LDL-cholesterol concentrations: a genome-wide association study
# ../data/db/papers/18282107.xml - Genome-Wide Association Identifies a Common Variant in the Reelin Gene That Increases the Risk of Schizophrenia Only in Women
# ../data/db/papers/18369459.xml - A Genome-Wide Association Study of Psoriasis and Psoriatic Arthritis Identifies New Disease Loci
# ../data/db/papers/18455228.xml - Bone mineral density, osteoporosis, and osteoporotic fractures: a genome-wide association study
# ../data/db/papers/18464913.xml - A Genome-Wide Association Study Identifies Protein Quantitative Trait Loci (pQTLs)
# ../data/db/papers/18483556.xml - A Genome-Wide Association Study Identifies Novel Alleles Associated with Hair Color and Skin Pigmentation
# ../data/db/papers/18604267.xml - Novel Association of ABO Histo-Blood Group Antigen with Soluble ICAM-1: Results of a Genome-Wide Association Study of 6,578 Women
# ../data/db/papers/18776929.xml - Identification of PLCL1 Gene for Hip Bone Size Variation in Females in a Genome-Wide Association Study
# ../data/db/papers/18823527.xml - A genome-wide association study for late-onset Alzheimer's disease using DNA pooling
# ../data/db/papers/18840781.xml - Follow-Up Analysis of Genome-Wide Association Data Identifies Novel Loci for Type 1 Diabetes
# ../data/db/papers/18846228.xml - Genome-Wide Scan on Total Serum IgE Levels Identifies FCER1A as Novel Susceptibility Locus
# ../data/db/papers/18941528.xml - Identification of a Novel Risk Locus for Multiple Sclerosis at 13q31.3 by a Pooled Genome-Wide Scan of 500,000 Single Nucleotide Polymorphisms
# ../data/db/papers/19056611.xml - Adiposity-Related Heterogeneity in Patterns of Type 2 Diabetes Susceptibility Observed in Genome-Wide Association Data
# ../data/db/papers/19081515.xml - Genetic risk factors for variant Creutzfeldt&#x2013;Jakob disease: a genome-wide association study
# ../data/db/papers/19096518.xml - Novel Association of HK1 with Glycated Hemoglobin in a Non-Diabetic Population: A Genome-Wide Evaluation of 14,618 Participants in the Women's Genome Health Study
# ../data/db/papers/19116933.xml - Identification of a novel susceptibility locus for juvenile idiopathic arthritis by genome-wide association analysis
# ../data/db/papers/19122664.xml - Ulcerative colitis loci on chromosomes 1p36 and 12q15 identified by genome-wide association study
# ../data/db/papers/19132087.xml - A Genome-Wide Association Study Identifies Novel and Functionally Related Susceptibility Loci for Kawasaki Disease
# ../data/db/papers/19169254.xml - Genomewide Scan Reveals Association of Psoriasis with IL-23 and NF-&#x3BA;B Pathways
# ../data/db/papers/19197348.xml - Genome-Wide Association Studies in an Isolated Founder Population from the Pacific Island of Kosrae
# ../data/db/papers/19219042.xml - Genome-wide association study identifies a novel breast cancer susceptibility locus at 6q25.1
# ../data/db/papers/19300482.xml - A Genome-Wide Association Study in Chronic Obstructive Pulmonary Disease (COPD): Identification of Two Major Susceptibility Loci
# ../data/db/papers/19300499.xml - A Genome-Wide Association Study Confirms VKORC1, CYP2C9, and CYP4F2 as Principal Genetic Determinants of Warfarin Dose
# ../data/db/papers/19300500.xml - A Genome-Wide Association Study of Pulmonary Function Measures in the Framingham Heart Study
# ../data/db/papers/19304780.xml - Genome-wide scan identifies CDH13 as a novel susceptibility locus contributing to blood pressure determination in two European populations
# ../data/db/papers/19305408.xml - Common variants at ten loci influence myocardial repolarization: the QTGEN consortium
# ../data/db/papers/19343178.xml - Meta-Analysis of Genome-Wide Scans for Human Adult Stature Identifies Novel Loci and Associations with Measures of Skeletal Frame Size
# ../data/db/papers/19359265.xml - A genome-wide association study identifies a novel locus on chromosome 18q12.2 influencing white cell telomere length
# ../data/db/papers/19401414.xml - Confirmation of Multiple Risk Loci and Genetic Impacts by a Genome-Wide Association Study of Type 2 Diabetes in the Japanese Population
# ../data/db/papers/19412175.xml - Common variations in BARD1 influence susceptibility to high-risk neuroblastoma
# ../data/db/papers/19412176.xml - Narcolepsy is strongly associated with the TCR alpha locus
# ../data/db/papers/19421330.xml - Genome-Wide Association Study of Young-Onset Hypertension in the Han Chinese Population of Taiwan
# ../data/db/papers/19430480.xml - Genome-wide association study and meta-analysis finds over 40 loci affect risk of type 1 diabetes
# ../data/db/papers/19430483.xml - Eight blood pressure loci identified by genome-wide association study of 34,433 people of European ancestry
# ../data/db/papers/19448621.xml - Genome-wide association studies identify novel loci associated with age at menarche and age at natural menopause
# ../data/db/papers/19454037.xml - Genome-wide association study identifies single-nucleotide polymorphism in KCNB1 associated with left ventricular mass in humans: The HyperGEN Study
# ../data/db/papers/19503088.xml - REL, a member of the NF-&#x3BA;B family of transcription factors, is a newly defined risk locus for rheumatoid arthritis
# ../data/db/papers/19503597.xml - Meta-Analysis of 28,141 Individuals Identifies Common Variants within Five New Loci That Influence Uric Acid Concentrations
# ../data/db/papers/19557161.xml - Genome-Wide Association Scan Meta-Analysis Identifies Three Loci Influencing Adiposity and Fat Distribution
# ../data/db/papers/19557197.xml - Genome-Wide Association Scan Meta-Analysis Identifies Three Loci Influencing Adiposity and Fat Distribution
# ../data/db/papers/19570815.xml - A genome-wide association study of northwestern Europeans involves the C-type natriuretic peptide signaling pathway in the etiology of human height variation
# ../data/db/papers/19571809.xml - Common variants on chromosome 6p22.1 are associated with schizophrenia
# ../data/db/papers/19578366.xml - Variants in the CDKN2B and RTEL1 regions are associated with high grade glioma susceptibility
# ../data/db/papers/19587794.xml - Common Genetic Variation Near the Phospholamban Gene Is Associated with Cardiac Repolarisation: Meta-Analysis of Three Genome-Wide Association Studies
# ../data/db/papers/19597492.xml - Variants in ZFHX3 are associated with atrial fibrillation in individuals of European ancestry
# ../data/db/papers/19609347.xml - A Genome-Wide Association Study of Hypertension and Blood Pressure in African Americans
# ../data/db/papers/19668339.xml - Hippocampal Atrophy as a Quantitative Trait in a Genome-Wide Association Study Identifying Novel Susceptibility Genes for Alzheimer's Disease
# ../data/db/papers/19684604.xml - Loci on 7p12.2, 10q21.2 and 14q11.2 are associated with risk of childhood acute lymphoblastic leukemia
# ../data/db/papers/19714205.xml - Genome-Wide Association Study Implicates Chromosome 9q21.31 as a Susceptibility Locus for Asthma in Mexican Children
# ../data/db/papers/19714249.xml - Powerful Bivariate Genome-Wide Association Analyses Suggest the SOX6 Gene Influencing Both Obesity and Osteoporosis Phenotypes in Males
# ../data/db/papers/19734902.xml - Genome-wide association study identifies variants at CLU and PICALM associated with Alzheimer's disease, and shows evidence for additional susceptibility genes
# ../data/db/papers/19779542.xml - A Genome-Wide Association Analysis Identified a Novel Susceptible Locus for Pathological Myopia at 11q24.1
# ../data/db/papers/19798445.xml - Genetic Determinants of Circulating Sphingolipid Concentrations in European Populations
# ../data/db/papers/19801982.xml - Twenty bone mineral density loci identified by large-scale meta-analysis of genome-wide association studies
# ../data/db/papers/19812673.xml - A GENOME-WIDE LINKAGE AND ASSOCIATION SCAN REVEALS NOVEL LOCI FOR AUTISM
# ../data/db/papers/19820699.xml - Common variants in TMPRSS6 are associated with iron status and erythrocyte volume
# ../data/db/papers/19862010.xml - Multiple loci influence erythrocyte phenotypes in the CHARGE Consortium
# ../data/db/papers/19874204.xml - IL21R and PTH May Underlie Variation of Femoral Neck Bone Mineral Density as Revealed by a Genome-wide Association Study
# ../data/db/papers/19915575.xml - Genome-Wide Association Study reveals genetic risk underlying Parkinson&#x2019;s disease
# ../data/db/papers/19966805.xml - The imprinted DLK1-MEG3 gene region on chromosome 14q32.2 alters susceptibility to type 1 diabetes
# ../data/db/papers/20011104.xml - A Genome-Wide Association Study Reveals Variants in ARL15 that Influence Adiponectin Levels
# ../data/db/papers/20038947.xml - Novel loci for major depression identified by genome-wide association study of STAR*D and meta-analysis of three studies
# ../data/db/papers/20041166.xml - Common Genetic Variation and the Control of HIV-1 in Humans
# ../data/db/papers/20062060.xml - Genome-wide association study of PR interval
# ../data/db/papers/20066028.xml - Modeling of Environmental Effects in Genome-Wide Association Studies Identifies SLC2A2 and HP as Novel Loci Influencing Serum Cholesterol Levels
# ../data/db/papers/20072603.xml - Genome-Wide Association Study Identifies ALDH7A1 as a Novel Susceptibility Gene for Osteoporosis
# ../data/db/papers/20081856.xml - Meta-analysis of genome-wide association data detects a risk locus for major mood disorders on chromosome 3p21.1
# ../data/db/papers/20081858.xml - New genetic loci implicated in fasting glucose homeostasis and their impact on type 2 diabetes risk
# ../data/db/papers/20169177.xml - Genome-Wide Association Study in Asian Populations Identifies Variants in ETS1 and WDFY4 Associated with Systemic Lupus Erythematosus
# ../data/db/papers/20173747.xml - Common Variants in KCNN3 are Associated with Lone Atrial Fibrillation
# ../data/db/papers/20173748.xml - Variants in FAM13A are associated with chronic obstructive pulmonary disease
# ../data/db/papers/20174558.xml - A Genome-Wide Association Study Identifies Susceptibility Variants for Type 2 Diabetes in Han Chinese
# ../data/db/papers/20190752.xml - Multiple common variants for celiac disease influencing immune gene expression
# ../data/db/papers/20195266.xml - Genomewide pharmacogenomic study of metabolic side effects to antipsychotic drugs
# ../data/db/papers/20305777.xml - New Sequence Variants in HLA Class II/III Region Associated with Susceptibility to Knee Osteoarthritis Identified by Genome-Wide Association Study
# ../data/db/papers/20339536.xml - Genome-Wide Association of Lipid-Lowering Response to Statins in Combined Study Populations
# ../data/db/papers/20364137.xml - Genome-wide association study of intracranial aneurysm identifies three new risk loci
# ../data/db/papers/20372150.xml - Variants in ADCY5 and near CCNL1 are associated with fetal growth and birth weight
# ../data/db/papers/20395239.xml - Genome-wide association identifies ATOH7 as a major gene determining human optic disc size
# ../data/db/papers/20418485.xml - Genome-wide association study of circulating vitamin D levels
# ../data/db/papers/20421936.xml - Two New Loci for Body-Weight Regulation Identified in a Joint Analysis of Genome-Wide Association Studies for Early-Onset Extreme Obesity in French and German Study Groups
# ../data/db/papers/20436471.xml - Genome wide association study identifies variants at CSF1, OPTN and TNFRSF11A as genetic risk factors for Paget&#x2019;s disease of bone
# ../data/db/papers/20442857.xml - Genome-Wide Association Study of Lp-PLA<sub>2</sub> Activity and Mass in the Framingham Heart Study
# ../data/db/papers/20463881.xml - Digital Quantification of Human Eye Color Highlights Genetic Association of Three New Loci
# ../data/db/papers/20485516.xml - Common Genetic Variants near the Brittle Cornea Syndrome Locus ZNF469 Influence the Blinding Disease Risk Factor Central Corneal Thickness
# ../data/db/papers/20522523.xml - Common genetic variation and susceptibility to partial epilepsies: a genome-wide association study
# ../data/db/papers/20526338.xml - Genome-wide meta-analyses identifies 7 loci associated with platelet aggregation in response to agonists
# ../data/db/papers/20548944.xml - An Integration of Genome-Wide Association Study and Gene Expression Profiling to Prioritize the Discovery of Novel Susceptibility Loci for Osteoporosis-Related Traits
# ../data/db/papers/20548946.xml - A Genome-Wide Association Study of Optic Disc Parameters
# ../data/db/papers/20585626.xml - Identification of a Functional Genetic Variant at 16q12.1 for Breast Cancer Risk: Results from the Asia Breast Cancer Consortium
# ../data/db/papers/20585627.xml - Web-Based, Participant-Driven Studies Yield Novel Genetic Associations for Common Traits
# ../data/db/papers/20622878.xml - Genome-wide association study identifies variants in the MHC class I, IL10, and IL23R/IL12RB2 regions associated with Beh&#xE7;et's disease
# ../data/db/papers/20634892.xml - A Genome-Wide Association Study of Neuroticism in a Population-Based Sample
# ../data/db/papers/20639881.xml - Genome-wide association study of follicular lymphoma identifies a risk locus at 6p21.32
# ../data/db/papers/20661308.xml - Genome-Wide Meta-Analysis for Serum Calcium Identifies Significantly Associated SNPs near the Calcium-Sensing Receptor (CASR) Gene
# ../data/db/papers/20663923.xml - A genome-wide scan for common alleles affecting risk for autism
# ../data/db/papers/20675712.xml - The perception of quinine taste intensity is associated with common genetic variants in a bitter receptor cluster on chromosome 12
# ../data/db/papers/20686608.xml - Genome-Wide Association Study of Pancreatic Cancer in Japanese Population
# ../data/db/papers/20686651.xml - Association of Variants at UMOD with Chronic Kidney Disease and Kidney Stones&#x2014;Role of Age and Comorbid Diseases
# ../data/db/papers/20694014.xml - Genome-wide association analyses identifies a susceptibility locus for tuberculosis on chromosome 18q11.2
# ../data/db/papers/20694148.xml - A Genome-Wide Association Study of the Metabolic Syndrome in Indian Asian Men
# ../data/db/papers/20700438.xml - The 5p15.33 Locus Is Associated with Risk of Lung Adenocarcinoma in Never-Smoking Females in Asia
# ../data/db/papers/20700443.xml - Genome-Wide Association Studies of Serum Magnesium, Potassium, and Sodium Concentrations Identify Six Loci Influencing Serum Magnesium Levels
# ../data/db/papers/20711177.xml - Common genetic variation in the HLA region is associated with late-onset sporadic Parkinson&#x2019;s disease
# ../data/db/papers/20729852.xml - Genome-wide association studies of gastric adenocarcinoma and esophageal squamous cell carcinoma identify a shared susceptibility locus in PLCE1 at 10q23
# ../data/db/papers/20801717.xml - Chromosome 9p21 in sporadic amyotrophic lateral sclerosis in the UK and seven other countries: a genome-wide association study
# ../data/db/papers/20802479.xml - Genome-wide association study of migraine implicates a common susceptibility variant on 8q22.1
# ../data/db/papers/20838585.xml - Longitudinal Genome-Wide Association of Cardiovascular Disease Risk Factors in the Bogalusa Heart Study
# ../data/db/papers/20852633.xml - Common variants at 19p13 are associated with susceptibility to ovarian cancer
# ../data/db/papers/20858683.xml - Common Variants at 10 Genomic Loci Influence Hemoglobin A<sub>1C</sub> Levels via Glycemic and Nonglycemic Pathways
# ../data/db/papers/20861866.xml - Genome-wide association identifies SKIV2L and MYRIP as protective factors for age-related macular degeneration
# ../data/db/papers/20862305.xml - Identification of New Genetic Risk Variants for Type 2 Diabetes
# ../data/db/papers/20885792.xml - Dementia Revealed: Novel Chromosome 6 Locus for Late-Onset Alzheimer Disease Provides Genetic Evidence for Folate-Pathway Abnormalities
# ../data/db/papers/20921969.xml - Genome-wide association study of antipsychotic induced QTc interval prolongation
# ../data/db/papers/20927387.xml - A Genome-Wide Association Study of Red Blood Cell Traits Using the Electronic Medical Record
# ../data/db/papers/20932310.xml - Genome-wide association reveals genetic effects on human A&#x3B2;<sub>42 </sub>and &#x3C4; protein levels in cerebrospinal fluids: a case control study
# ../data/db/papers/20935630.xml - A twin study of human obesity
# ../data/db/papers/20953186.xml - Common variants at TRAF3IP2 are associated with susceptibility to psoriatic arthritis and psoriasis
# ../data/db/papers/20953189.xml - Genome-wide association analysis identifies three psoriasis susceptibility loci
# ../data/db/papers/20972438.xml - A multi-stage genome-wide association study of bladder cancer identifies multiple susceptibility loci
# ../data/db/papers/20972440.xml - Meta-analysis of three genome-wide association studies identifies susceptibility loci for colorectal cancer at 1q41, 3q26.2, 12q13.13 and 20q13.33
# ../data/db/papers/21037568.xml - A genome-wide association study of Hodgkin Lymphoma identifies new susceptibility loci at 2p16.1 (REL), 8q24.21, and 10p14 (GATA3)
# ../data/db/papers/21042317.xml - Genome-wide association study of major depressive disorder: new results, meta-analysis, and lessons learned
# ../data/db/papers/21044948.xml - Dissection of the genetics of Parkinson's disease identifies an additional association 5&#x2032; of SNCA and multiple associated haplotypes at 17q21
# ../data/db/papers/21051773.xml - PCSK6 is associated with handedness in individuals with dyslexia
# ../data/db/papers/21060860.xml - Common Genetic Variants and Modification of Penetrance of BRCA2-Associated Breast Cancer
# ../data/db/papers/21060863.xml - Coronary microvascular dysfunction.
# ../data/db/papers/21076409.xml - Common variants in 22 loci are associated with QRS duration and cardiac ventricular conduction
# ../data/db/papers/21079607.xml - A genome-wide association study of anorexia nervosa
# ../data/db/papers/21082022.xml - Genome-Wide Association Study of Blood Pressure Extremes Identifies Variant near UMOD Associated with Hypertension
# ../data/db/papers/21124946.xml - Genome-Wide Association Meta-Analysis of Cortical Bone Mineral Density Unravels Allelic Heterogeneity at the RANKL Locus and Potential Pleiotropic Effects on Bone
# ../data/db/papers/21124955.xml - Genome-Wide Association Study Identifies Two Novel Regions at 11p15.5-p13 and 1p31 with Major Impact on Acute-Phase Serum Amyloid A
# ../data/db/papers/21151130.xml - Genome-wide association study identifies a locus at 7p15.2 associated with endometriosis
# ../data/db/papers/21203500.xml - Genomics Meets Glycomics&#x2014;The First GWAS Study of Human N-Glycome Identifies HNF1&#x3B1; as a Master Regulator of Plasma Protein Fucosylation
# ../data/db/papers/21223598.xml - Genome-wide joint SNP and CNV analysis of aortic root diameter in African Americans: the HyperGEN study
# ../data/db/papers/21242260.xml - Common variant in 6q26-q27 is associated with distal colon cancer in an Asian population
# ../data/db/papers/21244703.xml - Modeling the cumulative genetic risk for multiple sclerosis from genome-wide association data
# ../data/db/papers/21273288.xml - Genome-wide association analysis and fine mapping of NT-proBNP level provide novel insight into the role of the MTHFR-CLCN6-NPPA-NPPB gene cluster
# ../data/db/papers/21278746.xml - Common variants in ZNF365 are associated with both mammographic density and breast cancer risk
# ../data/db/papers/21297633.xml - Meta-analysis identifies 29 additional ulcerative colitis risk loci, increasing the number of confirmed associations to 47
# ../data/db/papers/21298027.xml - A Meta-Analysis of Genome-Wide Association Scans Identifies IL18RAP, PTPN2, TAGAP, and PUS10 As Shared Risk Loci for Crohn's Disease and Celiac Disease
# ../data/db/papers/21326860.xml - Identification of Novel Susceptibility Loci for Kawasaki Disease in a Han Chinese Population by a Genome-Wide Association Study
# ../data/db/papers/21339755.xml - A non- synonymous polymorphism in galactose mutarotase (GALM) is associated with serotonin transporter binding potential in the human thalamus: Results of a genome-wide association study
# ../data/db/papers/21347284.xml - Genome-Wide Association Studies of the PR Interval in African Americans
# ../data/db/papers/21364930.xml - Genome-Wide Association Study Identifies Single Nucleotide Polymorphism in DYRK1A Associated with Replication of HIV-1 in Monocyte-Derived Macrophages
# ../data/db/papers/21379329.xml - Genome-Wide Association of Familial Late-Onset Alzheimer's Disease Replicates BIN1 and CLU and Nominates CUGBP2 in Interaction with APOE
# ../data/db/papers/21383967.xml - Meta-Analysis of Genome-Wide Association Studies in Celiac Disease and Rheumatoid Arthritis Identifies Fourteen Non-HLA Shared Loci
# ../data/db/papers/21386085.xml - A Bivariate Genome-Wide Approach to Metabolic Syndrome
# ../data/db/papers/21390209.xml - Meta-Analysis for Genome-Wide Association Study Identifies Multiple Variants at the BIN1 Locus Associated with Late-Onset Alzheimer's Disease
# ../data/db/papers/21399635.xml - Genome-wide association study identifies 12 new susceptibility loci for primary biliary cirrhosis
# ../data/db/papers/21418511.xml - Genome-wide association study identifies a single major locus contributing to survival into old age; the APOE locus revisited
# ../data/db/papers/21423239.xml - A genome-wide association study of attempted suicide
# ../data/db/papers/21423719.xml - Genome-Wide Association Analysis Identifies Variants Associated with Nonalcoholic Fatty Liver Disease That Have Distinct Effects on Metabolic Traits
# ../data/db/papers/21424380.xml - Potential novel candidate polymorphisms identified in genome-wide association study for breast cancer susceptibility
# ../data/db/papers/21437268.xml - A Genome-Wide Association Study of Upper Aerodigestive Tract Cancers Conducted within the INHANCE Consortium
# ../data/db/papers/21448238.xml - Meta-analysis of genome-wide association for migraine in six population-based European cohorts
# ../data/db/papers/21460840.xml - Common variants in ABCA7, MS4A6A/MS4A4E, EPHA1, CD33 and CD2AP are associated with Alzheimer&#x2019;s disease
# ../data/db/papers/21460841.xml - Common variants in MS4A4/MS4A6E, CD2uAP, CD33, and EPHA1 are associated with late-onset Alzheimer&#x2019;s disease
# ../data/db/papers/21483430.xml - Impact of DISC1 variation on neuroanatomical and neurocognitive phenotypes
# ../data/db/papers/21483845.xml - Genome-Wide Association Study Identifies Genetic Loci Associated with Iron Deficiency
# ../data/db/papers/21490707.xml - Genome-Wide Meta-Analysis Identifies Regions on 7p21 (AHR) and 15q24 (CYP1A2) As Determinants of Habitual Caffeine Consumption
# ../data/db/papers/21490949.xml - Diabetes in Asia.
# ../data/db/papers/21502949.xml - Discovery and replication of dopamine-related gene effects on caudate volume in young and elderly populations (N=1198) using genome-wide search
# ../data/db/papers/21533022.xml - Impact of genetics on low bone mass in adults.
# ../data/db/papers/21533024.xml - Genome-Wide Association Analysis of Soluble ICAM-1 Concentration Reveals Novel Associations at the NFKBIK, PNPLA3, RELA, and SH2B3 Loci
# ../data/db/papers/21533074.xml - Organochlorines and risk of non-Hodgkin lymphoma.
# ../data/db/papers/21533175.xml - Eight Common Genetic Variants Associated with Serum DHEAS Levels Suggest a Key Role in Ageing Mechanisms
# ../data/db/papers/21552555.xml - A Genome-Wide Association Study on Obesity and Obesity-Related Traits
# ../data/db/papers/21573004.xml - Genome-Wide Association Study of Relative Telomere Length
# ../data/db/papers/21573128.xml - Common Variants in a Novel Gene, FONG on Chromosome 2q33.1 Confer Risk of Osteoporosis in Japanese
# ../data/db/papers/21602797.xml - Genome-wide association and linkage identify modifier loci of lung disease severity in cystic fibrosis at 11p13 and 20q13.2
# ../data/db/papers/21602798.xml - Genome-wide association study of prostate cancer in men of African ancestry identifies a susceptibility locus at 17q21
# ../data/db/papers/21627779.xml - The membrane-spanning 4-domains, subfamily A (MS4A) gene cluster contains a common variant associated with Alzheimer's disease
# ../data/db/papers/21658281.xml - GWAS for discovery and replication of genetic loci associated with sudden cardiac arrest in patients with coronary artery disease
# ../data/db/papers/21665990.xml - Common variants near FRK/COL10A1 and VEGFA are associated with advanced age-related macular degeneration
# ../data/db/papers/21685912.xml - Identification of common variants influencing risk of the tauopathy Progressive Supranuclear Palsy
# ../data/db/papers/21700879.xml - Novel Locus FER Is Associated With Serum HMW Adiponectin Levels
# ../data/db/papers/21708048.xml - Genome wide association study identifies KCNMA1 contributing to human obesity
# ../data/db/papers/21729881.xml - Genome-wide association study identifies common variants associated with circulating vitamin E levels
# ../data/db/papers/21738478.xml - Identification of Nine Novel Loci Associated with White Blood Cell Subtypes in a Japanese Population
# ../data/db/papers/21738479.xml - Genome-Wide Association Study of White Blood Cell Count in 16,388 African Americans: the Continental Origins and Genetic Epidemiology Network (COGENT)
# ../data/db/papers/21738487.xml - Web-Based Genome-Wide Association Study Identifies Two Novel Loci and a Substantial Genetic Component for Parkinson's Disease
# ../data/db/papers/21738491.xml - Identification of a Sudden Cardiac Death Susceptibility Locus at 2q24.2 through Genome-Wide Association in European Ancestry Individuals
# ../data/db/papers/21750679.xml - Genome-Wide Scan Identifies TNIP1, PSORS1C1, and RHOB as Novel Risk Loci for Systemic Sclerosis
# ../data/db/papers/21771975.xml - A Genome-Wide Association Study Reveals a Quantitative Trait Locus of Adiponectin on CDH13 That Predicts Cardiometabolic Outcomes
# ../data/db/papers/21779176.xml - Genome-Wide Association Study Identifies Novel Restless Legs Syndrome Susceptibility Loci on 2p14 and 16q12.1
# ../data/db/papers/21779181.xml - Identification of Novel Genetic Markers Associated with Clinical Phenotypes of Systemic Sclerosis through a Genome-Wide Association Strategy
# ../data/db/papers/21779381.xml - Genetic Determinants of Cardiovascular Events among Women with Migraine: A Genome-Wide Association Study
# ../data/db/papers/21799836.xml - A Genome-Wide Association Study Confirms Previously Reported Loci for Type 2 Diabetes in Han Chinese
# ../data/db/papers/21801394.xml - Genome-wide association study of Stevens-Johnson Syndrome and Toxic Epidermal Necrolysis in Europe
# ../data/db/papers/21804547.xml - Common variation at 10p12.31 near MLLT10 influences meningioma risk
# ../data/db/papers/21804549.xml - Meta-analysis of Genome-wide Association Studies of Asthma In Ethnically Diverse North American Populations
# ../data/db/papers/21810271.xml - Combined analysis of three genome-wide association studies on vWF and FVIII plasma levels
# ../data/db/papers/21812969.xml - Genome-Wide association study identifies candidate genes for Parkinson's disease in an Ashkenazi Jewish population
# ../data/db/papers/21814517.xml - Genome-Wide Association Study Identifies HLA-DP as a Susceptibility Gene for Pediatric Asthma in Asian Populations
# ../data/db/papers/21829377.xml - Genetic Loci Associated with Plasma Phospholipid n-3 Fatty Acids: A Meta-Analysis of Genome-Wide Association Studies from the CHARGE Consortium
# ../data/db/papers/21829393.xml - Genome-Wide Association Analysis of Autoantibody Positivity in Type 1 Diabetes Cases
# ../data/db/papers/21873549.xml - Genome-Wide Association Identifies Nine Common Variants Associated With Fasting Proinsulin Levels and Provides New Insights Into the Pathophysiology of Type 2 Diabetes
# ../data/db/papers/21876539.xml - Genome-wide association analysis of coffee drinking suggests association with CYP1A1/CYP1A2 and NRCAM
# ../data/db/papers/21878437.xml - Genome-wide association study of circulating retinol levels
# ../data/db/papers/21901158.xml - Genome-Wide Detection of Allele Specific Copy Number Variation Associated with Insulin Resistance in African Americans from the HyperGEN Study
# ../data/db/papers/21909110.xml - Genome-wide association study identifies six new loci influencing pulse pressure and mean arterial pressure
# ../data/db/papers/21909115.xml - Genetic Variants in Novel Pathways Influence Blood Pressure and Cardiovascular Disease Risk
# ../data/db/papers/21931564.xml - A Genome-Wide Metabolic QTL Analysis in Europeans Implicates Two Loci Shaped by Recent Positive Selection
# ../data/db/papers/21931568.xml - Genome-Wide Association Study Identifies Four Loci Associated with Eruption of Permanent Teeth
# ../data/db/papers/21935397.xml - Genome-Wide Population-Based Association Study of Extremely Overweight Young Adults &#x2013; The GOYA Study
# ../data/db/papers/21943158.xml - Genetic variants in LPL, OASL and TOMM40/APOE-C1-C2-C4 genes are associated with multiple cardiovascular-related traits
# ../data/db/papers/21946350.xml - Genome-wide association and large scale follow-up identifies 16 new loci influencing lung function
# ../data/db/papers/21980299.xml - A Genome-Wide Meta-Analysis of Six Type 1 Diabetes Cohorts Identifies Multiple Associated Loci
# ../data/db/papers/21980494.xml - Genetics of Venous Thrombosis: Insights from a New Genome Wide Association Study
# ../data/db/papers/21983785.xml - Genome-wide association study identifies a new melanoma susceptibility locus at 1q21.3
# ../data/db/papers/21983787.xml - Genome-wide association study identifies three new melanoma susceptibility loci
# ../data/db/papers/21998595.xml - Identification, Replication, and Fine-Mapping of Loci Associated with Adult Height in Individuals of African Ancestry
# ../data/db/papers/21998597.xml - Genetic Determinants of Serum Testosterone Concentrations in Men
# ../data/db/papers/22001756.xml - Genome-wide association study identifies susceptibility loci for Dengue shock syndrome at MICB and PLCE1
# ../data/db/papers/22028671.xml - A Genome-Wide Screen for Interactions Reveals a New Locus on 4p15 Modifying the Effect of Waist-to-Hip Ratio on Total Cholesterol
# ../data/db/papers/22085899.xml - UGT1A1 is a major locus influencing bilirubin levels in African Americans
# ../data/db/papers/22087292.xml - Bivariate Genome-Wide Association Analyses of Femoral Neck Bone Geometry and Appendicular Lean Mass
# ../data/db/papers/22144915.xml - Genome-Wide Meta-Analysis of Five Asian Cohorts Identifies PDGFRA as a Susceptibility Locus for Corneal Astigmatism
# ../data/db/papers/22170493.xml - Genome-wide meta-analysis of Psoriatic Arthritis Identifies Susceptibility Locus at REL
# ../data/db/papers/22197932.xml - META-ANALYSIS OF GENOME-WIDE ASSOCIATION STUDIES IDENTIFIES THREE NEW RISK LOCI FOR ATOPIC DERMATITIS
# ../data/db/papers/22216198.xml - A Genome-Wide Association Study of the Protein C Anticoagulant Pathway
# ../data/db/papers/22233651.xml - A Genome-Wide Association Study of Gestational Diabetes Mellitus in Korean Women
# ../data/db/papers/22238593.xml - A Genome-Wide Association Search for Type 2 Diabetes Genes in African Americans
# ../data/db/papers/22247754.xml - Genome-Wide Association of Implantable Cardioverter-Defibrillator Activation With Life-Threatening Arrhythmias
# ../data/db/papers/22267201.xml - Meta-analyses identify 13 novel loci associated with age at menopause and highlights DNA repair and immune pathways
# ../data/db/papers/22291604.xml - A Genome-Wide Association Study Identified AFF1 as a Susceptibility Locus for Systemic Lupus Eyrthematosus in Japanese
# ../data/db/papers/22291609.xml - A Genome-Wide Association Scan on the Levels of Markers of Inflammation in Sardinians Reveals Associations That Underpin Its Complex Regulation
# ../data/db/papers/22306652.xml - Genome-wide association study identifies a variant in HDAC9 associated with large vessel ischemic stroke
# ../data/db/papers/22344219.xml - Meta-analysis identifies common variants associated with body mass index in East Asians
# ../data/db/papers/22359512.xml - Genome-Wide Association Study Identifies Novel Loci Associated with Circulating Phospho- and Sphingolipid Concentrations
# ../data/db/papers/22368281.xml -
# ../data/db/papers/22383897.xml - Genome-Wide Association Study in East Asians Identifies Novel Susceptibility Loci for Breast Cancer
# ../data/db/papers/22384028.xml - A Genome-Wide Linkage and Association Scan Reveals Novel Loci for Hypertension and Blood Pressure Traits
# ../data/db/papers/22396660.xml - A Genome-Wide Association Study of Nephrolithiasis in the Japanese Population Identifies Novel Susceptible Loci at 5q35.3, 7p14.3, and 13q14.1
# ../data/db/papers/22423221.xml - Platelet activation and atherothrombosis.
# ../data/db/papers/22428042.xml - Common Variants in CDKN2B-AS1 Associated with Optic-Nerve Vulnerability of Glaucoma Identified by Genome-Wide Association Studies in Japanese
# ../data/db/papers/22430674.xml - Genome-wide haplotype association study identifies the FRMD4A gene as a risk locus for Alzheimer's disease
# ../data/db/papers/22438815.xml - Comprehensive Research Synopsis and Systematic Meta-Analyses in Parkinson's Disease Genetics: The PDGene Database
# ../data/db/papers/22452962.xml - A genome-wide association study identifies a breast cancer risk variant in ERBB4 at 2q34: results from the Seoul Breast Cancer Study
# ../data/db/papers/22470424.xml - A High-Density Genome-Wide Association Screen of Sporadic ALS in US Veterans
# ../data/db/papers/22479191.xml - Genome-Wide Association and Functional Follow-Up Reveals New Loci for Kidney Function
# ../data/db/papers/22479202.xml - Novel Loci for Adiponectin Levels and Their Influence on Type 2 Diabetes and Metabolic Traits: A Multi-Ethnic Meta-Analysis of 45,891 Individuals
# ../data/db/papers/22479309.xml - Genome-Wide Association Study to Identify Common Variants Associated with Brachial Circumference: A Meta-Analysis of 14 Cohorts
# ../data/db/papers/22479419.xml - Genome-Wide Association Study of Treatment Refractory Schizophrenia in Han Chinese
# ../data/db/papers/22484627.xml - A genome-wide association meta-analysis identifies new childhood obesity loci
# ../data/db/papers/22493691.xml - Novel Associations for Hypothyroidism Include Known Autoimmune Risk Loci
# ../data/db/papers/22504421.xml - Common variants at 12q14 and 12q24 are associated with hippocampal volume
# ../data/db/papers/22509378.xml - A Genome-Wide Association Study of Female Sexual Dysfunction
# ../data/db/papers/22511988.xml - A Genome-Wide Association Study Identifies UGT1A1 as a Regulator of Serum Cell-Free DNA in Young Adults: The Cardiovascular Risk in Young Finns Study
# ../data/db/papers/22544364.xml - A genome-wide association study identifies susceptibility loci for Wilms tumor
# ../data/db/papers/22558069.xml - Association of Common Variants in TNFRSF13B, TNFSF13, and ANXA3 with Serum Levels of Non-Albumin Protein and Immunoglobulin Isotypes in Japanese
# ../data/db/papers/22558097.xml - A Genome-Wide Association Study of Total Bilirubin and Cholelithiasis Risk in Sickle Cell Anemia
# ../data/db/papers/22561518.xml - Genome-wide association analyses identify 13 new susceptibility loci for generalized vitiligo
# ../data/db/papers/22570617.xml - Common Variants at 9p21 and 8q22 Are Associated with Increased Susceptibility to Optic Nerve Degeneration in Glaucoma
# ../data/db/papers/22570627.xml - Common Genetic Determinants of Intraocular Pressure and Primary Open-Angle Glaucoma
# ../data/db/papers/22570697.xml - Genome-Wide Association Study of Multiple Sclerosis Confirms a Novel Locus at 5p13.1
# ../data/db/papers/22589738.xml - Genome-Wide Association for Abdominal Subcutaneous and Visceral Adipose Reveals a Novel Locus for Visceral Fat in Women
# ../data/db/papers/22589742.xml - Genome-Wide Association of Pericardial Fat Identifies a Unique Locus for Ectopic Fat
# ../data/db/papers/22675492.xml - Genome-Wide Association Study of Circulating Estradiol, Testosterone, and Sex Hormone-Binding Globulin in Postmenopausal Women
# ../data/db/papers/22685421.xml - Genetic Variants on Chromosome 1q41 Influence Ocular Axial Length and High Myopia
# ../data/db/papers/22693455.xml - Stratifying Type 2 Diabetes Cases by BMI Identifies Genetic Risk Variants in LAMA1 and Enrichment for Risk Variants in Lean Compared to Obese Cases
# ../data/db/papers/22693459.xml - Six Novel Susceptibility Loci for Early-Onset Androgenetic Alopecia and Their Unexpected Association with Common Diseases
# ../data/db/papers/22719876.xml - Genetic Polymorphisms of the Human PNPLA3 Gene Are Strongly Associated with Severity of Non-Alcoholic Fatty Liver Disease in Japanese
# ../data/db/papers/22737229.xml - Genome-Wide Association Study Confirming Association of HLA-DP with Protection against Chronic Hepatitis B and Viral Clearance in Japanese and Korean
# ../data/db/papers/22745674.xml - Genome-Wide Association Study in a Lebanese Cohort Confirms PHACTR1 as a Major Determinant of Coronary Artery Stenosis
# ../data/db/papers/22760553.xml - Genome-wide pharmacogenomic study of citalopram-induced side effects in STAR<sup>*</sup>D
# ../data/db/papers/22763110.xml - Identification of new susceptibility loci for osteoarthritis (arcOGEN): a genome-wide association study
# ../data/db/papers/22792070.xml - Meta-Analysis of Genome-Wide Scans for Total Body BMD in Children and Adults Reveals Allelic Heterogeneity and Age-Specific Effects at the WNT16 Locus
# ../data/db/papers/22792071.xml - Consensus development conference: diagnosis, prophylaxis, and treatment of osteoporosis.
# ../data/db/papers/22792082.xml - Genome-Wide Association Analysis in Asthma Subjects Identifies SPATS2L as a Novel Bronchodilator Response Gene
# ../data/db/papers/22792221.xml - Common Variants on Chromosome 9p21 Are Associated with Normal Tension Glaucoma
# ../data/db/papers/22807686.xml - GWAS Identifies Novel Susceptibility Loci on 6p21.32 and 21q21.3 for Hepatocellular Carcinoma in Chronic Hepatitis B Virus Carriers
# ../data/db/papers/22829776.xml - A Genome-Wide Association Meta-Analysis of Circulating Sex Hormone&#x2013;Binding Globulin Reveals Multiple Loci Implicated in Sex Steroid Hormone Regulation
# ../data/db/papers/22832960.xml - A genome-wide meta-analysis of association studies of Cloninger's Temperament Scales
# ../data/db/papers/22832961.xml - Genome-wide association study of Alzheimer's disease
# ../data/db/papers/22832964.xml - Genome-wide meta-analyses of smoking behaviors in African Americans
# ../data/db/papers/22889924.xml - Genome-wide association study of Tourette Syndrome

# %% [markdown]
# Now let's see what happens when we run on a set of 100 random open-access papers. We should expect very few papers to be classified as GWAS, if any.

# %%
filter_type = 'weak'  # You can change this again! The choices are None, 'weak', or 'strong'

# %%
X_text = []
X_filters = []

papers = glob.glob('../data/db/non-gwas/*')

for paper in papers:
    features = extract_features(paper)
    X_text.append(features[0])
    X_filters.append(features[1])
    
with open('../data/classifiers/classifier.pkl') as f:
    clf = pickle.load(f)
predicted = clf.predict(X_text)

filters = np.asarray(X_filters)
predicted = np.logical_and(predicted, filters[:,0])
if filter_type == 'weak':
    predicted = np.logical_and(predicted, filters[:,1])
elif filter_type == 'strong':
    predicted = np.logical_and(predicted, filters[:,2])

num_gwas_predicted = np.count_nonzero(predicted)
print "number GWAS predicted: {} out of {}".format(num_gwas_predicted, len(predicted))
for i, p in enumerate(predicted):
    if p == 1:
        print "{} - {}".format(papers[i], get_title(papers[i]))

# %% [markdown]
# We ran the classifier with weak filter on 1.37 million open-access papers, and identified 1431 of them as GWAS. The PMC IDs for these 1431 can be found at /data/db/predicted/weak. You can download those 1431 papers by running the following:

# %%
# %%bash
# cd ../data/db
# make dl-predicted-papers

# %% [markdown]
# The predicted papers will be downloaded in XML format into /data/db/predicted-papers.
